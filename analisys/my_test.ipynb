# %%
import sys
sys.path.append('..')

from classes.NetworkXGraph import Graph

# %%
# Building graph

    # file_format: Adjacency TSV (Tab-Separated Values)
        # (Row, Col, Value) tuple describing the adjacency matrix of the graph in tab separated format.
        # Adjacency matrix is of size Num_vertices x Num_vertices
    # file: test.tsv (just a test)
    # num of nodes:      6
    # num of edges:      7
    # num of triangles:  1

g = Graph()
g.build_from_tsv('../datasets/test.tsv', data=(('ajd_value',float),), show_info=True)
# Out:
# Number of lines read from TSV file: 14
# Name:
# Type: Graph
# Number of nodes: 6
# Number of edges: 7
# Average degree:   2.3333
# Number of triangles:  1
# Clustering coefficient:  0.27777777777777773
# Connected:  Yes
# Diameter:  3
# Radius:  2
# elapsed time in seconds: 0.004530

# %%
# Using samples to build graphs and to calculate

g.get_analisys_from_samples(['clustering_coefficient', 'diameter', 'radius'])
# Out:
# ----------------------------------------
# Analysing by random edge sample strategy
# ----------------------------------------
# Elapsed time for 1 edges: 0.000765, total nodes processed: 2
# Elapsed time for 2 edges: 0.000450, total nodes processed: 2
# Elapsed time for 3 edges: 0.000924, total nodes processed: 4
# Elapsed time for 4 edges: 0.001688, total nodes processed: 5
# Elapsed time for 5 edges: 0.002296, total nodes processed: 6
# Elapsed time for 6 edges: 0.000901, total nodes processed: 5
# Elapsed time for 7 edges: 0.001123, total nodes processed: 6
# Elapsed time for 8 edges: 0.001154, total nodes processed: 6
# Elapsed time for 9 edges: 0.001232, total nodes processed: 6
# Elapsed time for 10 edges: 0.001438, total nodes processed: 6
# Elapsed time for 11 edges: 0.001195, total nodes processed: 6
# Elapsed time for 12 edges: 0.001204, total nodes processed: 6
# Elapsed time for 13 edges: 0.001246, total nodes processed: 6
# Elapsed time for 14 edges: 0.001255, total nodes processed: 6
# ----------------------------------------
# Analysing by random node sample strategy
# ----------------------------------------
# Elapsed time for 1 nodes: 0.000339, total nodes processed: 1
# Elapsed time for 2 nodes: 0.000644, total nodes processed: 2
# Elapsed time for 3 nodes: 0.000633, total nodes processed: 3
# Elapsed time for 4 nodes: 0.001077, total nodes processed: 4
# Elapsed time for 5 nodes: 0.001054, total nodes processed: 5
# Elapsed time for 6 nodes: 0.001416, total nodes processed: 6
# ----------------------------------------
# Analysing by random walk sample strategy
# ----------------------------------------
# Elapsed time for 1 steps: 0.000416, total nodes processed: 2
# Elapsed time for 2 steps: 0.000421, total nodes processed: 2
# Elapsed time for 3 steps: 0.000580, total nodes processed: 3
# Elapsed time for 4 steps: 0.000609, total nodes processed: 3
# Elapsed time for 5 steps: 0.000592, total nodes processed: 3
# Elapsed time for 6 steps: 0.000581, total nodes processed: 3
# Elapsed time for 7 steps: 0.000634, total nodes processed: 3
# Elapsed time for 8 steps: 0.000769, total nodes processed: 4
# Elapsed time for 9 steps: 0.001033, total nodes processed: 5
# Elapsed time for 10 steps: 0.001029, total nodes processed: 5
# Elapsed time for 11 steps: 0.001031, total nodes processed: 5
# Elapsed time for 12 steps: 0.001017, total nodes processed: 5
# Elapsed time for 13 steps: 0.001044, total nodes processed: 5
# Elapsed time for 14 steps: 0.001033, total nodes processed: 5
# Elapsed time for 15 steps: 0.001038, total nodes processed: 5
# Elapsed time for 16 steps: 0.001025, total nodes processed: 5
# Elapsed time for 17 steps: 0.001132, total nodes processed: 5
# Elapsed time for 18 steps: 0.001295, total nodes processed: 6
# Elapsed time for 19 steps: 0.001308, total nodes processed: 6
# Elapsed time for 20 steps: 0.001326, total nodes processed: 6
# Elapsed time for 21 steps: 0.001298, total nodes processed: 6
# Elapsed time for 22 steps: 0.001295, total nodes processed: 6
# Elapsed time for 23 steps: 0.001318, total nodes processed: 6
# Elapsed time for 24 steps: 0.001356, total nodes processed: 6
# Elapsed time for 25 steps: 0.001295, total nodes processed: 6
# Elapsed time for 26 steps: 0.001319, total nodes processed: 6
# Elapsed time for 27 steps: 0.001339, total nodes processed: 6
# Elapsed time for 28 steps: 0.001296, total nodes processed: 6
# Elapsed time for 29 steps: 0.001320, total nodes processed: 6
# Elapsed time for 30 steps: 0.001299, total nodes processed: 6
# Elapsed time for 31 steps: 0.001294, total nodes processed: 6
# Elapsed time for 32 steps: 0.001316, total nodes processed: 6
# Elapsed time for 33 steps: 0.001357, total nodes processed: 6
# Elapsed time for 34 steps: 0.001298, total nodes processed: 6
# Elapsed time for 35 steps: 0.001312, total nodes processed: 6
# Elapsed time for 36 steps: 0.001307, total nodes processed: 6
#
# Analisys from samples finished. Call plot_analsys() to view results

# %%
# Ploting results

g.plot_analisys(['clustering_coefficient', 'diameter', 'radius'])
