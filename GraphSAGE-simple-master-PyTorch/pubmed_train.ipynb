# %%
from graphsage import model
model.run_pubmed()
# Out:
# graphsage/encoders.py:31: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   init.xavier_uniform(self.weight)
# graphsage/model.py:28: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   init.xavier_uniform(self.weight)
# 0 tensor(1.0993)
# graphsage/model.py:188: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   print batch, loss.data[0]
# 1 tensor(1.0989)
# 2 tensor(1.0977)
# 3 tensor(1.0977)
# 4 tensor(1.0977)
# 5 tensor(1.0974)
# 6 tensor(1.0968)
# 7 tensor(1.0965)
# 8 tensor(1.0960)
# 9 tensor(1.0958)
# 10 tensor(1.0955)
# 11 tensor(1.0951)
# 12 tensor(1.0947)
# 13 tensor(1.0945)
# 14 tensor(1.0942)
# 15 tensor(1.0939)
# 16 tensor(1.0936)
# 17 tensor(1.0932)
# 18 tensor(1.0925)
# 19 tensor(1.0923)
# 20 tensor(1.0917)
# 21 tensor(1.0916)
# 22 tensor(1.0914)
# 23 tensor(1.0911)
# ...
