# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
import networkx as nx
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import MultiLabelBinarizer

# %%
# NUMBER_NODES = 9
NUMBER_NODES = 7
# NUMBER_NODES = 5
DATASET_PATH = f'../../../datasets/examples/opt_band_{NUMBER_NODES}_nodes_graph.csv'

def load_data():
    featuresNumber = (NUMBER_NODES * NUMBER_NODES - NUMBER_NODES) // 2 

    def get_tuple_dataset(row):
        X = row[0 : featuresNumber].astype('float32')
        Y = row[featuresNumber: ].astype('float32') # opt_band is in target
        return X, Y

    df = pd.read_csv(DATASET_PATH)
    train_dataset_df = df.sample(frac=0.8)
    df_remaining = df.drop(index=train_dataset_df.index)
    val_dataset_df = df_remaining.sample(frac=0.7)
    test_dataset_df = df_remaining.drop(index=val_dataset_df.index)

    train_dataset = list(map(get_tuple_dataset, train_dataset_df.to_numpy()))
    val_dataset = list(map(get_tuple_dataset, val_dataset_df.to_numpy()))
    test_dataset = list(map(get_tuple_dataset, test_dataset_df.to_numpy()))
    return train_dataset, val_dataset, test_dataset

# %%
train_dataset, val_dataset, test_dataset = load_data()

# %%
def getGraph(upperTriangleAdjMatrix):
    dense_adj = np.zeros((NUMBER_NODES, NUMBER_NODES))
    dense_adj = np.zeros((NUMBER_NODES, NUMBER_NODES))
    k = 0
    for i in range(NUMBER_NODES):
        for j in range(NUMBER_NODES):
            if i == j:
                continue
            elif i < j:
                dense_adj[i][j] = upperTriangleAdjMatrix[k]
                k += 1
            else:
                dense_adj[i][j] = dense_adj[j][i]
    return dense_adj

# %%
def processDataToImage(graphInput):
    graph_adj = getGraph(graphInput)
    plt.imshow(graph_adj, cmap="gray")
    plt.xticks([])
    plt.yticks([])
    plt.savefig(f'./Graph_adj_input_mse2.png')
    plt.clf()
    image_input = tf.keras.preprocessing.image.load_img(f'./Graph_adj_input_mse2.png')
    image_input_arr = tf.keras.preprocessing.image.img_to_array(image_input)
    image_input_np = np.array(image_input_arr)
    image_input_np = image_input_np / 255.0

    image_input_np = tf.image.resize(image_input_np, [256, 256])
    return image_input_np

# %%
def getData(dataset):
    train_images = []
    train_nodelist = []
    train_bandwidth = []
    for graphInput, target in dataset:
        optband = target[0]
        graphNodeList = target[1 : ]
        x_image = processDataToImage(graphInput)
        train_images.append(x_image)
        train_nodelist.append(graphNodeList)
        train_bandwidth.append([optband])
    return np.array(train_images), (np.array(train_nodelist) / 10), np.array(train_bandwidth)

# %%
def getData_2(dataset):
    train_images = []
    train_nodelist = []
    for graphInput, target in dataset:
        graphNodeList = target[1 : ]
        x_image = processDataToImage(graphInput)
        train_images.append(x_image)
        train_nodelist.append(graphNodeList)
    # mlb = MultiLabelBinarizer()
    # labels = mlb.fit_transform(train_nodelist)
    return np.array(train_images), np.array(train_nodelist) / 10

# %%
# train_images, train_nodelist, train_bandwidth = getData(train_dataset)
# val_images, val_nodelist, val_bandwidth = getData(val_dataset)
# test_images, test_nodelist, test_bandwidth = getData(test_dataset)
# print(train_images.shape)
# print(train_nodelist.shape)
# print(train_bandwidth.shape)

# %%
train_images, train_nodelist = getData_2(train_dataset)
val_images, val_nodelist= getData_2(val_dataset)
test_images, test_nodelist = getData_2(test_dataset)

# aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
# 	height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
# 	horizontal_flip=True, fill_mode="nearest")

print(train_images.shape)
print(train_nodelist.shape)
# Out:
# (835, 256, 256, 3)
# (835, 7)

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.RandomFlip("horizontal", input_shape=(256, 256, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

model = tf.keras.models.Sequential([
  # data_augmentation,
  # layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(NUMBER_NODES)
])

model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy'])

history = model.fit(
    train_images, train_nodelist,
    validation_data=(val_images, val_nodelist),
    epochs=128,
)
# Out:
# Epoch 1/128
# 27/27 [==============================] - 117s 4s/step - loss: 3.3071 - accuracy: 0.0275 - val_loss: 0.1066 - val_accuracy: 0.0068
# Epoch 2/128
# 27/27 [==============================] - 117s 4s/step - loss: 0.0863 - accuracy: 0.0036 - val_loss: 0.0661 - val_accuracy: 0.0068
# Epoch 3/128
# 27/27 [==============================] - 109s 4s/step - loss: 0.0486 - accuracy: 0.0623 - val_loss: 0.0382 - val_accuracy: 0.2534
# Epoch 4/128
# 27/27 [==============================] - 114s 4s/step - loss: 0.0357 - accuracy: 0.3078 - val_loss: 0.0349 - val_accuracy: 0.3356
# Epoch 5/128
# 27/27 [==============================] - 107s 4s/step - loss: 0.0345 - accuracy: 0.3485 - val_loss: 0.0356 - val_accuracy: 0.3562
# Epoch 6/128
# 27/27 [==============================] - 108s 4s/step - loss: 0.0342 - accuracy: 0.3677 - val_loss: 0.0345 - val_accuracy: 0.3562
# Epoch 7/128
# 27/27 [==============================] - 77s 3s/step - loss: 0.0335 - accuracy: 0.3593 - val_loss: 0.0345 - val_accuracy: 0.3288
# Epoch 8/128
# 27/27 [==============================] - 75s 3s/step - loss: 0.0332 - accuracy: 0.3868 - val_loss: 0.0340 - val_accuracy: 0.3493
# Epoch 9/128
# 27/27 [==============================] - 75s 3s/step - loss: 0.0331 - accuracy: 0.3856 - val_loss: 0.0341 - val_accuracy: 0.3493
# Epoch 10/128
# 27/27 [==============================] - 77s 3s/step - loss: 0.0329 - accuracy: 0.4012 - val_loss: 0.0342 - val_accuracy: 0.3973
# Epoch 11/128
# 27/27 [==============================] - 76s 3s/step - loss: 0.0330 - accuracy: 0.3641 - val_loss: 0.0354 - val_accuracy: 0.2945
# Epoch 12/128
# 27/27 [==============================] - 77s 3s/step - loss: 0.0337 - accuracy: 0.3509 - val_loss: 0.0342 - val_accuracy: 0.3082
# Epoch 13/128
# 27/27 [==============================] - 77s 3s/step - loss: 0.0328 - accuracy: 0.3713 - val_loss: 0.0339 - val_accuracy: 0.3288
# Epoch 14/128
# 27/27 [==============================] - 76s 3s/step - loss: 0.0327 - accuracy: 0.4024 - val_loss: 0.0343 - val_accuracy: 0.3562
# Epoch 15/128
# 27/27 [==============================] - 77s 3s/step - loss: 0.0328 - accuracy: 0.3533 - val_loss: 0.0343 - val_accuracy: 0.3288
# Epoch 16/128
# 27/27 [==============================] - 76s 3s/step - loss: 0.0324 - accuracy: 0.3868 - val_loss: 0.0342 - val_accuracy: 0.3904
# Epoch 17/128
# 27/27 [==============================] - 77s 3s/step - loss: 0.0325 - accuracy: 0.4084 - val_loss: 0.0336 - val_accuracy: 0.4041
# Epoch 18/128
# 27/27 [==============================] - 76s 3s/step - loss: 0.0326 - accuracy: 0.3713 - val_loss: 0.0338 - val_accuracy: 0.3493
# Epoch 19/128
# 27/27 [==============================] - 92s 3s/step - loss: 0.0323 - accuracy: 0.4000 - val_loss: 0.0336 - val_accuracy: 0.3767
# Epoch 20/128
# 27/27 [==============================] - 104s 4s/step - loss: 0.0321 - accuracy: 0.4048 - val_loss: 0.0343 - val_accuracy: 0.3562
# Epoch 21/128
# 27/27 [==============================] - 106s 4s/step - loss: 0.0325 - accuracy: 0.3629 - val_loss: 0.0337 - val_accuracy: 0.3288
# Epoch 22/128
# 27/27 [==============================] - 106s 4s/step - loss: 0.0321 - accuracy: 0.3880 - val_loss: 0.0340 - val_accuracy: 0.3356
# Epoch 23/128
# 27/27 [==============================] - 105s 4s/step - loss: 0.0323 - accuracy: 0.3844 - val_loss: 0.0334 - val_accuracy: 0.3836
# Epoch 24/128
# 27/27 [==============================] - 103s 4s/step - loss: 0.0322 - accuracy: 0.4287 - val_loss: 0.0335 - val_accuracy: 0.3904
# Epoch 25/128
# 27/27 [==============================] - 105s 4s/step - loss: 0.0322 - accuracy: 0.4084 - val_loss: 0.0340 - val_accuracy: 0.3699
# Epoch 26/128
# 27/27 [==============================] - 104s 4s/step - loss: 0.0322 - accuracy: 0.4144 - val_loss: 0.0338 - val_accuracy: 0.3904
# Epoch 27/128
# 27/27 [==============================] - 104s 4s/step - loss: 0.0320 - accuracy: 0.4000 - val_loss: 0.0333 - val_accuracy: 0.3767
# Epoch 28/128
# 27/27 [==============================] - 105s 4s/step - loss: 0.0323 - accuracy: 0.3892 - val_loss: 0.0340 - val_accuracy: 0.3836
# Epoch 29/128
# 27/27 [==============================] - 102s 4s/step - loss: 0.0318 - accuracy: 0.4216 - val_loss: 0.0337 - val_accuracy: 0.3904
# Epoch 30/128
# 27/27 [==============================] - 105s 4s/step - loss: 0.0316 - accuracy: 0.4120 - val_loss: 0.0335 - val_accuracy: 0.3973
# Epoch 31/128
# 27/27 [==============================] - 110s 4s/step - loss: 0.0317 - accuracy: 0.4347 - val_loss: 0.0339 - val_accuracy: 0.3836
# Epoch 32/128
# 27/27 [==============================] - 107s 4s/step - loss: 0.0321 - accuracy: 0.4084 - val_loss: 0.0338 - val_accuracy: 0.3493
# Epoch 33/128
# 27/27 [==============================] - 108s 4s/step - loss: 0.0317 - accuracy: 0.4072 - val_loss: 0.0336 - val_accuracy: 0.4041
# Epoch 34/128
# 27/27 [==============================] - 103s 4s/step - loss: 0.0316 - accuracy: 0.3976 - val_loss: 0.0341 - val_accuracy: 0.3630
# Epoch 35/128
# 27/27 [==============================] - 103s 4s/step - loss: 0.0315 - accuracy: 0.4287 - val_loss: 0.0333 - val_accuracy: 0.3973
# Epoch 36/128
# 27/27 [==============================] - 102s 4s/step - loss: 0.0316 - accuracy: 0.4240 - val_loss: 0.0336 - val_accuracy: 0.3630
# Epoch 37/128
# 27/27 [==============================] - 101s 4s/step - loss: 0.0318 - accuracy: 0.4012 - val_loss: 0.0335 - val_accuracy: 0.3767
# Epoch 38/128
# 27/27 [==============================] - 100s 4s/step - loss: 0.0319 - accuracy: 0.4407 - val_loss: 0.0339 - val_accuracy: 0.3904
# Epoch 39/128
# 27/27 [==============================] - 101s 4s/step - loss: 0.0313 - accuracy: 0.4168 - val_loss: 0.0344 - val_accuracy: 0.3836
# Epoch 40/128
# 27/27 [==============================] - 99s 4s/step - loss: 0.0319 - accuracy: 0.4395 - val_loss: 0.0336 - val_accuracy: 0.4110
# Epoch 41/128
# 27/27 [==============================] - 103s 4s/step - loss: 0.0314 - accuracy: 0.4419 - val_loss: 0.0334 - val_accuracy: 0.4247
# Epoch 42/128
# 27/27 [==============================] - 104s 4s/step - loss: 0.0312 - accuracy: 0.4156 - val_loss: 0.0339 - val_accuracy: 0.3904
# Epoch 43/128
# 27/27 [==============================] - 100s 4s/step - loss: 0.0317 - accuracy: 0.4287 - val_loss: 0.0336 - val_accuracy: 0.4247
# Epoch 44/128
# 27/27 [==============================] - 101s 4s/step - loss: 0.0318 - accuracy: 0.4323 - val_loss: 0.0339 - val_accuracy: 0.3904
# Epoch 45/128
# 27/27 [==============================] - 106s 4s/step - loss: 0.0315 - accuracy: 0.4180 - val_loss: 0.0335 - val_accuracy: 0.4178
# Epoch 46/128
# 27/27 [==============================] - 107s 4s/step - loss: 0.0314 - accuracy: 0.4515 - val_loss: 0.0340 - val_accuracy: 0.3904
# Epoch 47/128
# 27/27 [==============================] - 106s 4s/step - loss: 0.0313 - accuracy: 0.4563 - val_loss: 0.0338 - val_accuracy: 0.4384
# Epoch 48/128
# 27/27 [==============================] - 104s 4s/step - loss: 0.0310 - accuracy: 0.4287 - val_loss: 0.0340 - val_accuracy: 0.4178
# Epoch 49/128
# 27/27 [==============================] - 105s 4s/step - loss: 0.0312 - accuracy: 0.4275 - val_loss: 0.0342 - val_accuracy: 0.3973
# Epoch 50/128
# 27/27 [==============================] - 104s 4s/step - loss: 0.0311 - accuracy: 0.4347 - val_loss: 0.0334 - val_accuracy: 0.4384
# Epoch 51/128
# 27/27 [==============================] - 92s 3s/step - loss: 0.0311 - accuracy: 0.4419 - val_loss: 0.0339 - val_accuracy: 0.3973
# Epoch 52/128
# 27/27 [==============================] - 78s 3s/step - loss: 0.0312 - accuracy: 0.4371 - val_loss: 0.0337 - val_accuracy: 0.4315
# Epoch 53/128
# 27/27 [==============================] - 79s 3s/step - loss: 0.0308 - accuracy: 0.4204 - val_loss: 0.0334 - val_accuracy: 0.4315
# Epoch 54/128
# 27/27 [==============================] - 75s 3s/step - loss: 0.0309 - accuracy: 0.4311 - val_loss: 0.0338 - val_accuracy: 0.4110
# Epoch 55/128
# 27/27 [==============================] - 72s 3s/step - loss: 0.0310 - accuracy: 0.4419 - val_loss: 0.0341 - val_accuracy: 0.3767
# Epoch 56/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0310 - accuracy: 0.4204 - val_loss: 0.0334 - val_accuracy: 0.4315
# Epoch 57/128
# 27/27 [==============================] - 72s 3s/step - loss: 0.0309 - accuracy: 0.4443 - val_loss: 0.0335 - val_accuracy: 0.4452
# Epoch 58/128
# 27/27 [==============================] - 72s 3s/step - loss: 0.0307 - accuracy: 0.4599 - val_loss: 0.0346 - val_accuracy: 0.3767
# Epoch 59/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0310 - accuracy: 0.4431 - val_loss: 0.0339 - val_accuracy: 0.4452
# Epoch 60/128
# 27/27 [==============================] - 72s 3s/step - loss: 0.0309 - accuracy: 0.4395 - val_loss: 0.0337 - val_accuracy: 0.4110
# Epoch 61/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0307 - accuracy: 0.4731 - val_loss: 0.0338 - val_accuracy: 0.4110
# Epoch 62/128
# 27/27 [==============================] - 72s 3s/step - loss: 0.0307 - accuracy: 0.4599 - val_loss: 0.0341 - val_accuracy: 0.4110
# Epoch 63/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0307 - accuracy: 0.4551 - val_loss: 0.0338 - val_accuracy: 0.4110
# Epoch 64/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0305 - accuracy: 0.4587 - val_loss: 0.0336 - val_accuracy: 0.4384
# Epoch 65/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0303 - accuracy: 0.4551 - val_loss: 0.0339 - val_accuracy: 0.4178
# Epoch 66/128
# 27/27 [==============================] - 71s 3s/step - loss: 0.0306 - accuracy: 0.4335 - val_loss: 0.0337 - val_accuracy: 0.4247
# Epoch 67/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0307 - accuracy: 0.4635 - val_loss: 0.0335 - val_accuracy: 0.4384
# Epoch 68/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0304 - accuracy: 0.4479 - val_loss: 0.0335 - val_accuracy: 0.4452
# Epoch 69/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0305 - accuracy: 0.4551 - val_loss: 0.0336 - val_accuracy: 0.4247
# Epoch 70/128
# 27/27 [==============================] - 71s 3s/step - loss: 0.0306 - accuracy: 0.4790 - val_loss: 0.0334 - val_accuracy: 0.4315
# Epoch 71/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0306 - accuracy: 0.4695 - val_loss: 0.0335 - val_accuracy: 0.4315
# Epoch 72/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0305 - accuracy: 0.4527 - val_loss: 0.0335 - val_accuracy: 0.4315
# Epoch 73/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0304 - accuracy: 0.4790 - val_loss: 0.0337 - val_accuracy: 0.4110
# Epoch 74/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0306 - accuracy: 0.4743 - val_loss: 0.0337 - val_accuracy: 0.4041
# Epoch 75/128
# 27/27 [==============================] - 68s 3s/step - loss: 0.0305 - accuracy: 0.4671 - val_loss: 0.0337 - val_accuracy: 0.4452
# Epoch 76/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0304 - accuracy: 0.4563 - val_loss: 0.0333 - val_accuracy: 0.4315
# Epoch 77/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0303 - accuracy: 0.4635 - val_loss: 0.0336 - val_accuracy: 0.4315
# Epoch 78/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0304 - accuracy: 0.4659 - val_loss: 0.0333 - val_accuracy: 0.4315
# Epoch 79/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0305 - accuracy: 0.4563 - val_loss: 0.0337 - val_accuracy: 0.4110
# Epoch 80/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0306 - accuracy: 0.4695 - val_loss: 0.0334 - val_accuracy: 0.4110
# Epoch 81/128
# 27/27 [==============================] - 72s 3s/step - loss: 0.0302 - accuracy: 0.4623 - val_loss: 0.0338 - val_accuracy: 0.4247
# Epoch 82/128
# 27/27 [==============================] - 78s 3s/step - loss: 0.0301 - accuracy: 0.4611 - val_loss: 0.0337 - val_accuracy: 0.4384
# Epoch 83/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0301 - accuracy: 0.4778 - val_loss: 0.0339 - val_accuracy: 0.4452
# Epoch 84/128
# 27/27 [==============================] - 71s 3s/step - loss: 0.0301 - accuracy: 0.4778 - val_loss: 0.0336 - val_accuracy: 0.4315
# Epoch 85/128
# 27/27 [==============================] - 71s 3s/step - loss: 0.0304 - accuracy: 0.4731 - val_loss: 0.0333 - val_accuracy: 0.4315
# Epoch 86/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0304 - accuracy: 0.4707 - val_loss: 0.0337 - val_accuracy: 0.4178
# Epoch 87/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0302 - accuracy: 0.4743 - val_loss: 0.0335 - val_accuracy: 0.4452
# Epoch 88/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0302 - accuracy: 0.4683 - val_loss: 0.0338 - val_accuracy: 0.4521
# Epoch 89/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0306 - accuracy: 0.4790 - val_loss: 0.0337 - val_accuracy: 0.4452
# Epoch 90/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0301 - accuracy: 0.4671 - val_loss: 0.0335 - val_accuracy: 0.4384
# Epoch 91/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0300 - accuracy: 0.4635 - val_loss: 0.0333 - val_accuracy: 0.4315
# Epoch 92/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0303 - accuracy: 0.4766 - val_loss: 0.0337 - val_accuracy: 0.3973
# Epoch 93/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0301 - accuracy: 0.4671 - val_loss: 0.0335 - val_accuracy: 0.4110
# Epoch 94/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0301 - accuracy: 0.4970 - val_loss: 0.0333 - val_accuracy: 0.4315
# Epoch 95/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0301 - accuracy: 0.4635 - val_loss: 0.0336 - val_accuracy: 0.4110
# Epoch 96/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0302 - accuracy: 0.4695 - val_loss: 0.0332 - val_accuracy: 0.4452
# Epoch 97/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0301 - accuracy: 0.4743 - val_loss: 0.0332 - val_accuracy: 0.4315
# Epoch 98/128
# 27/27 [==============================] - 71s 3s/step - loss: 0.0297 - accuracy: 0.4754 - val_loss: 0.0333 - val_accuracy: 0.4247
# Epoch 99/128
# 27/27 [==============================] - 72s 3s/step - loss: 0.0299 - accuracy: 0.4826 - val_loss: 0.0332 - val_accuracy: 0.4384
# Epoch 100/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0298 - accuracy: 0.4898 - val_loss: 0.0332 - val_accuracy: 0.4384
# Epoch 101/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0300 - accuracy: 0.4731 - val_loss: 0.0333 - val_accuracy: 0.4315
# Epoch 102/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0300 - accuracy: 0.4814 - val_loss: 0.0333 - val_accuracy: 0.4521
# Epoch 103/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0299 - accuracy: 0.4778 - val_loss: 0.0332 - val_accuracy: 0.4247
# Epoch 104/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0298 - accuracy: 0.4910 - val_loss: 0.0332 - val_accuracy: 0.4452
# Epoch 105/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0301 - accuracy: 0.4707 - val_loss: 0.0334 - val_accuracy: 0.4247
# Epoch 106/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0302 - accuracy: 0.4659 - val_loss: 0.0337 - val_accuracy: 0.3904
# Epoch 107/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0300 - accuracy: 0.4743 - val_loss: 0.0333 - val_accuracy: 0.4315
# Epoch 108/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0299 - accuracy: 0.4695 - val_loss: 0.0333 - val_accuracy: 0.4384
# Epoch 109/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0300 - accuracy: 0.4814 - val_loss: 0.0331 - val_accuracy: 0.4384
# Epoch 110/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0299 - accuracy: 0.4707 - val_loss: 0.0332 - val_accuracy: 0.4452
# Epoch 111/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0299 - accuracy: 0.4766 - val_loss: 0.0333 - val_accuracy: 0.4384
# Epoch 112/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0299 - accuracy: 0.4838 - val_loss: 0.0337 - val_accuracy: 0.4315
# Epoch 113/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0299 - accuracy: 0.4814 - val_loss: 0.0334 - val_accuracy: 0.4452
# Epoch 114/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0299 - accuracy: 0.4707 - val_loss: 0.0337 - val_accuracy: 0.4315
# Epoch 115/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0299 - accuracy: 0.4874 - val_loss: 0.0332 - val_accuracy: 0.4452
# Epoch 116/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0298 - accuracy: 0.4719 - val_loss: 0.0333 - val_accuracy: 0.4315
# Epoch 117/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0297 - accuracy: 0.4790 - val_loss: 0.0334 - val_accuracy: 0.4384
# Epoch 118/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0297 - accuracy: 0.4934 - val_loss: 0.0335 - val_accuracy: 0.4384
# Epoch 119/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0296 - accuracy: 0.4922 - val_loss: 0.0333 - val_accuracy: 0.4247
# Epoch 120/128
# 27/27 [==============================] - 70s 3s/step - loss: 0.0299 - accuracy: 0.4898 - val_loss: 0.0334 - val_accuracy: 0.4247
# Epoch 121/128
# 27/27 [==============================] - 69s 3s/step - loss: 0.0298 - accuracy: 0.4743 - val_loss: 0.0332 - val_accuracy: 0.4247
# Epoch 122/128
# 27/27 [==============================] - 54s 2s/step - loss: 0.0297 - accuracy: 0.4778 - val_loss: 0.0333 - val_accuracy: 0.4384
# Epoch 123/128
# 27/27 [==============================] - 39s 1s/step - loss: 0.0297 - accuracy: 0.4838 - val_loss: 0.0333 - val_accuracy: 0.4315
# Epoch 124/128
# 27/27 [==============================] - 39s 1s/step - loss: 0.0300 - accuracy: 0.4731 - val_loss: 0.0334 - val_accuracy: 0.4384
# Epoch 125/128
# 27/27 [==============================] - 39s 1s/step - loss: 0.0297 - accuracy: 0.4982 - val_loss: 0.0330 - val_accuracy: 0.4247
# Epoch 126/128
# 27/27 [==============================] - 39s 1s/step - loss: 0.0298 - accuracy: 0.4743 - val_loss: 0.0331 - val_accuracy: 0.4315
# Epoch 127/128
# 27/27 [==============================] - 40s 1s/step - loss: 0.0297 - accuracy: 0.4790 - val_loss: 0.0329 - val_accuracy: 0.4384
# Epoch 128/128
# 27/27 [==============================] - 39s 1s/step - loss: 0.0297 - accuracy: 0.4838 - val_loss: 0.0330 - val_accuracy: 0.4384

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

# %%
# test = np.array([test_images[0]])
pred = model.predict(test_images)
true = test_nodelist
# print(pred)
print("Pred")
print((pred * 10).round())
print("True")
print(true * 10)
# Out:
# Pred
# [[2. 5. 3. 1. 3. 3. 3.]
#  [2. 5. 4. 1. 3. 4. 3.]
#  [3. 5. 3. 2. 3. 2. 3.]
#  [2. 4. 5. 2. 4. 2. 3.]
#  [2. 2. 3. 6. 4. 2. 3.]
#  [2. 3. 3. 4. 3. 2. 3.]
#  [2. 3. 4. 3. 4. 2. 3.]
#  [2. 3. 4. 5. 4. 2. 3.]
#  [2. 3. 3. 4. 3. 2. 3.]
#  [2. 3. 3. 5. 3. 2. 3.]
#  [2. 2. 4. 4. 4. 2. 2.]
#  [2. 3. 3. 4. 3. 2. 3.]
#  [2. 3. 4. 4. 3. 2. 3.]
#  [2. 2. 4. 5. 4. 2. 2.]
#  [2. 2. 4. 4. 4. 2. 2.]
#  [2. 2. 3. 4. 4. 2. 2.]
#  [2. 2. 4. 4. 4. 2. 2.]
#  [2. 1. 5. 5. 4. 2. 2.]
#  [2. 3. 3. 4. 3. 3. 3.]
#  [2. 3. 3. 5. 3. 2. 3.]
#  [2. 3. 3. 5. 3. 2. 3.]
#  [2. 3. 4. 4. 4. 2. 2.]
#  [2. 4. 4. 3. 3. 2. 3.]
#  [2. 2. 5. 4. 4. 2. 2.]
#  [2. 1. 4. 6. 4. 2. 2.]
#  [2. 2. 5. 2. 4. 2. 2.]
#  [2. 1. 5. 4. 4. 2. 2.]
#  [2. 2. 4. 4. 4. 2. 2.]
#  [2. 3. 4. 1. 3. 3. 3.]
#  [2. 4. 5. 2. 3. 3. 3.]
#  [2. 3. 4. 4. 4. 2. 2.]
#  [2. 3. 3. 4. 3. 2. 3.]
#  [3. 3. 3. 5. 3. 2. 3.]
#  [2. 2. 4. 5. 4. 2. 2.]
#  [2. 3. 4. 4. 3. 3. 3.]
#  [2. 3. 4. 4. 4. 2. 3.]
#  [2. 2. 4. 5. 4. 2. 2.]
#  [2. 2. 4. 4. 4. 2. 2.]
#  [2. 4. 4. 2. 3. 2. 3.]
#  [2. 3. 4. 4. 4. 2. 3.]
#  [2. 3. 4. 2. 3. 3. 3.]
#  [2. 1. 2. 6. 3. 3. 2.]
#  [2. 2. 4. 5. 4. 2. 3.]
#  [2. 2. 4. 4. 4. 4. 2.]
#  [2. 1. 4. 5. 4. 2. 2.]
#  [2. 0. 5. 5. 4. 2. 2.]
#  [2. 3. 3. 2. 2. 5. 3.]
#  [2. 2. 4. 4. 4. 3. 3.]
#  [2. 1. 4. 6. 4. 2. 2.]
#  [2. 1. 4. 6. 4. 2. 2.]
#  [2. 2. 4. 4. 3. 3. 3.]
#  [2. 1. 4. 5. 4. 2. 2.]
#  [2. 1. 4. 5. 4. 2. 2.]
#  [3. 3. 3. 5. 3. 2. 3.]
#  [3. 3. 3. 4. 3. 3. 3.]
#  [2. 2. 5. 3. 4. 2. 2.]
#  [2. 2. 4. 4. 4. 2. 2.]
#  [2. 2. 3. 6. 4. 2. 3.]
#  [2. 2. 6. 3. 5. 3. 2.]
#  [2. 4. 3. 3. 3. 3. 3.]
#  [2. 1. 4. 5. 4. 2. 2.]
#  [2. 1. 4. 4. 4. 2. 2.]
#  [2. 0. 5. 4. 4. 2. 1.]]
# True
# [[1. 0. 6. 4. 5. 3. 2.]
#  [1. 6. 0. 2. 5. 3. 4.]
#  [1. 5. 6. 0. 2. 4. 3.]
#  [1. 5. 6. 0. 3. 2. 4.]
#  [1. 0. 5. 4. 6. 2. 3.]
#  [3. 1. 6. 5. 0. 2. 4.]
#  [2. 0. 4. 6. 5. 1. 3.]
#  [2. 4. 6. 0. 5. 1. 3.]
#  [1. 5. 6. 2. 3. 0. 4.]
#  [1. 5. 6. 2. 3. 0. 4.]
#  [3. 0. 6. 4. 5. 2. 1.]
#  [3. 1. 2. 6. 5. 0. 4.]
#  [3. 0. 4. 6. 5. 1. 2.]
#  [2. 5. 1. 6. 0. 4. 3.]
#  [3. 1. 5. 6. 2. 0. 4.]
#  [4. 0. 5. 2. 1. 3. 6.]
#  [4. 0. 5. 6. 1. 2. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [4. 0. 5. 1. 6. 3. 2.]
#  [3. 1. 6. 4. 2. 0. 5.]
#  [4. 1. 0. 6. 2. 5. 3.]
#  [4. 6. 1. 0. 2. 5. 3.]
#  [1. 4. 6. 0. 2. 5. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [4. 0. 1. 6. 5. 2. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [2. 0. 4. 6. 5. 1. 3.]
#  [1. 4. 2. 5. 0. 6. 3.]
#  [1. 4. 6. 5. 0. 2. 3.]
#  [3. 5. 6. 0. 1. 2. 4.]
#  [5. 2. 1. 4. 6. 0. 3.]
#  [5. 2. 3. 1. 6. 0. 4.]
#  [0. 3. 4. 5. 6. 1. 2.]
#  [4. 6. 1. 0. 3. 5. 2.]
#  [2. 1. 5. 6. 4. 0. 3.]
#  [5. 1. 0. 4. 6. 3. 2.]
#  [1. 4. 5. 6. 0. 2. 3.]
#  [4. 2. 5. 1. 6. 0. 3.]
#  [5. 2. 1. 4. 6. 0. 3.]
#  [0. 3. 5. 6. 2. 1. 4.]
#  [2. 4. 1. 5. 6. 0. 3.]
#  [0. 3. 2. 6. 5. 4. 1.]
#  [1. 4. 2. 6. 5. 3. 0.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [2. 5. 1. 0. 4. 6. 3.]
#  [1. 6. 2. 4. 5. 0. 3.]
#  [1. 4. 0. 6. 3. 5. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 3. 5. 6. 0. 2. 4.]
#  [1. 3. 5. 6. 0. 4. 2.]
#  [0. 3. 5. 4. 6. 1. 2.]
#  [6. 2. 3. 4. 5. 1. 0.]
#  [1. 3. 5. 4. 6. 0. 2.]
#  [2. 0. 5. 6. 4. 3. 1.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 1. 5. 6. 4. 0. 2.]
#  [1. 3. 6. 4. 5. 0. 2.]
#  [0. 6. 3. 5. 2. 1. 4.]
#  [3. 2. 5. 0. 6. 4. 1.]
#  [3. 2. 5. 6. 0. 4. 1.]
#  [1. 0. 6. 4. 5. 3. 2.]]
