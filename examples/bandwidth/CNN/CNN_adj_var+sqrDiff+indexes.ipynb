# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
import networkx as nx
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image

# %%
# NUMBER_NODES = 9
NUMBER_NODES = 7
# NUMBER_NODES = 5
DATASET_PATH = f'../../../datasets/examples/opt_band_{NUMBER_NODES}_nodes_graph.csv'

def load_data():
    featuresNumber = (NUMBER_NODES * NUMBER_NODES - NUMBER_NODES) // 2 

    def get_tuple_dataset(row):
        X = row[0 : featuresNumber].astype('float32')
        Y = row[featuresNumber: ].astype('float32') # opt_band is in target
        return X, Y

    df = pd.read_csv(DATASET_PATH)
    train_dataset_df = df.sample(frac=0.8)
    df_remaining = df.drop(index=train_dataset_df.index)
    val_dataset_df = df_remaining.sample(frac=0.7)
    test_dataset_df = df_remaining.drop(index=val_dataset_df.index)

    train_dataset = list(map(get_tuple_dataset, train_dataset_df.to_numpy()))
    val_dataset = list(map(get_tuple_dataset, val_dataset_df.to_numpy()))
    test_dataset = list(map(get_tuple_dataset, test_dataset_df.to_numpy()))
    return train_dataset, val_dataset, test_dataset

# %%
train_dataset, val_dataset, test_dataset = load_data()

# %%
def getGraph(upperTriangleAdjMatrix):
    dense_adj = np.zeros((NUMBER_NODES, NUMBER_NODES))
    k = 0
    for i in range(NUMBER_NODES):
        for j in range(NUMBER_NODES):
            if i == j:
                continue
            elif i < j:
                dense_adj[i][j] = upperTriangleAdjMatrix[k]
                k += 1
            else:
                dense_adj[i][j] = dense_adj[j][i]
    return dense_adj

# %%
def processDataToImage(graphInput):
    adj = getGraph(graphInput)
    w, h = NUMBER_NODES, NUMBER_NODES
    data = np.zeros((h, w), dtype=np.uint8)
    for i in range(len(adj)):
        for j in range(len(adj)):
            if adj[i, j] == 1:
                data[i, j] = 255.0
    img = Image.fromarray(data, 'L')
    resized = img.resize((32, 32), Image.NEAREST)
    image = np.array(resized, dtype=np.float32)
    image = np.reshape(image, (32, 32, 1))
    image = (image / 127.5) - 1
    return image

# %%
def getData(dataset):
    train_images = []
    train_nodelist = []
    train_bandwidth = []
    for graphInput, target in dataset:
        optband = target[0]
        graphNodeList = target[1 : ]
        x_image = processDataToImage(graphInput)
        train_images.append(x_image)
        train_nodelist.append(graphNodeList)
        train_bandwidth.append([optband])
    return np.array(train_images), (np.array(train_nodelist) / 10), np.array(train_bandwidth)

# %%
def getData_2(dataset):
    train_images = []
    train_nodelist = []
    for graphInput, target in dataset:
        graphNodeList = target[1 : ]
        x_image = processDataToImage(graphInput)
        train_images.append(x_image)
        train_nodelist.append(graphNodeList)
    # mlb = MultiLabelBinarizer()
    # labels = mlb.fit_transform(train_nodelist)
    return np.array(train_images), np.array(train_nodelist) / 10

# %%
# train_images, train_nodelist, train_bandwidth = getData(train_dataset)
# val_images, val_nodelist, val_bandwidth = getData(val_dataset)
# test_images, test_nodelist, test_bandwidth = getData(test_dataset)
# print(train_images.shape)
# print(train_nodelist.shape)
# print(train_bandwidth.shape)

# %%
train_images, train_nodelist = getData_2(train_dataset)
val_images, val_nodelist= getData_2(val_dataset)
test_images, test_nodelist = getData_2(test_dataset)

# aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
# 	height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
# 	horizontal_flip=True, fill_mode="nearest")

print(train_images.shape)
print(train_nodelist.shape)
# Out:
# (835, 32, 32, 1)
# (835, 7)

# %%
maeLoss = tf.keras.losses.MeanAbsoluteError()
loss_object = tf.keras.losses.MeanSquaredError()

def loss_repeated_labels(roundedOutput, roundedTrue):
  true_used, true_indexes = tf.unique(tf.squeeze(roundedTrue))
  used_labels, indexes, counts = tf.unique_with_counts(tf.squeeze(roundedOutput))
  counts = tf.cast(counts, tf.float32)
  # 1 - counts = quao longe os elementos de counts estão de repetir uma vez só (elemento unico)
  squaredDiff = loss_object(tf.ones_like(counts), counts)
  mseIndexes = loss_object(tf.cast(true_indexes, tf.float32), tf.cast(indexes, tf.float32))
  # o quao longe os indexes estao de ser 0,1,2,3,4,5,6
  loss = tf.math.reduce_variance(counts) + squaredDiff + mseIndexes
  return loss

def customLoss(true, pred):
  mae = maeLoss(true, pred)
  roundedOutput = tf.round(pred)
  roundedTrue = tf.round(true)
  loss_repeated = loss_repeated_labels(roundedOutput, roundedTrue)
  return mae + loss_repeated

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.RandomFlip("horizontal", input_shape=(32, 32, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

model = tf.keras.models.Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.3),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(NUMBER_NODES, activation='sigmoid')
])

model.compile(optimizer='adam',
              lo
180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.7717 - accuracy: 0.8527 - val_loss: 18.8779 - val_accuracy: 0.4110
# Epoch 100/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.7053 - accuracy: 0.8347 - val_loss: 21.1768 - val_accuracy: 0.4247
# Epoch 101/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.5701 - accuracy: 0.8611 - val_loss: 18.1334 - val_accuracy: 0.4110
# Epoch 102/180
# 835/835 [==============================] - 5s 6ms/step - loss: 15.9886 - accuracy: 0.8575 - val_loss: 19.5623 - val_accuracy: 0.4452 3s - loss: 15.6115 - ac - ETA: 2s - loss: 15. - ETA: 1s - loss: 1
# Epoch 103/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.4561 - accuracy: 0.8216 - val_loss: 19.2064 - val_accuracy: 0.472616.4763 - accuracy:
# Epoch 104/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.5001 - accuracy: 0.8407 - val_loss: 19.3538 - val_accuracy: 0.4315
# Epoch 105/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.5096 - accuracy: 0.8731 - val_loss: 19.2447 - val_accuracy: 0.4589
# Epoch 106/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.5260 - accuracy: 0.8503 - val_loss: 20.1468 - val_accuracy: 0.4658
# Epoch 107/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.5922 - accuracy: 0.8407 - val_loss: 19.4486 - val_accuracy: 0.4452
# Epoch 108/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.5483 - accuracy: 0.8503 - val_loss: 20.2235 - val_accuracy: 0.5548
# Epoch 109/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.9672 - accuracy: 0.8623 - val_loss: 20.3298 - val_accuracy: 0.4658
# Epoch 110/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.3457 - accuracy: 0.8611 - val_loss: 20.5537 - val_accuracy: 0.4384
# Epoch 111/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.4074 - accuracy: 0.8683 - val_loss: 19.9960 - val_accuracy: 0.4521
# Epoch 112/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.4892 - accuracy: 0.8575 - val_loss: 19.7972 - val_accuracy: 0.4384
# Epoch 113/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1992 - accuracy: 0.8395 - val_loss: 20.5219 - val_accuracy: 0.4452
# Epoch 114/180
# 835/835 [==============================] - 5s 7ms/step - loss: 16.7062 - accuracy: 0.8539 - val_loss: 19.6502 - val_accuracy: 0.4658
# Epoch 115/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.7709 - accuracy: 0.8659 - val_loss: 20.3879 - val_accuracy: 0.4589
# Epoch 116/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.4838 - accuracy: 0.8503 - val_loss: 20.1207 - val_accuracy: 0.4932
# Epoch 117/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0603 - accuracy: 0.8575 - val_loss: 20.0481 - val_accuracy: 0.4863
# Epoch 118/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.8085 - accuracy: 0.8515 - val_loss: 20.0037 - val_accuracy: 0.4932
# Epoch 119/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.1770 - accuracy: 0.8599 - val_loss: 20.5440 - val_accuracy: 0.4863
# Epoch 120/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.4402 - accuracy: 0.8719 - val_loss: 19.4552 - val_accuracy: 0.4384
# Epoch 121/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.5847 - accuracy: 0.8743 - val_loss: 19.4625 - val_accuracy: 0.4521
# Epoch 122/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1617 - accuracy: 0.8719 - val_loss: 19.7528 - val_accuracy: 0.4521
# Epoch 123/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.3906 - accuracy: 0.8623 - val_loss: 20.1777 - val_accuracy: 0.4521
# Epoch 124/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.2433 - accuracy: 0.8419 - val_loss: 18.1113 - val_accuracy: 0.4726
# Epoch 125/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.3478 - accuracy: 0.8599 - val_loss: 20.2258 - val_accuracy: 0.4589
# Epoch 126/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.4762 - accuracy: 0.8503 - val_loss: 19.8890 - val_accuracy: 0.4658
# Epoch 127/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.2367 - accuracy: 0.8743 - val_loss: 19.4949 - val_accuracy: 0.4863
# Epoch 128/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.2770 - accuracy: 0.8671 - val_loss: 18.5940 - val_accuracy: 0.4589
# Epoch 129/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.3711 - accuracy: 0.8527 - val_loss: 19.6702 - val_accuracy: 0.4247
# Epoch 130/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.0930 - accuracy: 0.8731 - val_loss: 19.4236 - val_accuracy: 0.4589A: 1s - loss: 16.
# Epoch 131/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.2444 - accuracy: 0.8635 - val_loss: 19.3902 - val_accuracy: 0.5000
# Epoch 132/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.4880 - accuracy: 0.8695 - val_loss: 18.9077 - val_accuracy: 0.4247accuracy: 0.
# Epoch 133/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.2304 - accuracy: 0.8575 - val_loss: 19.1635 - val_accuracy: 0.4726
# Epoch 134/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.1100 - accuracy: 0.8814 - val_loss: 19.5932 - val_accuracy: 0.5205
# Epoch 135/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1186 - accuracy: 0.8778 - val_loss: 19.0574 - val_accuracy: 0.5000
# Epoch 136/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.4195 - accuracy: 0.8754 - val_loss: 20.1974 - val_accuracy: 0.4932
# Epoch 137/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.2163 - accuracy: 0.8886 - val_loss: 19.5143 - val_accuracy: 0.4795
# Epoch 138/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1137 - accuracy: 0.8659 - val_loss: 18.6001 - val_accuracy: 0.4932
# Epoch 139/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.5706 - accuracy: 0.8766 - val_loss: 20.3201 - val_accuracy: 0.4589
# Epoch 140/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1156 - accuracy: 0.8862 - val_loss: 19.6514 - val_accuracy: 0.4452
# Epoch 141/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.3883 - accuracy: 0.8850 - val_loss: 19.7619 - val_accuracy: 0.4589
# Epoch 142/180
# 835/835 [==============================] - 5s 7ms/step - loss: 16.3308 - accuracy: 0.8743 - val_loss: 20.3535 - val_accuracy: 0.4795s: 16.4635 - - ETA: 1s - loss: 16.3360 - accuracy: 0.87 - ETA: 1s - loss: 16
# Epoch 143/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.6116 - accuracy: 0.8671 - val_loss: 19.8009 - val_accuracy: 0.4452
# Epoch 144/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.2486 - accuracy: 0.8659 - val_loss: 19.2732 - val_accuracy: 0.4452
# Epoch 145/180
# 835/835 [==============================] - 5s 7ms/step - loss: 16.1498 - accuracy: 0.8683 - val_loss: 19.9567 - val_accuracy: 0.4589
# Epoch 146/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.3414 - accuracy: 0.8778 - val_loss: 20.1134 - val_accuracy: 0.4521
# Epoch 147/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.2205 - accuracy: 0.8419 - val_loss: 18.9825 - val_accuracy: 0.4589
# Epoch 148/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0780 - accuracy: 0.8539 - val_loss: 19.2822 - val_accuracy: 0.4863
# Epoch 149/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.3850 - accuracy: 0.8647 - val_loss: 19.7319 - val_accuracy: 0.4658
# Epoch 150/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.2855 - accuracy: 0.8647 - val_loss: 20.0618 - val_accuracy: 0.4589
# Epoch 151/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1868 - accuracy: 0.8886 - val_loss: 18.6871 - val_accuracy: 0.4589
# Epoch 152/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.3753 - accuracy: 0.8683 - val_loss: 19.3125 - val_accuracy: 0.4384
# Epoch 153/180
# 835/835 [==============================] - 6s 7ms/step - loss: 15.9273 - accuracy: 0.8563 - val_loss: 20.2756 - val_accuracy: 0.4658
# Epoch 154/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.2557 - accuracy: 0.8874 - val_loss: 19.0722 - val_accuracy: 0.5137
# Epoch 155/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.5755 - accuracy: 0.8850 - val_loss: 18.7771 - val_accuracy: 0.5205
# Epoch 156/180
# 835/835 [==============================] - 5s 7ms/step - loss: 16.2610 - accuracy: 0.8826 - val_loss: 19.3541 - val_accuracy: 0.4795
# Epoch 157/180
# 835/835 [==============================] - 5s 7ms/step - loss: 16.5689 - accuracy: 0.8802 - val_loss: 20.5718 - val_accuracy: 0.4521549 - accuracy - ETA: 0s - loss: 16.4946 - accuracy: 0.88
# Epoch 158/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1562 - accuracy: 0.8790 - val_loss: 18.5271 - val_accuracy: 0.4795
# Epoch 159/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.2221 - accuracy: 0.8874 - val_loss: 19.4328 - val_accuracy: 0.4863
# Epoch 160/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0703 - accuracy: 0.8790 - val_loss: 19.9675 - val_accuracy: 0.4521
# Epoch 161/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.2961 - accuracy: 0.8731 - val_loss: 19.8114 - val_accuracy: 0.445216.3
# Epoch 162/180
# 835/835 [==============================] - 5s 6ms/step - loss: 15.9919 - accuracy: 0.8970 - val_loss: 19.8539 - val_accuracy: 0.4589
# Epoch 163/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0844 - accuracy: 0.8743 - val_loss: 19.7290 - val_accuracy: 0.4589
# Epoch 164/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1635 - accuracy: 0.8838 - val_loss: 18.3338 - val_accuracy: 0.4589
# Epoch 165/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0592 - accuracy: 0.8826 - val_loss: 19.4495 - val_accuracy: 0.4521
# Epoch 166/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0995 - accuracy: 0.8802 - val_loss: 20.5548 - val_accuracy: 0.4932
# Epoch 167/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.1398 - accuracy: 0.8707 - val_loss: 19.7849 - val_accuracy: 0.4521
# Epoch 168/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.3552 - accuracy: 0.8970 - val_loss: 20.2078 - val_accuracy: 0.5068
# Epoch 169/180
# 835/835 [==============================] - 5s 6ms/step - loss: 15.8473 - accuracy: 0.8719 - val_loss: 19.3284 - val_accuracy: 0.4521
# Epoch 170/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1256 - accuracy: 0.8778 - val_loss: 19.7779 - val_accuracy: 0.4247
# Epoch 171/180
# 835/835 [==============================] - 5s 7ms/step - loss: 16.1699 - accuracy: 0.8898 - val_loss: 18.4287 - val_accuracy: 0.4658
# Epoch 172/180
# 835/835 [==============================] - 5s 6ms/step - loss: 15.9554 - accuracy: 0.8862 - val_loss: 19.5118 - val_accuracy: 0.4247 - ETA: 0s - loss: 15.9736 - accurac - ETA: 0s - loss: 15.9155 - accuracy:
# Epoch 173/180
# 835/835 [==============================] - 6s 7ms/step - loss: 16.1727 - accuracy: 0.8898 - val_loss: 19.2934 - val_accuracy: 0.4589
# Epoch 174/180
# 835/835 [==============================] - 5s 7ms/step - loss: 16.3764 - accuracy: 0.8719 - val_loss: 19.3309 - val_accuracy: 0.4521 0s - loss: 16.3288 -
# Epoch 175/180
# 835/835 [==============================] - 6s 7ms/step - loss: 15.9882 - accuracy: 0.8922 - val_loss: 19.2409 - val_accuracy: 0.5000
# Epoch 176/180
# 835/835 [==============================] - 5s 6ms/step - loss: 15.9306 - accuracy: 0.8982 - val_loss: 18.9219 - val_accuracy: 0.4521
# Epoch 177/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.4184 - accuracy: 0.8874 - val_loss: 19.9077 - val_accuracy: 0.4658
# Epoch 178/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1849 - accuracy: 0.8814 - val_loss: 20.7063 - val_accuracy: 0.4315
# Epoch 179/180
# 835/835 [==============================] - 5s 6ms/step - loss: 15.9972 - accuracy: 0.8814 - val_loss: 19.3198 - val_accuracy: 0.4863
# Epoch 180/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0206 - accuracy: 0.8886 - val_loss: 20.2115 - val_accuracy: 0.4589

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

# %%
# test = np.array([test_images[0]])
pred = model.predict(test_images)
true = test_nodelist
# print(pred)
print("Pred")
print((pred * 10).round())
print("True")
print(true*10)
# Out:
# Pred
# [[1. 5. 3. 4. 4. 3. 3.]
#  [2. 0. 5. 6. 4. 0. 3.]
#  [2. 4. 5. 4. 4. 2. 3.]
#  [1. 5. 3. 1. 4. 3. 3.]
#  [3. 4. 2. 1. 2. 3. 3.]
#  [1. 4. 6. 0. 4. 2. 3.]
#  [2. 0. 5. 6. 5. 0. 4.]
#  [1. 4. 6. 1. 1. 4. 3.]
#  [2. 3. 5. 0. 5. 2. 3.]
#  [3. 2. 4. 4. 0. 2. 4.]
#  [2. 2. 6. 3. 3. 2. 3.]
#  [2. 2. 5. 5. 3. 3. 3.]
#  [3. 4. 4. 5. 1. 2. 3.]
#  [2. 3. 5. 4. 5. 2. 3.]
#  [2. 3. 5. 0. 4. 2. 3.]
#  [1. 3. 3. 6. 5. 2. 3.]
#  [1. 4. 5. 1. 3. 4. 3.]
#  [2. 4. 2. 3. 5. 2. 3.]
#  [1. 4. 5. 5. 5. 2. 3.]
#  [1. 0. 6. 5. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 1. 5. 6. 4. 2. 2.]
#  [2. 0. 5. 5. 5. 3. 2.]
#  [2. 1. 4. 6. 5. 0. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [4. 1. 5. 5. 1. 0. 5.]
#  [2. 3. 3. 0. 6. 3. 4.]
#  [1. 5. 3. 4. 1. 5. 2.]
#  [2. 4. 5. 1. 1. 4. 3.]
#  [2. 4. 5. 6. 0. 2. 3.]
#  [1. 4. 5. 5. 4. 3. 2.]
#  [2. 4. 3. 1. 5. 0. 3.]
#  [4. 3. 1. 5. 5. 0. 3.]
#  [4. 2. 1. 4. 5. 1. 4.]
#  [3. 2. 4. 6. 3. 1. 3.]
#  [4. 4. 3. 0. 5. 2. 2.]
#  [1. 3. 5. 5. 6. 0. 3.]
#  [2. 1. 5. 6. 5. 1. 2.]
#  [2. 4. 5. 6. 5. 1. 3.]
#  [3. 3. 3. 2. 6. 0. 4.]
#  [6. 2. 1. 4. 6. 1. 2.]
#  [3. 0. 2. 6. 4. 3. 2.]
#  [3. 1. 4. 6. 5. 3. 2.]
#  [1. 4. 4. 3. 4. 3. 2.]
#  [2. 4. 6. 5. 5. 3. 2.]
#  [1. 0. 6. 5. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 3. 5. 0. 5. 3. 3.]
#  [1. 3. 6. 5. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [2. 2. 6. 6. 0. 2. 5.]
#  [1. 2. 5. 6. 0. 2. 4.]
#  [1. 3. 5. 5. 0. 3. 2.]
#  [2. 3. 5. 5. 0. 3. 2.]
#  [2. 3. 4. 5. 5. 2. 2.]
#  [2. 3. 5. 6. 5. 3. 1.]
#  [2. 4. 4. 6. 3. 2. 1.]
#  [3. 3. 4. 5. 1. 2. 4.]
#  [0. 4. 3. 3. 3. 2. 2.]
#  [3. 2. 5. 5. 4. 0. 3.]
#  [1. 3. 3. 6. 4. 4. 1.]
#  [2. 1. 5. 4. 4. 3. 2.]
#  [2. 3. 5. 6. 0. 4. 2.]]
# True
# [[1. 6. 0. 2. 5. 3. 4.]
#  [3. 4. 2. 6. 1. 5. 0.]
#  [0. 6. 5. 1. 2. 4. 3.]
#  [1. 5. 6. 0. 2. 4. 3.]
#  [1. 5. 6. 0. 2. 4. 3.]
#  [1. 5. 6. 0. 3. 2. 4.]
#  [2. 0. 4. 6. 5. 1. 3.]
#  [1. 5. 6. 0. 2. 4. 3.]
#  [2. 0. 4. 6. 5. 1. 3.]
#  [1. 5. 6. 2. 3. 0. 4.]
#  [1. 6. 5. 3. 2. 4. 0.]
#  [2. 1. 0. 6. 5. 4. 3.]
#  [2. 5. 6. 1. 0. 4. 3.]
#  [2. 4. 6. 0. 5. 1. 3.]
#  [1. 6. 4. 2. 0. 5. 3.]
#  [3. 5. 2. 6. 0. 1. 4.]
#  [1. 4. 6. 0. 2. 5. 3.]
#  [5. 4. 1. 0. 6. 2. 3.]
#  [3. 1. 2. 6. 4. 5. 0.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 1. 5. 6. 4. 0. 2.]
#  [2. 0. 4. 5. 6. 1. 3.]
#  [2. 0. 4. 6. 5. 1. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [4. 1. 0. 6. 3. 2. 5.]
#  [1. 4. 3. 0. 6. 5. 2.]
#  [1. 4. 6. 3. 0. 5. 2.]
#  [1. 4. 6. 2. 0. 5. 3.]
#  [3. 0. 5. 6. 4. 2. 1.]
#  [3. 5. 0. 6. 1. 2. 4.]
#  [1. 4. 6. 2. 5. 3. 0.]
#  [2. 5. 6. 1. 0. 4. 3.]
#  [3. 5. 0. 6. 1. 4. 2.]
#  [2. 1. 5. 6. 4. 0. 3.]
#  [1. 4. 5. 6. 0. 3. 2.]
#  [2. 1. 5. 6. 4. 0. 3.]
#  [1. 5. 4. 6. 0. 2. 3.]
#  [2. 3. 6. 5. 0. 1. 4.]
#  [4. 2. 5. 1. 6. 0. 3.]
#  [1. 4. 5. 6. 2. 0. 3.]
#  [3. 5. 6. 0. 1. 2. 4.]
#  [3. 0. 1. 6. 5. 4. 2.]
#  [2. 5. 4. 1. 6. 0. 3.]
#  [2. 4. 1. 5. 6. 0. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [2. 5. 6. 1. 0. 4. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [4. 0. 2. 3. 6. 5. 1.]
#  [1. 3. 5. 6. 0. 2. 4.]
#  [1. 3. 6. 5. 0. 4. 2.]
#  [1. 3. 5. 6. 0. 4. 2.]
#  [2. 1. 4. 5. 3. 6. 0.]
#  [0. 2. 6. 4. 3. 5. 1.]
#  [4. 2. 0. 6. 5. 3. 1.]
#  [4. 0. 2. 5. 6. 1. 3.]
#  [1. 3. 6. 2. 4. 0. 5.]
#  [3. 1. 5. 6. 4. 0. 2.]
#  [1. 6. 3. 0. 4. 2. 5.]
#  [1. 5. 4. 6. 3. 0. 2.]
#  [3. 2. 5. 0. 6. 4. 1.]]

# %%
# test = np.array([test_images[0]])
pred = model.predict(train_images[:10])
true = train_nodelist[:10]
# print(pred)
print("Pred")
print((pred* 10).round())
print("True")
print(true*10)
# Out:
# Pred
# [[1. 0. 6. 4. 5. 3. 2.]
#  [3. 5. 1. 0. 5. 4. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [5. 1. 5. 4. 3. 5. 1.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 5. 6. 0. 1. 2. 3.]
#  [3. 5. 4. 0. 1. 4. 1.]
#  [3. 0. 2. 6. 5. 5. 2.]
#  [1. 4. 0. 6. 5. 3. 3.]
#  [1. 5. 3. 4. 6. 2. 1.]]
# True
# [[1. 0. 6. 4. 5. 3. 2.]
#  [3. 6. 1. 0. 5. 4. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [6. 1. 4. 2. 3. 5. 0.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 5. 6. 0. 1. 2. 4.]
#  [3. 6. 4. 0. 2. 5. 1.]
#  [3. 0. 1. 6. 5. 4. 2.]
#  [0. 4. 1. 6. 5. 2. 3.]
#  [1. 5. 3. 4. 6. 2. 0.]]
