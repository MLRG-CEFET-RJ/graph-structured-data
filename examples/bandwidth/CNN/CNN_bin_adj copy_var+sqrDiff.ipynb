# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
import networkx as nx
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import MultiLabelBinarizer
from tensorflow.python.ops import gen_array_ops

# %%
# NUMBER_NODES = 9
NUMBER_NODES = 7
# NUMBER_NODES = 5
DATASET_PATH = f'../../../datasets/examples/opt_band_{NUMBER_NODES}_nodes_graph.csv'

def load_data():
    featuresNumber = (NUMBER_NODES * NUMBER_NODES - NUMBER_NODES) // 2 

    def get_tuple_dataset(row):
        X = row[0 : featuresNumber].astype('float32')
        Y = row[featuresNumber: ].astype('float32') # opt_band is in target
        return X, Y

    df = pd.read_csv(DATASET_PATH)
    train_dataset_df = df.sample(frac=0.8)
    df_remaining = df.drop(index=train_dataset_df.index)
    val_dataset_df = df_remaining.sample(frac=0.7)
    test_dataset_df = df_remaining.drop(index=val_dataset_df.index)

    train_dataset = list(map(get_tuple_dataset, train_dataset_df.to_numpy()))
    val_dataset = list(map(get_tuple_dataset, val_dataset_df.to_numpy()))
    test_dataset = list(map(get_tuple_dataset, test_dataset_df.to_numpy()))
    return train_dataset, val_dataset, test_dataset

# %%
train_dataset, val_dataset, test_dataset = load_data()

# %%
def getGraph(upperTriangleAdjMatrix):
    dense_adj = np.zeros((NUMBER_NODES, NUMBER_NODES))
    dense_adj = np.zeros((NUMBER_NODES, NUMBER_NODES))
    k = 0
    for i in range(NUMBER_NODES):
        for j in range(NUMBER_NODES):
            if i == j:
                continue
            elif i < j:
                dense_adj[i][j] = upperTriangleAdjMatrix[k]
                k += 1
            else:
                dense_adj[i][j] = dense_adj[j][i]
    return dense_adj

# %%
def processDataToImage(graphInput):
    graph_adj = getGraph(graphInput)
    plt.imshow(graph_adj, cmap="gray")
    plt.xticks([])
    plt.yticks([])
    plt.savefig(f'./Graph_adj_input_mse.png')
    plt.clf()
    image_input = tf.keras.preprocessing.image.load_img(f'./Graph_adj_input_mse.png')
    image_input_arr = tf.keras.preprocessing.image.img_to_array(image_input)
    image_input_np = np.array(image_input_arr)
    # image_input_np = image_input_np / 255.0

    image_input_np = tf.image.resize(image_input_np, [32, 32])
    return image_input_np

# %%
def getData(dataset):
    train_images = []
    train_nodelist = []
    train_bandwidth = []
    for graphInput, target in dataset:
        optband = target[0]
        graphNodeList = target[1 : ]
        x_image = processDataToImage(graphInput)
        train_images.append(x_image)
        train_nodelist.append(graphNodeList)
        train_bandwidth.append([optband])
    return np.array(train_images), (np.array(train_nodelist) / 10), np.array(train_bandwidth)

# %%
def getData_2(dataset):
    train_images = []
    train_nodelist = []
    for graphInput, target in dataset:
        graphNodeList = target[1 : ]
        x_image = processDataToImage(graphInput)
        train_images.append(x_image)
        train_nodelist.append(graphNodeList)
    # mlb = MultiLabelBinarizer()
    # labels = mlb.fit_transform(train_nodelist)
    return np.array(train_images), np.array(train_nodelist) / 10

# %%
# train_images, train_nodelist, train_bandwidth = getData(train_dataset)
# val_images, val_nodelist, val_bandwidth = getData(val_dataset)
# test_images, test_nodelist, test_bandwidth = getData(test_dataset)
# print(train_images.shape)
# print(train_nodelist.shape)
# print(train_bandwidth.shape)

# %%
train_images, train_nodelist = getData_2(train_dataset)
val_images, val_nodelist= getData_2(val_dataset)
test_images, test_nodelist = getData_2(test_dataset)

# aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
# 	height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
# 	horizontal_flip=True, fill_mode="nearest")

print(train_images.shape)
print(train_nodelist.shape)
# Out:
# (835, 32, 32, 3)
# (835, 7)

# %%
maeLoss = tf.keras.losses.MeanAbsoluteError()
loss_object = tf.keras.losses.MeanSquaredError()

def loss_repeated_labels(roundedOutput):
  used_labels, indexes, counts = tf.unique_with_counts(tf.squeeze(roundedOutput))
  counts = tf.cast(counts, tf.float32)
  # 1 - counts = quao longe os elementos de counts estão de repetir uma vez só (elemento unico)
  squaredDiff = loss_object(tf.ones_like(counts), counts)
  loss = tf.math.reduce_variance(counts) + squaredDiff
  return loss

def customLoss(true, pred):
  mae = maeLoss(true, pred)
  roundedOutput = tf.round(pred)
  loss_repeated = loss_repeated_labels(roundedOutput)
  return mae + loss_repeated

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.RandomFlip("horizontal", input_shape=(32, 32, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

model = tf.keras.models.Sequential([
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.3),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(NUMBER_NODES, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss=customLoss,
              metrics=['accuracy'])

history = model.fit(
    train_images, train_nodelist,
    validation_data=(val_images, val_nodelist),
    epochs=180,
    batch_size=1
)
# Out:
# Epoch 1/180
# 835/835 [==============================] - 6s 5ms/step - loss: 28.9709 - accuracy: 0.3090 - val_loss: 31.6681 - val_accuracy: 0.1781
# Epoch 2/180
# 835/835 [==============================] - 4s 5ms/step - loss: 29.8347 - accuracy: 0.3377 - val_loss: 31.5650 - val_accuracy: 0.3425
# Epoch 3/180
# 835/835 [==============================] - 4s 5ms/step - loss: 28.7051 - accuracy: 0.3760 - val_loss: 22.8457 - val_accuracy: 0.3836
# Epoch 4/180
# 835/835 [==============================] - 4s 5ms/step - loss: 27.7491 - accuracy: 0.4072 - val_loss: 33.3110 - val_accuracy: 0.3630
# Epoch 5/180
# 835/835 [==============================] - 4s 5ms/step - loss: 27.1696 - accuracy: 0.4647 - val_loss: 26.4824 - val_accuracy: 0.4521
# Epoch 6/180
# 835/835 [==============================] - 4s 5ms/step - loss: 26.1030 - accuracy: 0.4970 - val_loss: 25.7321 - val_accuracy: 0.5137
# Epoch 7/180
# 835/835 [==============================] - 4s 5ms/step - loss: 25.0713 - accuracy: 0.5054 - val_loss: 24.2893 - val_accuracy: 0.4863
# Epoch 8/180
# 835/835 [==============================] - 4s 5ms/step - loss: 24.1626 - accuracy: 0.5198 - val_loss: 23.8445 - val_accuracy: 0.4795
# Epoch 9/180
# 835/835 [==============================] - 4s 5ms/step - loss: 24.0783 - accuracy: 0.5246 - val_loss: 21.4331 - val_accuracy: 0.4932
# Epoch 10/180
# 835/835 [==============================] - 4s 4ms/step - loss: 23.1509 - accuracy: 0.5533 - val_loss: 21.2323 - val_accuracy: 0.4795
# Epoch 11/180
# 835/835 [==============================] - 4s 4ms/step - loss: 23.0611 - accuracy: 0.5485 - val_loss: 21.9942 - val_accuracy: 0.5274
# Epoch 12/180
# 835/835 [==============================] - 4s 4ms/step - loss: 22.4693 - accuracy: 0.5653 - val_loss: 20.8285 - val_accuracy: 0.4521
# Epoch 13/180
# 835/835 [==============================] - 4s 4ms/step - loss: 21.2743 - accuracy: 0.5808 - val_loss: 20.7222 - val_accuracy: 0.5137
# Epoch 14/180
# 835/835 [==============================] - 4s 4ms/step - loss: 21.5011 - accuracy: 0.5677 - val_loss: 23.0709 - val_accuracy: 0.5068
# Epoch 15/180
# 835/835 [==============================] - 4s 4ms/step - loss: 20.7643 - accuracy: 0.6311 - val_loss: 20.6724 - val_accuracy: 0.5274
# Epoch 16/180
# 835/835 [==============================] - 4s 4ms/step - loss: 20.9741 - accuracy: 0.6120 - val_loss: 19.9238 - val_accuracy: 0.4863
# Epoch 17/180
# 835/835 [==============================] - 4s 4ms/step - loss: 20.5500 - accuracy: 0.6012 - val_loss: 20.2198 - val_accuracy: 0.5068
# Epoch 18/180
# 835/835 [==============================] - 4s 4ms/step - loss: 20.0607 - accuracy: 0.6120 - val_loss: 19.9248 - val_accuracy: 0.5137
# Epoch 19/180
# 835/835 [==============================] - 4s 5ms/step - loss: 20.7483 - accuracy: 0.6156 - val_loss: 18.8271 - val_accuracy: 0.5137
# Epoch 20/180
# 835/835 [==============================] - 4s 5ms/step - loss: 19.9825 - accuracy: 0.6311 - val_loss: 21.4374 - val_accuracy: 0.4795
# Epoch 21/180
# 835/835 [==============================] - 4s 4ms/step - loss: 19.7226 - accuracy: 0.6407 - val_loss: 19.2687 - val_accuracy: 0.4795
# Epoch 22/180
# 835/835 [==============================] - 4s 4ms/step - loss: 19.2298 - accuracy: 0.6623 - val_loss: 20.6503 - val_accuracy: 0.5068
# Epoch 23/180
# 835/835 [==============================] - 4s 5ms/step - loss: 19.4307 - accuracy: 0.6743 - val_loss: 19.0415 - val_accuracy: 0.5342
# Epoch 24/180
# 835/835 [==============================] - 4s 4ms/step - loss: 18.4939 - accuracy: 0.6611 - val_loss: 19.6158 - val_accuracy: 0.4726
# Epoch 25/180
# 835/835 [==============================] - 4s 4ms/step - loss: 18.6974 - accuracy: 0.6707 - val_loss: 20.1697 - val_accuracy: 0.5205
# Epoch 26/180
# 835/835 [==============================] - 4s 5ms/step - loss: 18.7474 - accuracy: 0.6778 - val_loss: 19.9282 - val_accuracy: 0.5411
# Epoch 27/180
# 835/835 [==============================] - 4s 5ms/step - loss: 18.2165 - accuracy: 0.6970 - val_loss: 19.5512 - val_accuracy: 0.5548
# Epoch 28/180
# 835/835 [==============================] - 4s 4ms/step - loss: 18.6153 - accuracy: 0.7102 - val_loss: 20.5897 - val_accuracy: 0.5411
# Epoch 29/180
# 835/835 [==============================] - 4s 4ms/step - loss: 18.2191 - accuracy: 0.7018 - val_loss: 18.7939 - val_accuracy: 0.5000
# Epoch 30/180
# 835/835 [==============================] - 4s 4ms/step - loss: 18.4409 - accuracy: 0.7066 - val_loss: 19.3173 - val_accuracy: 0.4452
# Epoch 31/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.8881 - accuracy: 0.7078 - val_loss: 18.7059 - val_accuracy: 0.4932
# Epoch 32/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.8422 - accuracy: 0.7138 - val_loss: 17.8193 - val_accuracy: 0.5000
# Epoch 33/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.5886 - accuracy: 0.7138 - val_loss: 18.7495 - val_accuracy: 0.5205
# Epoch 34/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.6714 - accuracy: 0.7102 - val_loss: 18.6493 - val_accuracy: 0.5205
# Epoch 35/180
# 835/835 [==============================] - 4s 5ms/step - loss: 17.6606 - accuracy: 0.7497 - val_loss: 19.0063 - val_accuracy: 0.4658
# Epoch 36/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.6704 - accuracy: 0.7449 - val_loss: 17.8709 - val_accuracy: 0.5205
# Epoch 37/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.0202 - accuracy: 0.7401 - val_loss: 18.8763 - val_accuracy: 0.5548
# Epoch 38/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.2884 - accuracy: 0.7317 - val_loss: 20.1845 - val_accuracy: 0.4863
# Epoch 39/180
# 835/835 [==============================] - 4s 5ms/step - loss: 17.4221 - accuracy: 0.7102 - val_loss: 19.6748 - val_accuracy: 0.5137
# Epoch 40/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.2053 - accuracy: 0.7509 - val_loss: 19.4837 - val_accuracy: 0.5000
# Epoch 41/180
# 835/835 [==============================] - 4s 5ms/step - loss: 17.0634 - accuracy: 0.7401 - val_loss: 19.0994 - val_accuracy: 0.5205
# Epoch 42/180
# 835/835 [==============================] - 4s 5ms/step - loss: 17.1502 - accuracy: 0.7569 - val_loss: 19.1147 - val_accuracy: 0.5274
# Epoch 43/180
# 835/835 [==============================] - 4s 5ms/step - loss: 17.3915 - accuracy: 0.7677 - val_loss: 18.6531 - val_accuracy: 0.4795
# Epoch 44/180
# 835/835 [==============================] - 4s 5ms/step - loss: 17.0229 - accuracy: 0.7557 - val_loss: 17.2494 - val_accuracy: 0.4726
# Epoch 45/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.9338 - accuracy: 0.7760 - val_loss: 18.0354 - val_accuracy: 0.4795
# Epoch 46/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.1265 - accuracy: 0.7677 - val_loss: 17.7833 - val_accuracy: 0.5137
# Epoch 47/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.8799 - accuracy: 0.7569 - val_loss: 18.9843 - val_accuracy: 0.5205
# Epoch 48/180
# 835/835 [==============================] - 4s 4ms/step - loss: 17.0887 - accuracy: 0.7784 - val_loss: 18.9863 - val_accuracy: 0.5274
# Epoch 49/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.8388 - accuracy: 0.7653 - val_loss: 17.9881 - val_accuracy: 0.4795
# Epoch 50/180
# 835/835 [==============================] - 4s 5ms/step - loss: 17.0552 - accuracy: 0.7665 - val_loss: 19.1994 - val_accuracy: 0.5205
# Epoch 51/180
# 835/835 [==============================] - 4s 5ms/step - loss: 17.0948 - accuracy: 0.7784 - val_loss: 18.9688 - val_accuracy: 0.5068
# Epoch 52/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.8116 - accuracy: 0.7916 - val_loss: 18.7606 - val_accuracy: 0.5137
# Epoch 53/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.7837 - accuracy: 0.7760 - val_loss: 18.9213 - val_accuracy: 0.4932
# Epoch 54/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.7538 - accuracy: 0.7832 - val_loss: 17.2768 - val_accuracy: 0.5411
# Epoch 55/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.6224 - accuracy: 0.7928 - val_loss: 18.5265 - val_accuracy: 0.4863
# Epoch 56/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.5942 - accuracy: 0.8120 - val_loss: 18.6344 - val_accuracy: 0.5068
# Epoch 57/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.6640 - accuracy: 0.7868 - val_loss: 18.8899 - val_accuracy: 0.5274
# Epoch 58/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.6518 - accuracy: 0.7892 - val_loss: 18.9009 - val_accuracy: 0.5205
# Epoch 59/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.8502 - accuracy: 0.8108 - val_loss: 18.1675 - val_accuracy: 0.5342
# Epoch 60/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.2622 - accuracy: 0.7904 - val_loss: 18.5105 - val_accuracy: 0.4795
# Epoch 61/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.8594 - accuracy: 0.7940 - val_loss: 19.5790 - val_accuracy: 0.5137
# Epoch 62/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.5726 - accuracy: 0.8084 - val_loss: 18.7777 - val_accuracy: 0.5274
# Epoch 63/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.3666 - accuracy: 0.8084 - val_loss: 18.3064 - val_accuracy: 0.5000
# Epoch 64/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.7939 - accuracy: 0.8156 - val_loss: 18.2880 - val_accuracy: 0.5000
# Epoch 65/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.5065 - accuracy: 0.8323 - val_loss: 19.8556 - val_accuracy: 0.5274
# Epoch 66/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.3039 - accuracy: 0.8132 - val_loss: 18.3323 - val_accuracy: 0.5479
# Epoch 67/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.2587 - accuracy: 0.8024 - val_loss: 18.6444 - val_accuracy: 0.5274
# Epoch 68/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.4926 - accuracy: 0.8072 - val_loss: 17.9149 - val_accuracy: 0.4863
# Epoch 69/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.7694 - accuracy: 0.8072 - val_loss: 17.9212 - val_accuracy: 0.5205
# Epoch 70/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.5934 - accuracy: 0.8204 - val_loss: 18.0705 - val_accuracy: 0.5342
# Epoch 71/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.2376 - accuracy: 0.8263 - val_loss: 17.6171 - val_accuracy: 0.4932
# Epoch 72/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.4297 - accuracy: 0.8395 - val_loss: 17.0380 - val_accuracy: 0.5137
# Epoch 73/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.6441 - accuracy: 0.8251 - val_loss: 18.3598 - val_accuracy: 0.5068
# Epoch 74/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.3480 - accuracy: 0.8216 - val_loss: 17.1798 - val_accuracy: 0.5342
# Epoch 75/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.0770 - accuracy: 0.8192 - val_loss: 18.8078 - val_accuracy: 0.5205
# Epoch 76/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.3797 - accuracy: 0.8371 - val_loss: 17.1123 - val_accuracy: 0.5411
# Epoch 77/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.6227 - accuracy: 0.8084 - val_loss: 17.0780 - val_accuracy: 0.5205
# Epoch 78/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.3224 - accuracy: 0.8251 - val_loss: 18.5518 - val_accuracy: 0.5342
# Epoch 79/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.5702 - accuracy: 0.8467 - val_loss: 18.6118 - val_accuracy: 0.5068
# Epoch 80/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.3843 - accuracy: 0.8479 - val_loss: 16.6978 - val_accuracy: 0.4863
# Epoch 81/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.2342 - accuracy: 0.8443 - val_loss: 17.9627 - val_accuracy: 0.4863
# Epoch 82/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.1061 - accuracy: 0.8371 - val_loss: 18.3449 - val_accuracy: 0.5274
# Epoch 83/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.4686 - accuracy: 0.8503 - val_loss: 18.9011 - val_accuracy: 0.5068
# Epoch 84/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.3831 - accuracy: 0.8371 - val_loss: 19.4887 - val_accuracy: 0.5137
# Epoch 85/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.1851 - accuracy: 0.8431 - val_loss: 18.2441 - val_accuracy: 0.4932
# Epoch 86/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.1018 - accuracy: 0.8359 - val_loss: 18.3717 - val_accuracy: 0.4932
# Epoch 87/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.2575 - accuracy: 0.8491 - val_loss: 18.4757 - val_accuracy: 0.4932
# Epoch 88/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.6629 - accuracy: 0.8443 - val_loss: 18.5959 - val_accuracy: 0.5068
# Epoch 89/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.2860 - accuracy: 0.8419 - val_loss: 18.3353 - val_accuracy: 0.5000
# Epoch 90/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1266 - accuracy: 0.8467 - val_loss: 18.1033 - val_accuracy: 0.5274
# Epoch 91/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.1724 - accuracy: 0.8539 - val_loss: 18.1005 - val_accuracy: 0.4932
# Epoch 92/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.3062 - accuracy: 0.8431 - val_loss: 17.6861 - val_accuracy: 0.4863
# Epoch 93/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.2614 - accuracy: 0.8527 - val_loss: 17.1228 - val_accuracy: 0.5411
# Epoch 94/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0308 - accuracy: 0.8563 - val_loss: 17.7863 - val_accuracy: 0.5548
# Epoch 95/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1429 - accuracy: 0.8419 - val_loss: 16.8296 - val_accuracy: 0.5411
# Epoch 96/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.4968 - accuracy: 0.8719 - val_loss: 17.8920 - val_accuracy: 0.5205
# Epoch 97/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.2086 - accuracy: 0.8431 - val_loss: 18.0622 - val_accuracy: 0.5274
# Epoch 98/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1276 - accuracy: 0.8359 - val_loss: 19.1717 - val_accuracy: 0.5616
# Epoch 99/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.8591 - accuracy: 0.8635 - val_loss: 18.5674 - val_accuracy: 0.5411
# Epoch 100/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.5290 - accuracy: 0.8407 - val_loss: 17.6567 - val_accuracy: 0.5685
# Epoch 101/180
# 835/835 [==============================] - 5s 6ms/step - loss: 15.8849 - accuracy: 0.8587 - val_loss: 17.4790 - val_accuracy: 0.5685
# Epoch 102/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9659 - accuracy: 0.8731 - val_loss: 18.1688 - val_accuracy: 0.5342
# Epoch 103/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1940 - accuracy: 0.8551 - val_loss: 18.9053 - val_accuracy: 0.5137
# Epoch 104/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.2280 - accuracy: 0.8539 - val_loss: 18.1482 - val_accuracy: 0.5411
# Epoch 105/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0913 - accuracy: 0.8611 - val_loss: 17.7142 - val_accuracy: 0.5548
# Epoch 106/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.0970 - accuracy: 0.8766 - val_loss: 18.6449 - val_accuracy: 0.5548
# Epoch 107/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1236 - accuracy: 0.8814 - val_loss: 19.7250 - val_accuracy: 0.5479
# Epoch 108/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.4140 - accuracy: 0.8539 - val_loss: 18.0511 - val_accuracy: 0.5342
# Epoch 109/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1616 - accuracy: 0.8551 - val_loss: 16.6277 - val_accuracy: 0.5205: 0s - loss: 16.1525 - accuracy:
# Epoch 110/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.0925 - accuracy: 0.8790 - val_loss: 18.0179 - val_accuracy: 0.5616
# Epoch 111/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.2333 - accuracy: 0.8563 - val_loss: 19.4199 - val_accuracy: 0.5411
# Epoch 112/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1308 - accuracy: 0.8563 - val_loss: 18.0699 - val_accuracy: 0.5753
# Epoch 113/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.0765 - accuracy: 0.8635 - val_loss: 16.9496 - val_accuracy: 0.5616
# Epoch 114/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1286 - accuracy: 0.8563 - val_loss: 19.5106 - val_accuracy: 0.5205
# Epoch 115/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.2579 - accuracy: 0.8802 - val_loss: 18.1688 - val_accuracy: 0.5274
# Epoch 116/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.4265 - accuracy: 0.8683 - val_loss: 19.2639 - val_accuracy: 0.5616
# Epoch 117/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1091 - accuracy: 0.8491 - val_loss: 18.7106 - val_accuracy: 0.5342
# Epoch 118/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.2313 - accuracy: 0.8599 - val_loss: 18.7342 - val_accuracy: 0.5274
# Epoch 119/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.0702 - accuracy: 0.8778 - val_loss: 19.9009 - val_accuracy: 0.5205
# Epoch 120/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.7193 - accuracy: 0.8707 - val_loss: 19.4112 - val_accuracy: 0.5548
# Epoch 121/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1440 - accuracy: 0.8695 - val_loss: 18.5802 - val_accuracy: 0.5205
# Epoch 122/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.3334 - accuracy: 0.8814 - val_loss: 19.0912 - val_accuracy: 0.5411
# Epoch 123/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.2879 - accuracy: 0.8647 - val_loss: 18.7909 - val_accuracy: 0.5342
# Epoch 124/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1065 - accuracy: 0.8970 - val_loss: 17.5994 - val_accuracy: 0.4932
# Epoch 125/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9516 - accuracy: 0.8731 - val_loss: 18.4275 - val_accuracy: 0.4795
# Epoch 126/180
# 835/835 [==============================] - 5s 5ms/step - loss: 16.1631 - accuracy: 0.8719 - val_loss: 17.6618 - val_accuracy: 0.4658
# Epoch 127/180
# 835/835 [==============================] - 5s 6ms/step - loss: 15.9746 - accuracy: 0.8754 - val_loss: 18.1227 - val_accuracy: 0.5137
# Epoch 128/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0414 - accuracy: 0.8826 - val_loss: 17.0766 - val_accuracy: 0.5068
# Epoch 129/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0637 - accuracy: 0.8743 - val_loss: 18.2208 - val_accuracy: 0.5342
# Epoch 130/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0669 - accuracy: 0.8731 - val_loss: 18.5116 - val_accuracy: 0.5068
# Epoch 131/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.8569 - accuracy: 0.8754 - val_loss: 19.6382 - val_accuracy: 0.5342
# Epoch 132/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.0969 - accuracy: 0.9030 - val_loss: 18.9750 - val_accuracy: 0.5068
# Epoch 133/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.0880 - accuracy: 0.8814 - val_loss: 18.7297 - val_accuracy: 0.5000
# Epoch 134/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9848 - accuracy: 0.8719 - val_loss: 18.5934 - val_accuracy: 0.5274
# Epoch 135/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9166 - accuracy: 0.8958 - val_loss: 17.8584 - val_accuracy: 0.5342
# Epoch 136/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.0898 - accuracy: 0.8850 - val_loss: 18.2815 - val_accuracy: 0.5753
# Epoch 137/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.7329 - accuracy: 0.8647 - val_loss: 19.4740 - val_accuracy: 0.5205
# Epoch 138/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9369 - accuracy: 0.8958 - val_loss: 18.4879 - val_accuracy: 0.5548
# Epoch 139/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9932 - accuracy: 0.8754 - val_loss: 17.6257 - val_accuracy: 0.4932
# Epoch 140/180
# 835/835 [==============================] - 5s 6ms/step - loss: 16.1670 - accuracy: 0.8826 - val_loss: 19.1837 - val_accuracy: 0.5342
# Epoch 141/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9850 - accuracy: 0.8611 - val_loss: 18.0493 - val_accuracy: 0.5274
# Epoch 142/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.0712 - accuracy: 0.8599 - val_loss: 17.5830 - val_accuracy: 0.5205
# Epoch 143/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.3304 - accuracy: 0.8766 - val_loss: 17.1957 - val_accuracy: 0.5274
# Epoch 144/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.3920 - accuracy: 0.8695 - val_loss: 19.2556 - val_accuracy: 0.5342
# Epoch 145/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.0990 - accuracy: 0.8766 - val_loss: 17.6402 - val_accuracy: 0.5137
# Epoch 146/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.1209 - accuracy: 0.8802 - val_loss: 18.3698 - val_accuracy: 0.5342970 - accu
# Epoch 147/180
# 835/835 [==============================] - 4s 5ms/step - loss: 16.2890 - accuracy: 0.8922 - val_loss: 19.0896 - val_accuracy: 0.5411
# Epoch 148/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9135 - accuracy: 0.8671 - val_loss: 17.7039 - val_accuracy: 0.5205
# Epoch 149/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.7699 - accuracy: 0.8766 - val_loss: 18.8857 - val_accuracy: 0.5342
# Epoch 150/180
# 835/835 [==============================] - 3s 4ms/step - loss: 16.1552 - accuracy: 0.8754 - val_loss: 18.1129 - val_accuracy: 0.5137
# Epoch 151/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.8766 - accuracy: 0.8898 - val_loss: 18.1491 - val_accuracy: 0.5205
# Epoch 152/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.9801 - accuracy: 0.8707 - val_loss: 19.1019 - val_accuracy: 0.5000
# Epoch 153/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.9397 - accuracy: 0.8898 - val_loss: 19.3373 - val_accuracy: 0.4932
# Epoch 154/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.5609 - accuracy: 0.8994 - val_loss: 19.4559 - val_accuracy: 0.5137
# Epoch 155/180
# 835/835 [==============================] - 3s 4ms/step - loss: 16.0539 - accuracy: 0.8922 - val_loss: 18.4073 - val_accuracy: 0.5479
# Epoch 156/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9634 - accuracy: 0.8874 - val_loss: 18.1381 - val_accuracy: 0.5137
# Epoch 157/180
# 835/835 [==============================] - 5s 6ms/step - loss: 15.9379 - accuracy: 0.8886 - val_loss: 17.7495 - val_accuracy: 0.4932
# Epoch 158/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9254 - accuracy: 0.9030 - val_loss: 17.9570 - val_accuracy: 0.5205
# Epoch 159/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.2266 - accuracy: 0.8874 - val_loss: 18.3414 - val_accuracy: 0.5000
# Epoch 160/180
# 835/835 [==============================] - 3s 4ms/step - loss: 16.0952 - accuracy: 0.8910 - val_loss: 17.4694 - val_accuracy: 0.5137
# Epoch 161/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.8521 - accuracy: 0.8802 - val_loss: 17.7679 - val_accuracy: 0.5274
# Epoch 162/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.8578 - accuracy: 0.8766 - val_loss: 17.5374 - val_accuracy: 0.5274
# Epoch 163/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.8723 - accuracy: 0.8886 - val_loss: 18.7168 - val_accuracy: 0.5342
# Epoch 164/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.9771 - accuracy: 0.8838 - val_loss: 18.2564 - val_accuracy: 0.5342
# Epoch 165/180
# 835/835 [==============================] - 3s 4ms/step - loss: 16.1000 - accuracy: 0.9126 - val_loss: 18.7040 - val_accuracy: 0.5137
# Epoch 166/180
# 835/835 [==============================] - 3s 4ms/step - loss: 16.2584 - accuracy: 0.8850 - val_loss: 18.6822 - val_accuracy: 0.5205
# Epoch 167/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.8901 - accuracy: 0.8994 - val_loss: 17.8156 - val_accuracy: 0.5274
# Epoch 168/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.7508 - accuracy: 0.8731 - val_loss: 17.9839 - val_accuracy: 0.5274
# Epoch 169/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.0938 - accuracy: 0.8766 - val_loss: 19.3547 - val_accuracy: 0.5411
# Epoch 170/180
# 835/835 [==============================] - 4s 4ms/step - loss: 15.8681 - accuracy: 0.8754 - val_loss: 18.0876 - val_accuracy: 0.5068
# Epoch 171/180
# 835/835 [==============================] - 4s 4ms/step - loss: 15.8620 - accuracy: 0.8826 - val_loss: 18.1107 - val_accuracy: 0.5137
# Epoch 172/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.9594 - accuracy: 0.9114 - val_loss: 17.7776 - val_accuracy: 0.5548
# Epoch 173/180
# 835/835 [==============================] - 3s 4ms/step - loss: 16.1277 - accuracy: 0.8934 - val_loss: 19.7192 - val_accuracy: 0.5753
# Epoch 174/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.6772 - accuracy: 0.8874 - val_loss: 17.7395 - val_accuracy: 0.5616
# Epoch 175/180
# 835/835 [==============================] - 3s 4ms/step - loss: 15.7779 - accuracy: 0.8754 - val_loss: 18.6439 - val_accuracy: 0.5205
# Epoch 176/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.9771 - accuracy: 0.8814 - val_loss: 17.8970 - val_accuracy: 0.4932
# Epoch 177/180
# 835/835 [==============================] - 4s 4ms/step - loss: 15.6577 - accuracy: 0.9042 - val_loss: 18.0038 - val_accuracy: 0.5411
# Epoch 178/180
# 835/835 [==============================] - 4s 4ms/step - loss: 16.2268 - accuracy: 0.8946 - val_loss: 18.1229 - val_accuracy: 0.5274
# Epoch 179/180
# 835/835 [==============================] - 4s 5ms/step - loss: 15.5953 - accuracy: 0.8898 - val_loss: 19.2186 - val_accuracy: 0.5274
# Epoch 180/180
# 835/835 [==============================] - 4s 4ms/step - loss: 15.8301 - accuracy: 0.8886 - val_loss: 18.3877 - val_accuracy: 0.5205

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

# %%
# test = np.array([test_images[0]])
pred = model.predict(test_images)
true = test_nodelist
# print(pred)
print("Pred")
print((pred * 10).round())
print("True")
print(true*10)
# Out:
# Pred
# [[2. 5. 4. 5. 4. 4. 3.]
#  [2. 4. 5. 3. 5. 3. 3.]
#  [3. 5. 1. 1. 4. 4. 3.]
#  [3. 2. 4. 0. 5. 3. 4.]
#  [4. 1. 2. 6. 5. 3. 3.]
#  [2. 4. 6. 0. 5. 3. 2.]
#  [2. 4. 5. 2. 4. 3. 3.]
#  [4. 1. 2. 5. 5. 2. 3.]
#  [3. 2. 5. 6. 4. 3. 3.]
#  [2. 4. 5. 3. 0. 3. 3.]
#  [3. 1. 6. 5. 4. 3. 2.]
#  [3. 4. 3. 5. 0. 3. 3.]
#  [2. 3. 5. 6. 0. 1. 4.]
#  [4. 2. 3. 4. 5. 2. 2.]
#  [2. 1. 4. 6. 5. 2. 3.]
#  [1. 4. 1. 6. 5. 3. 3.]
#  [2. 1. 4. 6. 5. 1. 3.]
#  [2. 4. 6. 4. 2. 2. 4.]
#  [2. 4. 1. 5. 1. 4. 2.]
#  [2. 4. 6. 5. 3. 2. 3.]
#  [1. 4. 6. 4. 3. 3. 2.]
#  [1. 2. 3. 5. 4. 3. 2.]
#  [2. 4. 6. 4. 0. 4. 3.]
#  [4. 3. 4. 5. 5. 3. 3.]
#  [4. 2. 5. 6. 3. 3. 3.]
#  [2. 3. 4. 6. 5. 2. 3.]
#  [5. 1. 2. 6. 5. 0. 3.]
#  [4. 5. 2. 0. 3. 5. 2.]
#  [3. 1. 5. 6. 4. 2. 3.]
#  [2. 4. 4. 5. 3. 2. 3.]
#  [2. 4. 5. 5. 0. 3. 2.]
#  [2. 2. 5. 6. 4. 1. 3.]
#  [2. 3. 5. 6. 0. 2. 3.]
#  [1. 5. 2. 3. 5. 4. 1.]
#  [3. 0. 4. 6. 4. 3. 2.]
#  [1. 5. 6. 1. 0. 3. 4.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 3. 6. 5. 4. 1. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [2. 0. 6. 5. 5. 3. 2.]
#  [2. 3. 6. 5. 4. 1. 3.]
#  [2. 4. 3. 3. 4. 4. 3.]
#  [1. 3. 5. 5. 0. 4. 2.]
#  [0. 2. 5. 5. 4. 3. 2.]
#  [1. 3. 5. 5. 4. 4. 3.]
#  [3. 3. 3. 2. 6. 0. 3.]
#  [2. 3. 3. 6. 4. 3. 1.]
#  [3. 4. 6. 6. 0. 2. 4.]
#  [3. 4. 4. 6. 0. 2. 3.]
#  [1. 3. 6. 1. 5. 0. 4.]
#  [3. 2. 1. 6. 5. 2. 3.]
#  [3. 2. 5. 6. 0. 1. 3.]
#  [3. 2. 6. 3. 4. 3. 2.]
#  [4. 3. 6. 0. 4. 3. 3.]
#  [3. 1. 5. 6. 4. 0. 2.]
#  [1. 4. 5. 5. 4. 1. 3.]
#  [1. 2. 2. 5. 4. 3. 2.]
#  [3. 4. 3. 4. 5. 3. 2.]
#  [2. 0. 5. 5. 4. 3. 1.]
#  [2. 3. 5. 5. 4. 3. 1.]
#  [2. 0. 5. 5. 5. 4. 0.]]
# True
# [[0. 6. 5. 1. 2. 4. 3.]
#  [1. 6. 2. 5. 0. 3. 4.]
#  [4. 3. 0. 5. 2. 6. 1.]
#  [3. 1. 5. 0. 6. 2. 4.]
#  [2. 0. 4. 6. 5. 1. 3.]
#  [1. 5. 0. 6. 4. 2. 3.]
#  [1. 6. 5. 0. 2. 4. 3.]
#  [3. 1. 5. 6. 2. 0. 4.]
#  [5. 1. 2. 3. 6. 0. 4.]
#  [3. 2. 5. 6. 0. 1. 4.]
#  [2. 5. 3. 6. 0. 1. 4.]
#  [1. 4. 6. 5. 0. 2. 3.]
#  [2. 3. 5. 6. 0. 1. 4.]
#  [0. 4. 5. 6. 1. 2. 3.]
#  [3. 0. 4. 6. 5. 1. 2.]
#  [1. 2. 4. 6. 5. 0. 3.]
#  [5. 3. 0. 1. 6. 4. 2.]
#  [3. 0. 6. 5. 1. 2. 4.]
#  [0. 5. 6. 3. 1. 4. 2.]
#  [1. 4. 2. 5. 6. 0. 3.]
#  [2. 5. 3. 0. 6. 4. 1.]
#  [0. 3. 5. 6. 1. 4. 2.]
#  [5. 2. 1. 6. 4. 0. 3.]
#  [5. 2. 1. 4. 6. 0. 3.]
#  [5. 2. 1. 0. 6. 4. 3.]
#  [5. 2. 1. 6. 4. 3. 0.]
#  [3. 5. 0. 6. 1. 4. 2.]
#  [4. 6. 1. 0. 3. 5. 2.]
#  [3. 0. 5. 6. 4. 1. 2.]
#  [2. 1. 6. 4. 5. 0. 3.]
#  [1. 4. 5. 6. 0. 3. 2.]
#  [3. 2. 0. 6. 5. 4. 1.]
#  [3. 0. 2. 6. 5. 4. 1.]
#  [3. 0. 1. 5. 4. 6. 2.]
#  [0. 3. 5. 6. 4. 1. 2.]
#  [1. 5. 6. 2. 0. 4. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 0. 6. 5. 4. 1. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [2. 0. 4. 6. 5. 3. 1.]
#  [1. 5. 3. 6. 2. 0. 4.]
#  [1. 3. 6. 5. 0. 4. 2.]
#  [0. 1. 6. 3. 4. 5. 2.]
#  [0. 1. 4. 5. 3. 6. 2.]
#  [4. 1. 0. 6. 3. 5. 2.]
#  [2. 0. 4. 6. 5. 3. 1.]
#  [1. 5. 6. 3. 0. 2. 4.]
#  [1. 3. 5. 6. 4. 0. 2.]
#  [4. 2. 6. 0. 5. 1. 3.]
#  [4. 0. 2. 6. 5. 3. 1.]
#  [4. 2. 0. 5. 6. 1. 3.]
#  [1. 3. 6. 5. 4. 0. 2.]
#  [5. 3. 1. 0. 6. 4. 2.]
#  [3. 1. 5. 6. 4. 0. 2.]
#  [3. 1. 4. 6. 5. 0. 2.]
#  [1. 6. 3. 0. 4. 2. 5.]
#  [3. 1. 4. 0. 5. 6. 2.]
#  [2. 0. 5. 6. 4. 3. 1.]
#  [1. 6. 3. 2. 4. 0. 5.]
#  [1. 0. 6. 4. 5. 3. 2.]]

# %%
# test = np.array([test_images[0]])
pred = model.predict(train_images[:5])
true = train_nodelist[:5]
# print(pred)
print("Pred")
print((pred* 10).round())
print("True")
print(true*10)
# Out:
# Pred
# [[4. 6. 1. 0. 2. 5. 2.]
#  [2. 3. 5. 6. 1. 0. 4.]
#  [5. 2. 0. 2. 6. 4. 1.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 5. 0. 4. 6. 2. 4.]]
# True
# [[4. 6. 1. 0. 2. 5. 3.]
#  [2. 3. 5. 6. 1. 0. 4.]
#  [5. 2. 0. 3. 6. 4. 1.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 5. 0. 3. 6. 2. 4.]]
