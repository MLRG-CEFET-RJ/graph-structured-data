# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
import networkx as nx
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import MultiLabelBinarizer
from tensorflow.python.ops import gen_array_ops

# %%
# NUMBER_NODES = 9
NUMBER_NODES = 7
# NUMBER_NODES = 5
DATASET_PATH = f'../../../datasets/examples/opt_band_{NUMBER_NODES}_nodes_graph.csv'

def load_data():
    featuresNumber = (NUMBER_NODES * NUMBER_NODES - NUMBER_NODES) // 2 

    def get_tuple_dataset(row):
        X = row[0 : featuresNumber].astype('float32')
        Y = row[featuresNumber: ].astype('float32') # opt_band is in target
        return X, Y

    df = pd.read_csv(DATASET_PATH)
    train_dataset_df = df.sample(frac=0.8)
    df_remaining = df.drop(index=train_dataset_df.index)
    val_dataset_df = df_remaining.sample(frac=0.7)
    test_dataset_df = df_remaining.drop(index=val_dataset_df.index)

    train_dataset = list(map(get_tuple_dataset, train_dataset_df.to_numpy()))
    val_dataset = list(map(get_tuple_dataset, val_dataset_df.to_numpy()))
    test_dataset = list(map(get_tuple_dataset, test_dataset_df.to_numpy()))
    return train_dataset, val_dataset, test_dataset

# %%
train_dataset, val_dataset, test_dataset = load_data()

# %%
def getGraph(upperTriangleAdjMatrix):
    dense_adj = np.zeros((NUMBER_NODES, NUMBER_NODES))
    dense_adj = np.zeros((NUMBER_NODES, NUMBER_NODES))
    k = 0
    for i in range(NUMBER_NODES):
        for j in range(NUMBER_NODES):
            if i == j:
                continue
            elif i < j:
                dense_adj[i][j] = upperTriangleAdjMatrix[k]
                k += 1
            else:
                dense_adj[i][j] = dense_adj[j][i]
    return dense_adj

# %%
def processDataToImage(graphInput):
    graph_adj = getGraph(graphInput)
    plt.imshow(graph_adj, cmap="gray")
    plt.xticks([])
    plt.yticks([])
    plt.savefig(f'./Graph_adj_input_mse.png')
    plt.clf()
    image_input = tf.keras.preprocessing.image.load_img(f'./Graph_adj_input_mse.png')
    image_input_arr = tf.keras.preprocessing.image.img_to_array(image_input)
    image_input_np = np.array(image_input_arr)
    # image_input_np = image_input_np / 255.0

    image_input_np = tf.image.resize(image_input_np, [32, 32])
    return image_input_np

# %%
def getData(dataset):
    train_images = []
    train_nodelist = []
    train_bandwidth = []
    for graphInput, target in dataset:
        optband = target[0]
        graphNodeList = target[1 : ]
        x_image = processDataToImage(graphInput)
        train_images.append(x_image)
        train_nodelist.append(graphNodeList)
        train_bandwidth.append([optband])
    return np.array(train_images), (np.array(train_nodelist) / 10), np.array(train_bandwidth)

# %%
def getData_2(dataset):
    train_images = []
    train_nodelist = []
    for graphInput, target in dataset:
        graphNodeList = target[1 : ]
        x_image = processDataToImage(graphInput)
        train_images.append(x_image)
        train_nodelist.append(graphNodeList)
    # mlb = MultiLabelBinarizer()
    # labels = mlb.fit_transform(train_nodelist)
    return np.array(train_images), np.array(train_nodelist) / 10

# %%
# train_images, train_nodelist, train_bandwidth = getData(train_dataset)
# val_images, val_nodelist, val_bandwidth = getData(val_dataset)
# test_images, test_nodelist, test_bandwidth = getData(test_dataset)
# print(train_images.shape)
# print(train_nodelist.shape)
# print(train_bandwidth.shape)

# %%
train_images, train_nodelist = getData_2(train_dataset)
val_images, val_nodelist= getData_2(val_dataset)
test_images, test_nodelist = getData_2(test_dataset)

# aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
# 	height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
# 	horizontal_flip=True, fill_mode="nearest")

print(train_images.shape)
print(train_nodelist.shape)
# Out:
# (835, 32, 32, 3)
# (835, 7)

# %%
maeLoss = tf.keras.losses.MeanAbsoluteError()
loss_object = tf.keras.losses.MeanSquaredError()

def loss_repeated_labels(roundedOutput, roundedTrue):
  true_used, true_indexes = tf.unique(tf.squeeze(roundedTrue))
  used_labels, indexes, counts = tf.unique_with_counts(tf.squeeze(roundedOutput))
  counts = tf.cast(counts, tf.float32)
  # 1 - counts = quao longe os elementos de counts estão de repetir uma vez só (elemento unico)
  squaredDiff = loss_object(tf.ones_like(counts), counts)
  mseIndexes = loss_object(tf.cast(true_indexes, tf.float32), tf.cast(indexes, tf.float32))
  # o quao longe os indexes estao de ser 0,1,2,3,4,5,6
  loss = tf.math.reduce_variance(counts) * squaredDiff * mseIndexes
  return loss

def customLoss(true, pred):
  mae = maeLoss(true, pred)
  roundedOutput = tf.round(pred)
  roundedTrue = tf.round(true)
  loss_repeated = loss_repeated_labels(roundedOutput, roundedTrue)
  return mae + loss_repeated

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.RandomFlip("horizontal", input_shape=(32, 32, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

model = tf.keras.models.Sequential([
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.3),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(NUMBER_NODES, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss=customLoss,
              metrics=['accuracy'])

history = model.fit(
    train_images, train_nodelist,
    validation_data=(val_images, val_nodelist),
    epochs=180,
    batch_size=1
)
# Out:
# Epoch 1/180
# 835/835 [==============================] - 6s 5ms/step - loss: 4.9684 - accuracy: 0.3222 - val_loss: 0.1496 - val_accuracy: 0.3630
# Epoch 2/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.2475 - accuracy: 0.3557 - val_loss: 4.2972 - val_accuracy: 0.4178
# Epoch 3/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.7849 - accuracy: 0.3677 - val_loss: 4.1737 - val_accuracy: 0.3219
# Epoch 4/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.5038 - accuracy: 0.4204 - val_loss: 7.5924 - val_accuracy: 0.4863
# Epoch 5/180
# 835/835 [==============================] - 6s 7ms/step - loss: 5.2329 - accuracy: 0.4371 - val_loss: 3.5255 - val_accuracy: 0.5479
# Epoch 6/180
# 835/835 [==============================] - 5s 6ms/step - loss: 4.5126 - accuracy: 0.4802 - val_loss: 6.2512 - val_accuracy: 0.5548
# Epoch 7/180
# 835/835 [==============================] - 5s 6ms/step - loss: 5.1798 - accuracy: 0.4515 - val_loss: 4.2124 - val_accuracy: 0.5342
# Epoch 8/180
# 835/835 [==============================] - 5s 6ms/step - loss: 5.2896 - accuracy: 0.4826 - val_loss: 4.8602 - val_accuracy: 0.5890
# Epoch 9/180
# 835/835 [==============================] - 5s 6ms/step - loss: 4.6097 - accuracy: 0.5006 - val_loss: 4.0632 - val_accuracy: 0.47260s - loss: 4.7085 -
# Epoch 10/180
# 835/835 [==============================] - 5s 6ms/step - loss: 5.4439 - accuracy: 0.5078 - val_loss: 4.7839 - val_accuracy: 0.5274
# Epoch 11/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.4867 - accuracy: 0.5257 - val_loss: 6.4597 - val_accuracy: 0.4726
# Epoch 12/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.6166 - accuracy: 0.5545 - val_loss: 5.7183 - val_accuracy: 0.5000
# Epoch 13/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.4527 - accuracy: 0.5413 - val_loss: 4.3852 - val_accuracy: 0.5685
# Epoch 14/180
# 835/835 [==============================] - 4s 5ms/step - loss: 6.0657 - accuracy: 0.5305 - val_loss: 4.0908 - val_accuracy: 0.6164
# Epoch 15/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.4058 - accuracy: 0.5593 - val_loss: 5.7154 - val_accuracy: 0.6027
# Epoch 16/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.7922 - accuracy: 0.5677 - val_loss: 6.5484 - val_accuracy: 0.6233
# Epoch 17/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.9551 - accuracy: 0.5808 - val_loss: 5.5009 - val_accuracy: 0.6027
# Epoch 18/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.1992 - accuracy: 0.6180 - val_loss: 6.0364 - val_accuracy: 0.5959
# Epoch 19/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.5318 - accuracy: 0.6060 - val_loss: 5.3486 - val_accuracy: 0.5822
# Epoch 20/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.5448 - accuracy: 0.5988 - val_loss: 6.2341 - val_accuracy: 0.5479
# Epoch 21/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.4035 - accuracy: 0.6335 - val_loss: 5.2315 - val_accuracy: 0.6027
# Epoch 22/180
# 835/835 [==============================] - 4s 5ms/step - loss: 6.0539 - accuracy: 0.6060 - val_loss: 6.1215 - val_accuracy: 0.5959
# Epoch 23/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.2893 - accuracy: 0.6335 - val_loss: 6.7644 - val_accuracy: 0.6027
# Epoch 24/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.8941 - accuracy: 0.6455 - val_loss: 5.3515 - val_accuracy: 0.6096
# Epoch 25/180
# 835/835 [==============================] - 4s 5ms/step - loss: 5.2442 - accuracy: 0.6455 - val_loss: 5.5634 - val_accuracy: 0.5959
# Epoch 26/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.6853 - accuracy: 0.6719 - val_loss: 6.3589 - val_accuracy: 0.6096
# Epoch 27/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.7741 - accuracy: 0.6802 - val_loss: 6.0354 - val_accuracy: 0.6027
# Epoch 28/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.7220 - accuracy: 0.6731 - val_loss: 5.1492 - val_accuracy: 0.6918
# Epoch 29/180
# 835/835 [==============================] - 5s 5ms/step - loss: 4.4873 - accuracy: 0.6766 - val_loss: 5.3370 - val_accuracy: 0.6233
# Epoch 30/180
# 835/835 [==============================] - 5s 5ms/step - loss: 4.9488 - accuracy: 0.6766 - val_loss: 5.4734 - val_accuracy: 0.5959
# Epoch 31/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.7220 - accuracy: 0.6838 - val_loss: 4.3997 - val_accuracy: 0.6096
# Epoch 32/180
# 835/835 [==============================] - 5s 6ms/step - loss: 4.6796 - accuracy: 0.6958 - val_loss: 5.3951 - val_accuracy: 0.6370
# Epoch 33/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.4636 - accuracy: 0.6862 - val_loss: 4.9315 - val_accuracy: 0.6164
# Epoch 34/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.2943 - accuracy: 0.7353 - val_loss: 4.5691 - val_accuracy: 0.6370
# Epoch 35/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.4117 - accuracy: 0.7174 - val_loss: 6.2302 - val_accuracy: 0.6233accuracy:
# Epoch 36/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.2428 - accuracy: 0.7246 - val_loss: 5.3936 - val_accuracy: 0.6233
# Epoch 37/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.1797 - accuracy: 0.7042 - val_loss: 5.6754 - val_accuracy: 0.5959
# Epoch 38/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.7054 - accuracy: 0.7497 - val_loss: 6.1966 - val_accuracy: 0.6027
# Epoch 39/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.0467 - accuracy: 0.7521 - val_loss: 5.6589 - val_accuracy: 0.6233
# Epoch 40/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.7176 - accuracy: 0.7521 - val_loss: 4.9431 - val_accuracy: 0.6438
# Epoch 41/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.1634 - accuracy: 0.7365 - val_loss: 4.6843 - val_accuracy: 0.6712
# Epoch 42/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.1092 - accuracy: 0.7377 - val_loss: 5.1466 - val_accuracy: 0.6575
# Epoch 43/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.0110 - accuracy: 0.7581 - val_loss: 5.3455 - val_accuracy: 0.6370
# Epoch 44/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.9055 - accuracy: 0.7449 - val_loss: 4.8850 - val_accuracy: 0.6370
# Epoch 45/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.9044 - accuracy: 0.7473 - val_loss: 5.6547 - val_accuracy: 0.6301
# Epoch 46/180
# 835/835 [==============================] - 5s 5ms/step - loss: 3.7698 - accuracy: 0.7880 - val_loss: 5.1743 - val_accuracy: 0.6233
# Epoch 47/180
# 835/835 [==============================] - 4s 5ms/step - loss: 4.1650 - accuracy: 0.7389 - val_loss: 5.9650 - val_accuracy: 0.6027
# Epoch 48/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.9226 - accuracy: 0.7461 - val_loss: 5.8144 - val_accuracy: 0.6233
# Epoch 49/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.2369 - accuracy: 0.7904 - val_loss: 4.9626 - val_accuracy: 0.6712
# Epoch 50/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.3592 - accuracy: 0.7617 - val_loss: 6.2172 - val_accuracy: 0.6096
# Epoch 51/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.5137 - accuracy: 0.7737 - val_loss: 5.4471 - val_accuracy: 0.6507
# Epoch 52/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.6250 - accuracy: 0.7737 - val_loss: 6.3626 - val_accuracy: 0.5959
# Epoch 53/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.7544 - accuracy: 0.7737 - val_loss: 6.3688 - val_accuracy: 0.6096
# Epoch 54/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.3027 - accuracy: 0.7689 - val_loss: 5.9620 - val_accuracy: 0.6438
# Epoch 55/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.4615 - accuracy: 0.7952 - val_loss: 6.0131 - val_accuracy: 0.5959
# Epoch 56/180
# 835/835 [==============================] - 5s 5ms/step - loss: 3.3612 - accuracy: 0.7844 - val_loss: 5.9208 - val_accuracy: 0.6027
# Epoch 57/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.3420 - accuracy: 0.8060 - val_loss: 5.5672 - val_accuracy: 0.6301
# Epoch 58/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.5584 - accuracy: 0.7856 - val_loss: 5.8946 - val_accuracy: 0.6096
# Epoch 59/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.2776 - accuracy: 0.8204 - val_loss: 5.4148 - val_accuracy: 0.6370
# Epoch 60/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.3383 - accuracy: 0.7904 - val_loss: 4.9535 - val_accuracy: 0.6575
# Epoch 61/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7069 - accuracy: 0.8192 - val_loss: 5.7217 - val_accuracy: 0.6370
# Epoch 62/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.3494 - accuracy: 0.7868 - val_loss: 4.7072 - val_accuracy: 0.6438
# Epoch 63/180
# 835/835 [==============================] - 5s 5ms/step - loss: 3.2276 - accuracy: 0.8024 - val_loss: 5.4368 - val_accuracy: 0.6233
# Epoch 64/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.2258 - accuracy: 0.8132 - val_loss: 5.8852 - val_accuracy: 0.6644
# Epoch 65/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.2841 - accuracy: 0.8096 - val_loss: 5.5249 - val_accuracy: 0.6438
# Epoch 66/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.3960 - accuracy: 0.8084 - val_loss: 6.4776 - val_accuracy: 0.5685
# Epoch 67/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.3001 - accuracy: 0.8024 - val_loss: 5.8279 - val_accuracy: 0.6164
# Epoch 68/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.1917 - accuracy: 0.8168 - val_loss: 5.0970 - val_accuracy: 0.6233
# Epoch 69/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.1985 - accuracy: 0.8216 - val_loss: 6.1785 - val_accuracy: 0.6301
# Epoch 70/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.3287 - accuracy: 0.8108 - val_loss: 5.3583 - val_accuracy: 0.6164
# Epoch 71/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.5294 - accuracy: 0.8096 - val_loss: 5.0090 - val_accuracy: 0.6027: 2s - loss: 3 - ETA: 1s - los - ETA:
# Epoch 72/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.1074 - accuracy: 0.8156 - val_loss: 6.0084 - val_accuracy: 0.6233
# Epoch 73/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.0244 - accuracy: 0.8144 - val_loss: 6.5265 - val_accuracy: 0.5822
# Epoch 74/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.1864 - accuracy: 0.8036 - val_loss: 5.3560 - val_accuracy: 0.6164
# Epoch 75/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.0095 - accuracy: 0.8359 - val_loss: 6.1943 - val_accuracy: 0.6438
# Epoch 76/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.0149 - accuracy: 0.8144 - val_loss: 5.5229 - val_accuracy: 0.5959
# Epoch 77/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.1186 - accuracy: 0.8060 - val_loss: 6.1295 - val_accuracy: 0.6370
# Epoch 78/180
# 835/835 [==============================] - 5s 6ms/step - loss: 2.5948 - accuracy: 0.8371 - val_loss: 5.9278 - val_accuracy: 0.5890
# Epoch 79/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.1108 - accuracy: 0.8347 - val_loss: 5.9322 - val_accuracy: 0.6164
# Epoch 80/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.0184 - accuracy: 0.8299 - val_loss: 5.4005 - val_accuracy: 0.6233
# Epoch 81/180
# 835/835 [==============================] - 5s 6ms/step - loss: 2.8303 - accuracy: 0.8419 - val_loss: 6.0978 - val_accuracy: 0.5890
# Epoch 82/180
# 835/835 [==============================] - 6s 7ms/step - loss: 2.9312 - accuracy: 0.8287 - val_loss: 5.4392 - val_accuracy: 0.59590.82
# Epoch 83/180
# 835/835 [==============================] - 6s 7ms/step - loss: 2.6234 - accuracy: 0.8275 - val_loss: 5.9766 - val_accuracy: 0.6781
# Epoch 84/180
# 835/835 [==============================] - 6s 7ms/step - loss: 2.6381 - accuracy: 0.8443 - val_loss: 5.5718 - val_accuracy: 0.6301
# Epoch 85/180
# 835/835 [==============================] - 5s 6ms/step - loss: 2.8628 - accuracy: 0.8359 - val_loss: 6.0714 - val_accuracy: 0.5959
# Epoch 86/180
# 835/835 [==============================] - 5s 6ms/step - loss: 2.5966 - accuracy: 0.8335 - val_loss: 6.1359 - val_accuracy: 0.6233
# Epoch 87/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.1804 - accuracy: 0.8335 - val_loss: 6.7663 - val_accuracy: 0.5890
# Epoch 88/180
# 835/835 [==============================] - 5s 6ms/step - loss: 2.7542 - accuracy: 0.8419 - val_loss: 6.9063 - val_accuracy: 0.6164
# Epoch 89/180
# 835/835 [==============================] - 5s 6ms/step - loss: 3.0423 - accuracy: 0.8192 - val_loss: 6.0329 - val_accuracy: 0.6096
# Epoch 90/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6594 - accuracy: 0.8515 - val_loss: 6.4671 - val_accuracy: 0.6096
# Epoch 91/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.0954 - accuracy: 0.8407 - val_loss: 6.6262 - val_accuracy: 0.5753
# Epoch 92/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7989 - accuracy: 0.8407 - val_loss: 6.7447 - val_accuracy: 0.5753
# Epoch 93/180
# 835/835 [==============================] - 5s 5ms/step - loss: 3.0724 - accuracy: 0.8347 - val_loss: 6.9620 - val_accuracy: 0.6233
# Epoch 94/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6903 - accuracy: 0.8383 - val_loss: 6.0837 - val_accuracy: 0.5959
# Epoch 95/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7927 - accuracy: 0.8407 - val_loss: 6.8749 - val_accuracy: 0.5890
# Epoch 96/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7019 - accuracy: 0.8587 - val_loss: 6.5526 - val_accuracy: 0.5753
# Epoch 97/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.0895 - accuracy: 0.8347 - val_loss: 6.5395 - val_accuracy: 0.5959
# Epoch 98/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.8244 - accuracy: 0.8455 - val_loss: 6.3938 - val_accuracy: 0.6096
# Epoch 99/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.8773 - accuracy: 0.8443 - val_loss: 6.0816 - val_accuracy: 0.6027
# Epoch 100/180
# 835/835 [==============================] - 4s 5ms/step - loss: 3.0276 - accuracy: 0.8383 - val_loss: 5.3356 - val_accuracy: 0.6096
# Epoch 101/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7215 - accuracy: 0.8599 - val_loss: 6.4783 - val_accuracy: 0.6027
# Epoch 102/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6968 - accuracy: 0.8539 - val_loss: 6.6981 - val_accuracy: 0.6096
# Epoch 103/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.8344 - accuracy: 0.8587 - val_loss: 6.8721 - val_accuracy: 0.6027
# Epoch 104/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6080 - accuracy: 0.8563 - val_loss: 5.9032 - val_accuracy: 0.6096
# Epoch 105/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7066 - accuracy: 0.8539 - val_loss: 5.5462 - val_accuracy: 0.5890
# Epoch 106/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6358 - accuracy: 0.8635 - val_loss: 7.1892 - val_accuracy: 0.5822
# Epoch 107/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7360 - accuracy: 0.8491 - val_loss: 5.5928 - val_accuracy: 0.6233
# Epoch 108/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.2215 - accuracy: 0.8731 - val_loss: 6.5887 - val_accuracy: 0.6644
# Epoch 109/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6446 - accuracy: 0.8407 - val_loss: 4.9029 - val_accuracy: 0.6438
# Epoch 110/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6727 - accuracy: 0.8467 - val_loss: 5.8918 - val_accuracy: 0.6164
# Epoch 111/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6455 - accuracy: 0.8479 - val_loss: 6.5378 - val_accuracy: 0.63017 - ac - ETA: 1s - ETA: 0s - loss: 2.706
# Epoch 112/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4828 - accuracy: 0.8659 - val_loss: 5.7907 - val_accuracy: 0.6096
# Epoch 113/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6110 - accuracy: 0.8635 - val_loss: 6.1231 - val_accuracy: 0.6027
# Epoch 114/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.8172 - accuracy: 0.8383 - val_loss: 5.3808 - val_accuracy: 0.6027
# Epoch 115/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4679 - accuracy: 0.8719 - val_loss: 5.4900 - val_accuracy: 0.6575
# Epoch 116/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4348 - accuracy: 0.8599 - val_loss: 6.2184 - val_accuracy: 0.6164
# Epoch 117/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6724 - accuracy: 0.8383 - val_loss: 5.8932 - val_accuracy: 0.6027
# Epoch 118/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6410 - accuracy: 0.8431 - val_loss: 5.0698 - val_accuracy: 0.6164
# Epoch 119/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.2543 - accuracy: 0.8814 - val_loss: 5.1484 - val_accuracy: 0.6301
# Epoch 120/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4457 - accuracy: 0.8671 - val_loss: 5.1069 - val_accuracy: 0.6781
# Epoch 121/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7274 - accuracy: 0.8551 - val_loss: 5.7333 - val_accuracy: 0.5890
# Epoch 122/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6614 - accuracy: 0.8659 - val_loss: 5.7227 - val_accuracy: 0.6027
# Epoch 123/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7194 - accuracy: 0.8395 - val_loss: 5.7732 - val_accuracy: 0.6027
# Epoch 124/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.5762 - accuracy: 0.8467 - val_loss: 5.9470 - val_accuracy: 0.6507
# Epoch 125/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.9356 - accuracy: 0.8659 - val_loss: 5.2898 - val_accuracy: 0.6096
# Epoch 126/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4310 - accuracy: 0.8611 - val_loss: 5.8696 - val_accuracy: 0.6438
# Epoch 127/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4675 - accuracy: 0.8647 - val_loss: 5.5854 - val_accuracy: 0.6301
# Epoch 128/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.5033 - accuracy: 0.8659 - val_loss: 6.2535 - val_accuracy: 0.6233
# Epoch 129/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6951 - accuracy: 0.8671 - val_loss: 5.7514 - val_accuracy: 0.6233
# Epoch 130/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4469 - accuracy: 0.8671 - val_loss: 5.3857 - val_accuracy: 0.5959
# Epoch 131/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4989 - accuracy: 0.8455 - val_loss: 6.3474 - val_accuracy: 0.6370
# Epoch 132/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.9953 - accuracy: 0.8599 - val_loss: 5.2769 - val_accuracy: 0.5685
# Epoch 133/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.3056 - accuracy: 0.8683 - val_loss: 5.2354 - val_accuracy: 0.6233
# Epoch 134/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7278 - accuracy: 0.8623 - val_loss: 5.4899 - val_accuracy: 0.6575
# Epoch 135/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6590 - accuracy: 0.8671 - val_loss: 5.5719 - val_accuracy: 0.6233
# Epoch 136/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7057 - accuracy: 0.8671 - val_loss: 6.2410 - val_accuracy: 0.6027
# Epoch 137/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6525 - accuracy: 0.8515 - val_loss: 5.8110 - val_accuracy: 0.6096
# Epoch 138/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7712 - accuracy: 0.8503 - val_loss: 6.2266 - val_accuracy: 0.6233
# Epoch 139/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6214 - accuracy: 0.8635 - val_loss: 6.4055 - val_accuracy: 0.6233
# Epoch 140/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.3051 - accuracy: 0.8778 - val_loss: 6.1248 - val_accuracy: 0.6233
# Epoch 141/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4132 - accuracy: 0.8838 - val_loss: 6.5189 - val_accuracy: 0.6370
# Epoch 142/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.3419 - accuracy: 0.8778 - val_loss: 6.5978 - val_accuracy: 0.5890
# Epoch 143/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6047 - accuracy: 0.8743 - val_loss: 6.9773 - val_accuracy: 0.6233
# Epoch 144/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.3218 - accuracy: 0.8731 - val_loss: 6.1408 - val_accuracy: 0.6096
# Epoch 145/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7138 - accuracy: 0.8611 - val_loss: 5.4090 - val_accuracy: 0.5959
# Epoch 146/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.5036 - accuracy: 0.8802 - val_loss: 6.1070 - val_accuracy: 0.6370
# Epoch 147/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6823 - accuracy: 0.8611 - val_loss: 7.1869 - val_accuracy: 0.5479
# Epoch 148/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.9151 - accuracy: 0.8467 - val_loss: 6.9793 - val_accuracy: 0.5890
# Epoch 149/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6740 - accuracy: 0.8599 - val_loss: 4.9440 - val_accuracy: 0.6507
# Epoch 150/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4203 - accuracy: 0.8719 - val_loss: 6.9616 - val_accuracy: 0.5685
# Epoch 151/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4454 - accuracy: 0.8695 - val_loss: 5.7972 - val_accuracy: 0.6027
# Epoch 152/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.5275 - accuracy: 0.8766 - val_loss: 6.5970 - val_accuracy: 0.5959
# Epoch 153/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6428 - accuracy: 0.8587 - val_loss: 6.6919 - val_accuracy: 0.5959
# Epoch 154/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.5961 - accuracy: 0.8778 - val_loss: 5.3716 - val_accuracy: 0.6164
# Epoch 155/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6444 - accuracy: 0.8695 - val_loss: 6.8846 - val_accuracy: 0.5822
# Epoch 156/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6235 - accuracy: 0.8683 - val_loss: 5.7735 - val_accuracy: 0.6233
# Epoch 157/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.3171 - accuracy: 0.8862 - val_loss: 6.4216 - val_accuracy: 0.6027
# Epoch 158/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4235 - accuracy: 0.8647 - val_loss: 5.7594 - val_accuracy: 0.5822
# Epoch 159/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.2729 - accuracy: 0.8826 - val_loss: 4.9791 - val_accuracy: 0.6027
# Epoch 160/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.5355 - accuracy: 0.8683 - val_loss: 5.5055 - val_accuracy: 0.6096
# Epoch 161/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4997 - accuracy: 0.8838 - val_loss: 5.2898 - val_accuracy: 0.6096
# Epoch 162/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4443 - accuracy: 0.8838 - val_loss: 5.5078 - val_accuracy: 0.5753
# Epoch 163/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.3031 - accuracy: 0.8790 - val_loss: 5.9709 - val_accuracy: 0.5959
# Epoch 164/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.1560 - accuracy: 0.8958 - val_loss: 5.8768 - val_accuracy: 0.5616
# Epoch 165/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4175 - accuracy: 0.8611 - val_loss: 5.4547 - val_accuracy: 0.5822
# Epoch 166/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.3894 - accuracy: 0.8874 - val_loss: 5.8021 - val_accuracy: 0.6096
# Epoch 167/180
# 835/835 [==============================] - 4s 4ms/step - loss: 2.6074 - accuracy: 0.8575 - val_loss: 5.2529 - val_accuracy: 0.6027
# Epoch 168/180
# 835/835 [==============================] - 3s 4ms/step - loss: 2.7020 - accuracy: 0.8683 - val_loss: 5.9226 - val_accuracy: 0.6164
# Epoch 169/180
# 835/835 [==============================] - 3s 4ms/step - loss: 2.3398 - accuracy: 0.9006 - val_loss: 6.6722 - val_accuracy: 0.5822
# Epoch 170/180
# 835/835 [==============================] - 4s 4ms/step - loss: 2.7552 - accuracy: 0.8766 - val_loss: 4.8311 - val_accuracy: 0.6096
# Epoch 171/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4102 - accuracy: 0.8898 - val_loss: 6.0589 - val_accuracy: 0.5890
# Epoch 172/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.5320 - accuracy: 0.8659 - val_loss: 5.1693 - val_accuracy: 0.5753
# Epoch 173/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.2951 - accuracy: 0.8922 - val_loss: 6.5494 - val_accuracy: 0.5685
# Epoch 174/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.3263 - accuracy: 0.8790 - val_loss: 6.0264 - val_accuracy: 0.5753
# Epoch 175/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.4595 - accuracy: 0.8946 - val_loss: 6.4121 - val_accuracy: 0.5753
# Epoch 176/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.3583 - accuracy: 0.8886 - val_loss: 5.9612 - val_accuracy: 0.6164
# Epoch 177/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.6954 - accuracy: 0.8778 - val_loss: 5.9477 - val_accuracy: 0.5890
# Epoch 178/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.5573 - accuracy: 0.8886 - val_loss: 6.4156 - val_accuracy: 0.6233
# Epoch 179/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.5680 - accuracy: 0.8838 - val_loss: 5.2757 - val_accuracy: 0.6301
# Epoch 180/180
# 835/835 [==============================] - 4s 5ms/step - loss: 2.7509 - accuracy: 0.8838 - val_loss: 5.1280 - val_accuracy: 0.6096

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

# %%
# test = np.array([test_images[0]])
pred = model.predict(test_images)
true = test_nodelist
# print(pred)
print("Pred")
print((pred * 10).round())
print("True")
print(true*10)
# Out:
# Pred
# [[1. 6. 2. 5. 2. 4. 3.]
#  [2. 1. 5. 6. 4. 0. 4.]
#  [1. 4. 0. 4. 5. 4. 4.]
#  [3. 0. 1. 6. 5. 3. 3.]
#  [3. 3. 3. 0. 5. 3. 3.]
#  [3. 4. 1. 1. 4. 3. 3.]
#  [3. 2. 5. 6. 4. 2. 3.]
#  [1. 6. 6. 0. 3. 3. 3.]
#  [1. 5. 5. 2. 0. 4. 4.]
#  [3. 4. 1. 5. 5. 4. 2.]
#  [3. 3. 5. 5. 5. 3. 3.]
#  [4. 4. 1. 0. 3. 5. 3.]
#  [2. 0. 5. 6. 4. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 3.]
#  [3. 1. 5. 5. 5. 0. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 2. 5. 6. 2. 3. 4.]
#  [2. 0. 5. 5. 4. 4. 2.]
#  [2. 4. 5. 5. 4. 3. 2.]
#  [3. 2. 5. 6. 4. 3. 3.]
#  [4. 2. 1. 5. 5. 0. 3.]
#  [4. 2. 3. 6. 3. 0. 3.]
#  [4. 3. 3. 6. 4. 0. 3.]
#  [4. 1. 4. 0. 5. 1. 3.]
#  [3. 1. 5. 6. 5. 2. 2.]
#  [3. 2. 5. 5. 5. 3. 3.]
#  [2. 0. 5. 6. 5. 3. 2.]
#  [3. 3. 2. 5. 5. 0. 3.]
#  [2. 3. 5. 6. 1. 0. 3.]
#  [3. 0. 5. 6. 4. 2. 2.]
#  [3. 4. 4. 5. 4. 4. 3.]
#  [3. 4. 5. 6. 5. 3. 3.]
#  [2. 3. 0. 6. 5. 4. 2.]
#  [3. 0. 5. 6. 4. 1. 2.]
#  [3. 0. 4. 6. 4. 3. 3.]
#  [3. 4. 0. 6. 4. 1. 2.]
#  [0. 3. 5. 6. 4. 3. 2.]
#  [0. 0. 6. 3. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 2. 1. 5. 5. 3. 3.]
#  [2. 0. 6. 4. 5. 2. 2.]
#  [3. 0. 5. 6. 4. 2. 2.]
#  [3. 0. 5. 6. 4. 1. 2.]
#  [3. 4. 4. 0. 4. 4. 3.]
#  [1. 0. 6. 3. 5. 3. 3.]
#  [2. 3. 0. 5. 5. 3. 2.]
#  [4. 2. 0. 6. 6. 3. 2.]
#  [2. 3. 6. 5. 0. 4. 3.]
#  [3. 3. 4. 0. 5. 4. 2.]
#  [1. 3. 5. 5. 5. 0. 2.]
#  [2. 3. 5. 6. 5. 3. 3.]
#  [2. 3. 5. 5. 6. 0. 2.]
#  [2. 0. 5. 5. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [4. 0. 4. 5. 3. 3. 3.]
#  [2. 3. 5. 6. 3. 3. 3.]
#  [2. 4. 4. 5. 5. 2. 3.]
#  [1. 5. 3. 4. 3. 0. 3.]
#  [3. 3. 5. 5. 5. 2. 3.]
#  [3. 1. 5. 5. 5. 4. 1.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 1. 1. 6. 4. 4. 3.]
#  [3. 0. 3. 4. 5. 3. 2.]]
# True
# [[1. 6. 2. 0. 5. 3. 4.]
#  [1. 4. 6. 2. 3. 0. 5.]
#  [1. 5. 0. 2. 6. 3. 4.]
#  [1. 5. 0. 6. 3. 2. 4.]
#  [3. 1. 5. 0. 6. 2. 4.]
#  [5. 1. 2. 6. 0. 3. 4.]
#  [5. 1. 0. 6. 4. 2. 3.]
#  [1. 5. 6. 0. 4. 3. 2.]
#  [1. 6. 3. 2. 0. 4. 5.]
#  [3. 1. 5. 6. 2. 0. 4.]
#  [2. 3. 1. 4. 5. 6. 0.]
#  [4. 6. 1. 0. 2. 5. 3.]
#  [1. 4. 6. 5. 0. 2. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 2. 1. 4. 5. 6. 0.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [5. 3. 2. 0. 6. 4. 1.]
#  [0. 5. 6. 3. 1. 4. 2.]
#  [3. 5. 0. 6. 1. 2. 4.]
#  [1. 4. 6. 2. 5. 3. 0.]
#  [4. 3. 1. 0. 6. 5. 2.]
#  [4. 1. 0. 6. 5. 3. 2.]
#  [5. 2. 1. 6. 4. 0. 3.]
#  [1. 4. 5. 6. 0. 3. 2.]
#  [2. 1. 6. 4. 5. 0. 3.]
#  [4. 1. 6. 0. 5. 2. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [5. 2. 1. 4. 6. 0. 3.]
#  [4. 2. 1. 5. 6. 0. 3.]
#  [3. 5. 6. 0. 1. 2. 4.]
#  [2. 1. 4. 6. 5. 3. 0.]
#  [2. 3. 0. 4. 6. 5. 1.]
#  [1. 5. 4. 6. 0. 2. 3.]
#  [3. 0. 1. 6. 5. 4. 2.]
#  [3. 0. 1. 6. 5. 4. 2.]
#  [0. 3. 2. 6. 5. 4. 1.]
#  [1. 4. 2. 6. 5. 3. 0.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [4. 0. 3. 6. 5. 1. 2.]
#  [2. 1. 5. 4. 6. 0. 3.]
#  [3. 0. 6. 5. 4. 2. 1.]
#  [2. 1. 4. 6. 5. 0. 3.]
#  [2. 5. 1. 0. 4. 6. 3.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [2. 5. 3. 0. 6. 4. 1.]
#  [3. 6. 1. 0. 2. 5. 4.]
#  [3. 6. 1. 0. 4. 5. 2.]
#  [1. 3. 5. 4. 6. 0. 2.]
#  [1. 3. 5. 4. 6. 0. 2.]
#  [1. 3. 6. 4. 5. 0. 2.]
#  [4. 1. 0. 6. 3. 5. 2.]
#  [2. 0. 5. 6. 4. 3. 1.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [5. 1. 3. 6. 0. 2. 4.]
#  [0. 4. 6. 5. 2. 1. 3.]
#  [0. 5. 3. 6. 2. 1. 4.]
#  [6. 4. 0. 2. 1. 3. 5.]
#  [2. 4. 6. 0. 5. 1. 3.]
#  [3. 2. 5. 6. 0. 4. 1.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 0. 1. 6. 2. 5. 4.]
#  [2. 5. 4. 1. 6. 0. 3.]]

# %%
# test = np.array([test_images[0]])
pred = model.predict(train_images[:10])
true = train_nodelist[:10]
# print(pred)
print("Pred")
print((pred* 10).round())
print("True")
print(true*10)
# Out:
# Pred
# [[1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 5. 3. 6. 0. 1. 4.]
#  [2. 1. 6. 5. 3. 0. 5.]
#  [2. 6. 1. 1. 6. 0. 4.]
#  [1. 4. 6. 3. 0. 5. 2.]
#  [4. 3. 5. 3. 5. 0. 3.]
#  [3. 2. 0. 6. 5. 3. 0.]
#  [1. 3. 5. 6. 0. 2. 4.]
#  [2. 0. 5. 4. 6. 2. 2.]]
# True
# [[1. 0. 6. 4. 5. 3. 2.]
#  [1. 0. 6. 4. 5. 3. 2.]
#  [3. 5. 2. 6. 0. 1. 4.]
#  [2. 1. 6. 4. 3. 0. 5.]
#  [3. 5. 1. 2. 6. 0. 4.]
#  [1. 4. 6. 3. 0. 5. 2.]
#  [4. 2. 5. 1. 6. 0. 3.]
#  [4. 2. 1. 6. 5. 3. 0.]
#  [1. 3. 6. 5. 0. 2. 4.]
#  [3. 0. 5. 4. 6. 1. 2.]]
