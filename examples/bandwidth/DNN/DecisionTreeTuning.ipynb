# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Resultados do dataset de 7 vértices

# %%
# configuração:
# [[original, output, otima, total repetição, saidas com pelo menos 1 repetição]]
DecisionTreeRegressor2 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{5.238095238095238:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{252}',
        f'{63}'
    ]
])

DecisionTreeRegressor4 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{4.698412698412699:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{256}',
        f'{62}'
    ]
])

DecisionTreeRegressor6 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{4.666666666666667:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{203}',
        f'{61}'
    ]
])

DecisionTreeRegressor8 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{4.5396825396825395:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{164}',
        f'{55}'
    ]
])

DecisionTreeRegressor10 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{4.174603174603175:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{105}',
        f'{35}'
    ]
])

DecisionTreeRegressor12 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.857142857142857:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{40}',
        f'{14}'
    ]
])

DecisionTreeRegressor14 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.761904761904762:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{10}',
        f'{5}'
    ]
])

DecisionTreeRegressor16 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.6984126984126986:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

DecisionTreeRegressor18 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.7777777777777777:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

DecisionTreeRegressor20 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.6507936507936507:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

DecisionTreeRegressor22 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.746031746031746:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

DecisionTreeRegressor24 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.7142857142857144:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

DecisionTreeRegressor26 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.746031746031746:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

DecisionTreeRegressor28 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.634920634920635:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

DecisionTreeRegressor30 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.6666666666666665:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

DecisionTreeRegressor32 = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.6031746031746033:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

print('Test length -  63')
print('Para 9 vértices o max_depth default é 18')

data = np.concatenate(
    (
        DecisionTreeRegressor2,
        DecisionTreeRegressor4,
        DecisionTreeRegressor6,
        DecisionTreeRegressor8,
        DecisionTreeRegressor10,
        DecisionTreeRegressor12,
        DecisionTreeRegressor14,
        DecisionTreeRegressor16,
        DecisionTreeRegressor18,
        DecisionTreeRegressor20,
        DecisionTreeRegressor22,
        DecisionTreeRegressor24,
        DecisionTreeRegressor26,
        DecisionTreeRegressor28,
        DecisionTreeRegressor30,
        DecisionTreeRegressor32
    )
)

df = pd.DataFrame(
    data,
    index=[
        'DecisionTreeRegressor2',
        'DecisionTreeRegressor4',
        'DecisionTreeRegressor6',
        'DecisionTreeRegressor8',
        'DecisionTreeRegressor10',
        'DecisionTreeRegressor12',
        'DecisionTreeRegressor14',
        'DecisionTreeRegressor16',
        'DecisionTreeRegressor18',
        'DecisionTreeRegressor20',
        'DecisionTreeRegressor22',
        'DecisionTreeRegressor24',
        'DecisionTreeRegressor26',
        'DecisionTreeRegressor28',
        'DecisionTreeRegressor30',
        'DecisionTreeRegressor32'
    ],
    columns=[
        'média largura de banda original',
        'média largura de banda produzida pelo modelo',
        'média largura de banda ótima',
        'Total de rótulos repetidos produzidos',
        'Total de saídas com ao menos uma repetição'
    ]
)
print(data)
print("--Resultados para 7 vértices--")
df
# Out:
# Test length -  63
# Para 9 vértices o max_depth default é 18
# [['5.9048' '5.2381' '3.1905' '252' '63']
#  ['5.9048' '4.6984' '3.1905' '256' '62']
#  ['5.9048' '4.6667' '3.1905' '203' '61']
#  ['5.9048' '4.5397' '3.1905' '164' '55']
#  ['5.9048' '4.1746' '3.1905' '105' '35']
#  ['5.9048' '3.8571' '3.1905' '40' '14']
#  ['5.9048' '3.7619' '3.1905' '10' '5']
#  ['5.9048' '3.6984' '3.1905' '0' '0']
#  ['5.9048' '3.7778' '3.1905' '0' '0']
#  ['5.9048' '3.6508' '3.1905' '0' '0']
#  ['5.9048' '3.7460' '3.1905' '0' '0']
#  ['5.9048' '3.7143' '3.1905' '0' '0']
#  ['5.9048' '3.7460' '3.1905' '0' '0']
#  ['5.9048' '3.6349' '3.1905' '0' '0']
#  ['5.9048' '3.6667' '3.1905' '0' '0']
#  ['5.9048' '3.6032' '3.1905' '0' '0']]
# --Resultados para 7 vértices--
#                         média largura de banda original  \
# DecisionTreeRegressor2                           5.9048
# DecisionTreeRegressor4                           5.9048
# DecisionTreeRegressor6                           5.9048
# DecisionTreeRegressor8                           5.9048
# DecisionTreeRegressor10                          5.9048
# DecisionTreeRegressor12                          5.9048
# DecisionTreeRegressor14                          5.9048
# DecisionTreeRegressor16                          5.9048
# DecisionTreeRegressor18                          5.9048
# DecisionTreeRegressor20                          5.9048
# DecisionTreeRegressor22                          5.9048
# DecisionTreeRegressor24                          5.9048
# DecisionTreeRegressor26                          5.9048
# DecisionTreeRegressor28                          5.9048
# DecisionTreeRegressor30                          5.9048
# DecisionTreeRegressor32                          5.9048
#
#                         média largura de banda produzida pelo modelo  \
# DecisionTreeRegressor2                                        5.2381
# DecisionTreeRegressor4                                        4.6984
# DecisionTreeRegressor6                                        4.6667
# DecisionTreeRegressor8                                        4.5397
# DecisionTreeRegressor10                                       4.1746
# DecisionTreeRegressor12                                       3.8571
# DecisionTreeRegressor14                                       3.7619
# DecisionTreeRegressor16                                       3.6984
# DecisionTreeRegressor18                                       3.7778
# DecisionTreeRegressor20                                       3.6508
# DecisionTreeRegressor22                                       3.7460
# DecisionTreeRegressor24                                       3.7143
# DecisionTreeRegressor26                                       3.7460
# DecisionTreeRegressor28                                       3.6349
# DecisionTreeRegressor30                                       3.6667
# DecisionTreeRegressor32                                       3.6032
#
#                         média largura de banda ótima  \
# DecisionTreeRegressor2                        3.1905
# DecisionTreeRegressor4                        3.1905
# DecisionTreeRegressor6                        3.1905
# DecisionTreeRegressor8                        3.1905
# DecisionTreeRegressor10                       3.1905
# DecisionTreeRegressor12                       3.1905
# DecisionTreeRegressor14                       3.1905
# DecisionTreeRegressor16                       3.1905
# DecisionTreeRegressor18                       3.1905
# DecisionTreeRegressor20                       3.1905
# DecisionTreeRegressor22                       3.1905
# DecisionTreeRegressor24                       3.1905
# DecisionTreeRegressor26                       3.1905
# DecisionTreeRegressor28                       3.1905
# DecisionTreeRegressor30                       3.1905
# DecisionTreeRegressor32                       3.1905
#
#                         Total de rótulos repetidos produzidos  \
# DecisionTreeRegressor2                                    252
# DecisionTreeRegressor4                                    256
# DecisionTreeRegressor6                                    203
# DecisionTreeRegressor8                                    164
# DecisionTreeRegressor10                                   105
# DecisionTreeRegressor12                                    40
# DecisionTreeRegressor14                                    10
# DecisionTreeRegressor16                                     0
# DecisionTreeRegressor18                                     0
# DecisionTreeRegressor20                                     0
# DecisionTreeRegressor22                                     0
# DecisionTreeRegressor24                                     0
# DecisionTreeRegressor26                                     0
# DecisionTreeRegressor28                                     0
# DecisionTreeRegressor30                                     0
# DecisionTreeRegressor32                                     0
#
#                         Total de saídas com ao menos uma repetição
# DecisionTreeRegressor2                                          63
# DecisionTreeRegressor4                                          62
# DecisionTreeRegressor6                                          61
# DecisionTreeRegressor8                                          55
# DecisionTreeRegressor10                                         35
# DecisionTreeRegressor12                                         14
# DecisionTreeRegressor14                                          5
# DecisionTreeRegressor16                                          0
# DecisionTreeRegressor18                                          0
# DecisionTreeRegressor20                                          0
# DecisionTreeRegressor22                                          0
# DecisionTreeRegressor24                                          0
# DecisionTreeRegressor26                                          0
# DecisionTreeRegressor28                                          0
# DecisionTreeRegressor30                                          0
# DecisionTreeRegressor32                                          0

# %%
df.to_latex()
# Out:
# '\\begin{tabular}{llllll}\n\\toprule\n{} & média largura de banda original & média largura de banda produzida pelo modelo & média largura de banda ótima & Total de rótulos repetidos produzidos & Total de saídas com ao menos uma repetição \\\\\n\\midrule\nDecisionTreeRegressor2  &                          5.9048 &                                       5.2381 &                       3.1905 &                                   252 &                                         63 \\\\\nDecisionTreeRegressor4  &                          5.9048 &                                       4.6984 &                       3.1905 &                                   256 &                                         62 \\\\\nDecisionTreeRegressor6  &                          5.9048 &                                       4.6667 &                       3.1905 &                                   203 &                                         61 \\\\\nDecisionTreeRegressor8  &                          5.9048 &                                       4.5397 &                       3.1905 &                                   164 &                                         55 \\\\\nDecisionTreeRegressor10 &                          5.9048 &                                       4.1746 &                       3.1905 &                                   105 &                                         35 \\\\\nDecisionTreeRegressor12 &                          5.9048 &                                       3.8571 &                       3.1905 &                                    40 &                                         14 \\\\\nDecisionTreeRegressor14 &                          5.9048 &                                       3.7619 &                       3.1905 &                                    10 &                                          5 \\\\\nDecisionTreeRegressor16 &                          5.9048 &                                       3.6984 &                       3.1905 &                                     0 &                                          0 \\\\\nDecisionTreeRegressor18 &                          5.9048 &                                       3.7778 &                       3.1905 &                                     0 &                                          0 \\\\\nDecisionTreeRegressor20 &                          5.9048 &                                       3.6508 &                       3.1905 &                                     0 &                                          0 \\\\\nDecisionTreeRegressor22 &                          5.9048 &                                       3.7460 &                       3.1905 &                                     0 &                                          0 \\\\\nDecisionTreeRegressor24 &                          5.9048 &                                       3.7143 &                       3.1905 &                                     0 &                                          0 \\\\\nDecisionTreeRegressor26 &                          5.9048 &                                       3.7460 &                       3.1905 &                                     0 &                                          0 \\\\\nDecisionTreeRegressor28 &                          5.9048 &                                       3.6349 &                       3.1905 &                                     0 &                                          0 \\\\\nDecisionTreeRegressor30 &                          5.9048 &                                       3.6667 &                       3.1905 &                                     0 &                                          0 \\\\\nDecisionTreeRegressor32 &                          5.9048 &                                       3.6032 &                       3.1905 &                                     0 &                                          0 \\\\\n\\bottomrule\n\\end{tabular}\n'
