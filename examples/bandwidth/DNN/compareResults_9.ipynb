# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Resultados do dataset de 9 vértices

# %%
# configuração:
# [[original, output, otima, total repetição, saidas com pelo menos 1 repetição]]
DecisionTreeRegressor = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{4.433434466019418:.4f}',
        f'{4.0928398058252437:.4f}',
        f'{0}',
        f'{0}'
    ]
])

print('Test length -  16480')

CatBoostRegressor = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.423240291262136:.4f}',
        f'{4.092839805825243:.4f}',
        f'{78379}',
        f'{16480}'
    ]
])

NeuralDecisionTree = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.12876213592233:.4f}',
        f'{4.092839805825243:.4f}',
        f'{78067}',
        f'{16480}'
    ]
])

NeuralDecisionForest = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.417050970873786:.4f}',
        f'{4.092839805825243:.4f}',
        f'{76425}',
        f'{16473}'
    ]
])

PytorchNeuralNetwork = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{4.682539682539683:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{144}',
        f'{61}'
    ]
])

ReverseCuthillMckee = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{4.775:.4f}',
        f'{4.092839805825243:.4f}',
        f'{0}',
        f'{0}'
    ]
])

print('No problema de classificação, se torna um multi-class classification (não confundir com multi-label)')
print('Numero de classes no dataset de trieno - 44195')
print('Numero de classes no dataset de trieno - 9319')

AdjMatrixClassificationCNN = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{4.399332524271845:.4f}',
        f'{4.092839805825243:.4f}',
        f'{0}',
        f'{0}'
    ]
])

data = np.concatenate(
    (
        DecisionTreeRegressor,
        CatBoostRegressor,
        NeuralDecisionTree,
        NeuralDecisionForest,
        PytorchNeuralNetwork,
        ReverseCuthillMckee,
        AdjMatrixClassificationCNN
    )
)

df = pd.DataFrame(
    data,
    index=[
        'DecisionTreeRegressor',
        'CatBoostRegressor',
        'NeuralDecisionTree',
        'NeuralDecisionForest',
        'PytorchNeuralNetwork',
        'ReverseCuthillMckee',
        'AdjMatrixClassificationCNN'
    ],
    columns=[
        'média largura de banda original',
        'média largura de banda produzida pelo modelo',
        'média largura de banda ótima',
        'Total de rótulos repetidos produzidos',
        'Total de saídas com ao menos uma repetição'
    ]
)
print(data)
print("--Resultados para 7 vértices--")
df
# Out:
# Test length -  16480
# No problema de classificação, se torna um multi-class classification (não confundir com multi-label)
# Numero de classes no dataset de trieno - 44195
# Numero de classes no dataset de trieno - 9319
# [['7.7976' '4.4334' '4.0928' '0' '0']
#  ['7.7976' '6.4232' '4.0928' '78379' '16480']
#  ['7.7976' '6.1288' '4.0928' '78067' '16480']
#  ['7.7976' '6.4171' '4.0928' '76425' '16473']
#  ['5.9048' '4.6825' '3.1905' '144' '61']
#  ['7.7976' '4.7750' '4.0928' '0' '0']
#  ['7.7976' '4.3993' '4.0928' '0' '0']]
# --Resultados para 7 vértices--
#                            média largura de banda original  \
# DecisionTreeRegressor                               7.7976
# CatBoostRegressor                                   7.7976
# NeuralDecisionTree                                  7.7976
# NeuralDecisionForest                                7.7976
# PytorchNeuralNetwork                                5.9048
# ReverseCuthillMckee                                 7.7976
# AdjMatrixClassificationCNN                          7.7976
#
#                            média largura de banda produzida pelo modelo  \
# DecisionTreeRegressor                                            4.4334
# CatBoostRegressor                                                6.4232
# NeuralDecisionTree                                               6.1288
# NeuralDecisionForest                                             6.4171
# PytorchNeuralNetwork                                             4.6825
# ReverseCuthillMckee                                              4.7750
# AdjMatrixClassificationCNN                                       4.3993
#
#                            média largura de banda ótima  \
# DecisionTreeRegressor                            4.0928
# CatBoostRegressor                                4.0928
# NeuralDecisionTree                               4.0928
# NeuralDecisionForest                             4.0928
# PytorchNeuralNetwork                             3.1905
# ReverseCuthillMckee                              4.0928
# AdjMatrixClassificationCNN                       4.0928
#
#                            Total de rótulos repetidos produzidos  \
# DecisionTreeRegressor                                          0
# CatBoostRegressor                                          78379
# NeuralDecisionTree                                         78067
# NeuralDecisionForest                                       76425
# PytorchNeuralNetwork                                         144
# ReverseCuthillMckee                                            0
# AdjMatrixClassificationCNN                                     0
#
#                            Total de saídas com ao menos uma repetição
# DecisionTreeRegressor                                               0
# CatBoostRegressor                                               16480
# NeuralDecisionTree                                              16480
# NeuralDecisionForest                                            16473
# PytorchNeuralNetwork                                               61
# ReverseCuthillMckee                                                 0
# AdjMatrixClassificationCNN                                          0

# %%
df.to_latex()
# Out:
# '\\begin{tabular}{llllll}\n\\toprule\n{} & média largura de banda original & média largura de banda produzida pelo modelo & média largura de banda ótima & Total de rótulos repetidos produzidos & Total de saídas com ao menos uma repetição \\\\\n\\midrule\nDecisionTreeRegressor      &                          7.7976 &                                       4.4334 &                       4.0928 &                                     0 &                                          0 \\\\\nCatBoostRegressor          &                          7.7976 &                                       6.4232 &                       4.0928 &                                 78379 &                                      16480 \\\\\nNeuralDecisionTree         &                          7.7976 &                                       6.1288 &                       4.0928 &                                 78067 &                                      16480 \\\\\nNeuralDecisionForest       &                          7.7976 &                                       6.4171 &                       4.0928 &                                 76425 &                                      16473 \\\\\nPytorchNeuralNetwork       &                          5.9048 &                                       4.6825 &                       3.1905 &                                   144 &                                         61 \\\\\nReverseCuthillMckee        &                          7.7976 &                                       4.7750 &                       4.0928 &                                     0 &                                          0 \\\\\nAdjMatrixClassificationCNN &                          7.7976 &                                       4.3993 &                       4.0928 &                                     0 &                                          0 \\\\\n\\bottomrule\n\\end{tabular}\n'
