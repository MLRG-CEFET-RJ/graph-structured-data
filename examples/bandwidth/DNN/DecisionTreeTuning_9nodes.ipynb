# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Resultados do dataset de 9 vértices

# %%
# configuração:
# [[original, output, otima, total repetição, saidas com pelo menos 1 repetição]]
DecisionTreeRegressor2 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.036771844660194:.4f}',
        f'{4.092839805825243:.4f}',
        f'{86615}',
        f'{16480}'
    ]
])

DecisionTreeRegressor4 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.038167475728155:.4f}',
        f'{4.092839805825243:.4f}',
        f'{80427}',
        f'{16480}'
    ]
])

DecisionTreeRegressor6 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.186043689320388:.4f}',
        f'{4.092839805825243:.4f}',
        f'{81651}',
        f'{16480}'
    ]
])

DecisionTreeRegressor8 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.389563106796117:.4f}',
        f'{4.092839805825243:.4f}',
        f'{79338}',
        f'{16479}'
    ]
])

DecisionTreeRegressor10 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.402973300970873:.4f}',
        f'{4.092839805825243:.4f}',
        f'{78208}',
        f'{16461}'
    ]
])

DecisionTreeRegressor12 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.431007281553398:.4f}',
        f'{4.092839805825243:.4f}',
        f'{74326}',
        f'{16362}'
    ]
])

DecisionTreeRegressor14 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.315958737864078:.4f}',
        f'{4.092839805825243:.4f}',
        f'{67783}',
        f'{15833}'
    ]
])

DecisionTreeRegressor16 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{6.089805825242719:.4f}',
        f'{4.092839805825243:.4f}',
        f'{56423}',
        f'{14160}'
    ]
])

DecisionTreeRegressor18 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{5.688531553398058:.4f}',
        f'{4.092839805825243:.4f}',
        f'{40950}',
        f'{11040}'
    ]
])

DecisionTreeRegressor20 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{5.2038228155339805:.4f}',
        f'{4.092839805825243:.4f}',
        f'{24698}',
        f'{6939}'
    ]
])

DecisionTreeRegressor22 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{4.785558252427184:.4f}',
        f'{4.092839805825243:.4f}',
        f'{11088}',
        f'{3272}'
    ]
])
DecisionTreeRegressor24 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{4.533373786407767:.4f}',
        f'{4.092839805825243:.4f}',
        f'{3207}',
        f'{970}'
    ]
])
DecisionTreeRegressor26 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{4.449453883495146:.4f}',
        f'{4.092839805825243:.4f}',
        f'{614}',
        f'{189}'
    ]
])
DecisionTreeRegressor28 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{4.430885922330097:.4f}',
        f'{4.092839805825243:.4f}',
        f'{78}',
        f'{23}'
    ]
])
DecisionTreeRegressor30 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{4.434344660194175:.4f}',
        f'{4.092839805825243:.4f}',
        f'{6}',
        f'{3}'
    ]
])
DecisionTreeRegressor32 = np.array([
    [
        f'{7.7975728155339805:.4f}',
        f'{4.433616504854369:.4f}',
        f'{4.092839805825243:.4f}',
        f'{0}',
        f'{0}'
    ]
])

print('Test length -  16480')
print('Para 9 vértices o max_depth default é 32')

data = np.concatenate(
    (
        DecisionTreeRegressor2,
        DecisionTreeRegressor4,
        DecisionTreeRegressor6,
        DecisionTreeRegressor8,
        DecisionTreeRegressor10,
        DecisionTreeRegressor12,
        DecisionTreeRegressor14,
        DecisionTreeRegressor16,
        DecisionTreeRegressor18,
        DecisionTreeRegressor20,
        DecisionTreeRegressor22,
        DecisionTreeRegressor24,
        DecisionTreeRegressor26,
        DecisionTreeRegressor28,
        DecisionTreeRegressor30,
        DecisionTreeRegressor32
    )
)

df = pd.DataFrame(
    data,
    index=[
        'DecisionTreeRegressor2',
        'DecisionTreeRegressor4',
        'DecisionTreeRegressor6',
        'DecisionTreeRegressor8',
        'DecisionTreeRegressor10',
        'DecisionTreeRegressor12',
        'DecisionTreeRegressor14',
        'DecisionTreeRegressor16',
        'DecisionTreeRegressor18',
        'DecisionTreeRegressor20',
        'DecisionTreeRegressor22',
        'DecisionTreeRegressor24',
        'DecisionTreeRegressor26',
        'DecisionTreeRegressor28',
        'DecisionTreeRegressor30',
        'DecisionTreeRegressor32'
    ],
    columns=[
        'média largura de banda original',
        'média largura de banda produzida pelo modelo',
        'média largura de banda ótima',
        'Total de rótulos repetidos produzidos',
        'Total de saídas com ao menos uma repetição'
    ]
)
print(data)
print("--Resultados para 7 vértices--")
df
# Out:
# Test length -  16480
# Para 9 vértices o max_depth default é 32
# [['7.7976' '6.0368' '4.0928' '86615' '16480']
#  ['7.7976' '6.0382' '4.0928' '80427' '16480']
#  ['7.7976' '6.1860' '4.0928' '81651' '16480']
#  ['7.7976' '6.3896' '4.0928' '79338' '16479']
#  ['7.7976' '6.4030' '4.0928' '78208' '16461']
#  ['7.7976' '6.4310' '4.0928' '74326' '16362']
#  ['7.7976' '6.3160' '4.0928' '67783' '15833']
#  ['7.7976' '6.0898' '4.0928' '56423' '14160']
#  ['7.7976' '5.6885' '4.0928' '40950' '11040']
#  ['7.7976' '5.2038' '4.0928' '24698' '6939']
#  ['7.7976' '4.7856' '4.0928' '11088' '3272']
#  ['7.7976' '4.5334' '4.0928' '3207' '970']
#  ['7.7976' '4.4495' '4.0928' '614' '189']
#  ['7.7976' '4.4309' '4.0928' '78' '23']
#  ['7.7976' '4.4343' '4.0928' '6' '3']
#  ['7.7976' '4.4336' '4.0928' '0' '0']]
# --Resultados para 7 vértices--
#                         média largura de banda original  \
# DecisionTreeRegressor2                           7.7976
# ...

# %%
df.to_latex()
# Out:
# '\\begin{tabular}{llllll}\n\\toprule\n{} & média largura de banda original & média largura de banda produzida pelo modelo & média largura de banda ótima & Total de rótulos repetidos produzidos & Total de saídas com ao menos uma repetição \\\\\n\\midrule\nDecisionTreeRegressor2  &                          7.7976 &                                       6.0368 &                       4.0928 &                                 86615 &                                      16480 \\\\\nDecisionTreeRegressor4  &                          7.7976 &                                       6.0382 &                       4.0928 &                                 80427 &                                      16480 \\\\\nDecisionTreeRegressor6  &                          7.7976 &                                       6.1860 &                       4.0928 &                                 81651 &                                      16480 \\\\\nDecisionTreeRegressor8  &                          7.7976 &   
# ...
