# %%
import pandas as pd
import numpy as np

# %%
# configuração:
# [[original, output, otima, total repetição, saidas com pelo menos 1 repetição]]
DecisionRegressionTree = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.634920634920635:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

CatBoostRegressor = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{4.73015873015873:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{210}',
        f'{62}'
    ]
])

NeuralDecisionTree = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{4.619047619047619:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{229}',
        f'{63}'
    ]
])

NeuralDecisionForest = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{4.841269841269841:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{187}',
        f'{62}'
    ]
])

PytorchNeuralNetwork = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{4.682539682539683:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{144}',
        f'{61}'
    ]
])

ReverseCuthillMckee = np.array([
    [
        f'{5.904761904761905:.4f}',
        f'{3.4126984126984126:.4f}',
        f'{3.1904761904761907:.4f}',
        f'{0}',
        f'{0}'
    ]
])

data = np.concatenate(
    (
        DecisionRegressionTree,
        CatBoostRegressor,
        NeuralDecisionTree,
        NeuralDecisionForest,
        PytorchNeuralNetwork,
        ReverseCuthillMckee
    )
)

df = pd.DataFrame(
    data,
    index=[
        'DecisionRegressionTree',
        'CatBoostRegressor',
        'NeuralDecisionTree',
        'NeuralDecisionForest',
        'PytorchNeuralNetwork',
        'ReverseCuthillMckee'
    ],
    columns=[
        'média largura de banda original',
        'média largura de banda produzida pelo modelo',
        'média largura de banda ótima',
        'Total de rótulos repetidos produzidos',
        'Total de saídas com ao menos uma repetição'
    ]
)
print(data)
print("--Resultados para 7 vértices--")
df
# Out:
# [['5.9048' '3.6349' '3.1905' '0' '0']
#  ['5.9048' '4.7302' '3.1905' '210' '62']
#  ['5.9048' '4.8730' '3.1905' '229' '63']
#  ['5.9048' '4.7619' '3.1905' '187' '62']
#  ['5.9048' '4.6825' '3.1905' '144' '61']
#  ['5.9048' '3.4127' '3.1905' '0' '0']]
# --Resultados para 7 vértices--
#                        média largura de banda original  \
# DecisionRegressionTree                          5.9048
# CatBoostRegressor                               5.9048
# NeuralDecisionTree                              5.9048
# NeuralDecisionForest                            5.9048
# PytorchNeuralNetwork                            5.9048
# ReverseCuthillMckee                             5.9048
#
#                        média largura de banda produzida pelo modelo  \
# DecisionRegressionTree                                       3.6349
# CatBoostRegressor                                            4.7302
# NeuralDecisionTree                                           4.8730
# NeuralDecisionForest                                         4.7619
# PytorchNeuralNetwork                                         4.6825
# ReverseCuthillMckee                                          3.4127
#
#                        média largura de banda ótima  \
# DecisionRegressionTree                       3.1905
# CatBoostRegressor                            3.1905
# NeuralDecisionTree                           3.1905
# NeuralDecisionForest                         3.1905
# PytorchNeuralNetwork                         3.1905
# ReverseCuthillMckee                          3.1905
#
#                        Total de rótulos repetidos produzidos  \
# DecisionRegressionTree                                     0
# CatBoostRegressor                                        210
# NeuralDecisionTree                                       229
# NeuralDecisionForest                                     187
# PytorchNeuralNetwork                                     144
# ReverseCuthillMckee                                        0
#
#                        Total de saídas com ao menos uma repetição
# DecisionRegressionTree                                          0
# CatBoostRegressor                                              62
# NeuralDecisionTree                                             63
# NeuralDecisionForest                                           62
# PytorchNeuralNetwork                                           61
# ReverseCuthillMckee                                             0

# %%
df.to_latex()
# Out:
# '\\begin{tabular}{llllll}\n\\toprule\n{} & média largura de banda original & média largura de banda produzida pelo modelo & média largura de banda ótima & Total de rótulos repetidos produzidos & Total de saídas com ao menos uma repetição \\\\\n\\midrule\nDecisionRegressionTree &                          5.9048 &                                       3.6349 &                       3.1905 &                                     0 &                                          0 \\\\\nCatBoostRegressor      &                          5.9048 &                                       4.7302 &                       3.1905 &                                   210 &                                         62 \\\\\nNeuralDecisionTree     &                          5.9048 &                                       4.8730 &                       3.1905 &                                   229 &                                         63 \\\\\nNeuralDecisionForest   &                          5.9048 &                                       4.7619 &                       3.1905 &                                   187 &                                         62 \\\\\nPytorchNeuralNetwork   &                          5.9048 &                                       4.6825 &                       3.1905 &                                   144 &                                         61 \\\\\nReverseCuthillMckee    &                          5.9048 &                                       3.4127 &                       3.1905 &                                     0 &                                          0 \\\\\n\\bottomrule\n\\end{tabular}\n'
