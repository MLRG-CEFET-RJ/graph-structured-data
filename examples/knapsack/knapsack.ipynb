# %% [markdown]
# # Knapsack problem
#
# Given a list of items and a knapsack capacity, find the maximum profit that this knapsack can carry. Each item contains a value and a weight, the goal is select items to maximize the combined value (sum of all items values selected) in a way that the selected items weights combined do not overspace the capacity of the knapsack.
#
# There are some approaches to tackle this problem, this notebook uses the following:
#
# - brute force
# - dynamic programming
# - neural knapsack

# %% [markdown]
# ## Brute force
#
# it consists in ....

# %%
# code brute force
# TODO

# %% [markdown]
# ## Dynamic programming
#
# This method builds a matrix containing possible knapsack configurations. The last digit in the matrix (last row and last column) holds the maximum profit arrangement, since the algorithm choose the maximum value, between adding the current item or just use repeat the last configuration.
#
# Space time complexity - O(items*capacity)

# %%
# code dynamic programming
capacity = 50
items = [[60, 10], [100, 20], [120, 30]]

def getIndicesItems(values, items):
	indices = []
	i = len(values) - 1
	j = len(values[i]) - 1
	while i > 0:
		if values[i][j] != values[i - 1][j]:
			# Remember, comparing to items array we got an extra [] item
			indices.append(i - 1)
			wItem = items[i - 1][1]
			j -= wItem
		i -= 1
	return indices

def knapsackProblem(items, capacity):
	values = [[0 for _ in range(capacity + 1)] for _ in range(len(items) + 1)]
	for i in range(1, len(values)):
		for j in range(len(values[i])):
			currentItem = items[i - 1] # because we have an [] extra item
			v, w = currentItem
			if w <= j:
				previousValue = values[i - 1][j]
				currentValue = values[i - 1][j - w] + v
				values[i][j] = max(previousValue, currentValue)
			else:
				values[i][j] = values[i - 1][j]
	indices = getIndicesItems(values, items)
	combinedValue = sum([items[i][0] for i in indices])
	return [combinedValue, indices]

knapsackProblem(items, capacity)
# Out:
# [220, [2, 1]]

# %% [markdown]
# ## Neural knapsack
#
# Code based on the article "Neural Knapsack", by Shayan Hashemi
#
# Supervised learning approach.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Concatenate
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.metrics import binary_accuracy, binary_crossentropy
import tensorflow.keras.backend as K
import pandas as pd
tf.compat.v1.disable_eager_execution()
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2
# INFO:tensorflow:Disabling eager execution

# %%
def brute_force_knapsack(x_weights, x_prices, x_capacity):
    item_count = x_weights.shape[0]
    picks_space = 2 ** item_count
    best_price = -1
    best_picks = np.zeros(item_count)
    for p in range(picks_space):
        picks = [int(c) for c in f"{p:0{item_count}b}"]
        price = np.dot(x_prices, picks)
        weight = np.dot(x_weights, picks)
        if weight <= x_capacity and price > best_price:
            best_price = price
            best_picks = picks
    return best_picks


def create_knapsack(item_count=5):
    x_weights = np.random.randint(1, 45, item_count)
    x_prices = np.random.randint(1, 99, item_count)
    x_capacity = np.random.randint(1, 99)
    y = brute_force_knapsack(x_weights, x_prices, x_capacity)
    return x_weights, x_prices, x_capacity, y
x_weights, x_prices, x_capacity, y = create_knapsack()
print("Weights:")
print(x_weights)
print("Prices:")
print(x_prices)
print("Capacity:")
print(x_capacity)
print("Optimum solution: ")
print(y)
print("\nData normalized to be passed into the neural newtork:\n")
x_weights = x_weights / x_capacity
print("Weights:")
print(x_weights)
x_prices = x_prices / max(x_prices)
print("Prices:")
print(x_prices)
print(y)
# Out:
# Weights:
# [17  3 10 32 13]
# Prices:
# [ 6 95 60 92 16]
# Capacity:
# 82
# Optimum solution:
# [1, 1, 1, 1, 1]
#
# Data normalized to be passed into the neural newtork:
#
# Weights:
# [0.20731707 0.03658537 0.12195122 0.3902439  0.15853659]
# Prices:
# [0.06315789 1.         0.63157895 0.96842105 0.16842105]
# [1, 1, 1, 1, 1]

# %%
samples_training = 9000
samples_testing = 1000

def build_dataset(samples, filename):
  data =  []
  for i in range(samples):
    x_weights, x_prices, x_capacity, y = create_knapsack()
    # normalize data
    x_weights = x_weights / x_capacity
    x_prices = x_prices / max(x_prices)
    row = np.concatenate((x_weights, x_prices, y))
    data.append(row)
  df = pd.DataFrame(data, columns=('w0', 'w1', 'w2', 'w3', 'w4', 'p0', 'p1', 'p2', 'p3', 'p4', 'y0', 'y1', 'y2', 'y3', 'y4'))
  csv_text = df.to_csv(index=False, line_terminator='\n')
  with open(filename, 'w') as writer:
    writer.write(csv_text)

build_dataset(samples_training, 'knapsack_train_dataset.csv')
build_dataset(samples_testing, 'knapsack_test_dataset.csv')

# %%
def get_dataset(dataset_csv):
  df = pd.read_csv(dataset_csv)
  x_weights_df = df[['w0', 'w1', 'w2', 'w3', 'w4']]
  x_prices_df = df[['p0', 'p1', 'p2', 'p3', 'p4']]
  y_df = df[['y0', 'y1', 'y2', 'y3', 'y4']]
  # x_weights = tf.convert_to_tensor(x_weights_df)
  x_weights = x_weights_df.to_numpy()
  # x_prices = tf.convert_to_tensor(x_prices_df)
  x_prices = x_prices_df.to_numpy()
  # y = tf.convert_to_tensor(y_df)
  y = y_df.to_numpy()
  return [x_weights, x_prices], y

x_train, y_train = get_dataset('./knapsack_train_dataset.csv')
x_test, y_test = get_dataset('./knapsack_test_dataset.csv')

# %%
def get_model(item_count=5):
    input_weights = Input((item_count,))
    input_prices = Input((item_count,))
    inputs_concat = Concatenate()([input_weights, input_prices])
    picks = Dense(35, activation="sigmoid")(inputs_concat)
    picks = Dense(item_count, activation="sigmoid")(picks)
    model = Model(inputs=[input_weights, input_prices], outputs=[picks])
    model.compile(
        'adam',
        tf.keras.losses.binary_crossentropy,
        metrics = [
          tf.keras.metrics.binary_accuracy,
          metric_space_violation(input_weights),
          metric_overprice(input_prices)
          ]
    )
    return model

def get_model_test2():
  model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(35, activation='sigmoid'),
    tf.keras.layers.Dense(5, activation='sigmoid')
  ])
  return model

# %%
def metric_overprice(input_prices):
    def overpricing(y_true, y_pred):
        y_pred = K.round(y_pred)
        return K.mean(K.batch_dot(y_pred, input_prices, 1) - K.batch_dot(y_true, input_prices, 1))
    return overpricing
def metric_space_violation(input_weights):
    def space_violation(y_true, y_pred):
        y_pred = K.round(y_pred)
        return K.mean(K.maximum(K.batch_dot(y_pred, input_weights, 1) - 1, 0))

    return space_violation

# %%
model = get_model()

# %%
model.fit(x_train, y_train, epochs=512, verbose=2)
# Out:
# Train on 9000 samples
# Epoch 1/512
# 9000/9000 - 0s - loss: 0.6496 - binary_accuracy: 0.6623 - space_violation: 1.0878 - overpricing: 0.4083
# Epoch 2/512
# 9000/9000 - 0s - loss: 0.5653 - binary_accuracy: 0.7250 - space_violation: 0.4360 - overpricing: 0.2965
# Epoch 3/512
# 9000/9000 - 0s - loss: 0.5200 - binary_accuracy: 0.7480 - space_violation: 0.3484 - overpricing: 0.2328
# Epoch 4/512
# 9000/9000 - 0s - loss: 0.4809 - binary_accuracy: 0.7746 - space_violation: 0.2744 - overpricing: 0.2086
# Epoch 5/512
# 9000/9000 - 0s - loss: 0.4436 - binary_accuracy: 0.8040 - space_violation: 0.2076 - overpricing: 0.1953
# Epoch 6/512
# 9000/9000 - 0s - loss: 0.4105 - binary_accuracy: 0.8285 - space_violation: 0.1614 - overpricing: 0.1848
# Epoch 7/512
# 9000/9000 - 0s - loss: 0.3839 - binary_accuracy: 0.8423 - space_violation: 0.1355 - overpricing: 0.1733
# Epoch 8/512
# 9000/9000 - 0s - loss: 0.3631 - binary_accuracy: 0.8510 - space_violation: 0.1223 - overpricing: 0.1626
# Epoch 9/512
# 9000/9000 - 0s - loss: 0.3473 - binary_accuracy: 0.8551 - space_violation: 0.1139 - overpricing: 0.1537
# Epoch 10/512
# 9000/9000 - 0s - loss: 0.3353 - binary_accuracy: 0.8575 - space_violation: 0.1087 - overpricing: 0.1442
# Epoch 11/512
# 9000/9000 - 0s - loss: 0.3261 - binary_accuracy: 0.8601 - space_violation: 0.1047 - overpricing: 0.1379
# Epoch 12/512
# 9000/9000 - 0s - loss: 0.3190 - binary_accuracy: 0.8618 - space_violation: 0.1041 - overpricing: 0.1323
# Epoch 13/512
# 9000/9000 - 0s - loss: 0.3132 - binary_accuracy: 0.8633 - space_violation: 0.0962 - overpricing: 0.1205
# Epoch 14/512
# 9000/9000 - 0s - loss: 0.3087 - binary_accuracy: 0.8640 - space_violation: 0.0914 - overpricing: 0.1123
# Epoch 15/512
# 9000/9000 - 0s - loss: 0.3049 - binary_accuracy: 0.8653 - space_violation: 0.0881 - overpricing: 0.1078
# Epoch 16/512
# 9000/9000 - 0s - loss: 0.3020 - binary_accuracy: 0.8652 - space_violation: 0.0874 - overpricing: 0.1057
# Epoch 17/512
# 9000/9000 - 0s - loss: 0.2995 - binary_accuracy: 0.8656 - space_violation: 0.0851 - overpricing: 0.0979
# Epoch 18/512
# 9000/9000 - 0s - loss: 0.2971 - binary_accuracy: 0.8660 - space_violation: 0.0819 - overpricing: 0.0935
# Epoch 19/512
# 9000/9000 - 0s - loss: 0.2954 - binary_accuracy: 0.8670 - space_violation: 0.0816 - overpricing: 0.0940
# Epoch 20/512
# 9000/9000 - 0s - loss: 0.2937 - binary_accuracy: 0.8672 - space_violation: 0.0810 - overpricing: 0.0884
# Epoch 21/512
# 9000/9000 - 0s - loss: 0.2926 - binary_accuracy: 0.8670 - space_violation: 0.0791 - overpricing: 0.0860
# Epoch 22/512
# 9000/9000 - 0s - loss: 0.2911 - binary_accuracy: 0.8678 - space_violation: 0.0784 - overpricing: 0.0862
# Epoch 23/512
# 9000/9000 - 0s - loss: 0.2901 - binary_accuracy: 0.8675 - space_violation: 0.0776 - overpricing: 0.0824
# Epoch 24/512
# 9000/9000 - 0s - loss: 0.2892 - binary_accuracy: 0.8679 - space_violation: 0.0775 - overpricing: 0.0819
# Epoch 25/512
# 9000/9000 - 0s - loss: 0.2882 - binary_accuracy: 0.8685 - space_violation: 0.0778 - overpricing: 0.0852
# Epoch 26/512
# 9000/9000 - 0s - loss: 0.2874 - binary_accuracy: 0.8687 - space_violation: 0.0760 - overpricing: 0.0780
# Epoch 27/512
# 9000/9000 - 0s - loss: 0.2866 - binary_accuracy: 0.8693 - space_violation: 0.0743 - overpricing: 0.0770
# Epoch 28/512
# 9000/9000 - 0s - loss: 0.2859 - binary_accuracy: 0.8694 - space_violation: 0.0755 - overpricing: 0.0772
# Epoch 29/512
# 9000/9000 - 0s - loss: 0.2852 - binary_accuracy: 0.8695 - space_violation: 0.0742 - overpricing: 0.0762
# Epoch 30/512
# 9000/9000 - 0s - loss: 0.2847 - binary_accuracy: 0.8700 - space_violation: 0.0726 - overpricing: 0.0739
# Epoch 31/512
# 9000/9000 - 0s - loss: 0.2839 - binary_accuracy: 0.8701 - space_violation: 0.0739 - overpricing: 0.0769
# Epoch 32/512
# 9000/9000 - 0s - loss: 0.2835 - binary_accuracy: 0.8706 - space_violation: 0.0713 - overpricing: 0.0720
# Epoch 33/512
# 9000/9000 - 0s - loss: 0.2830 - binary_accuracy: 0.8702 - space_violation: 0.0704 - overpricing: 0.0708
# Epoch 34/512
# 9000/9000 - 0s - loss: 0.2823 - binary_accuracy: 0.8708 - space_violation: 0.0718 - overpricing: 0.0747
# Epoch 35/512
# 9000/9000 - 0s - loss: 0.2817 - binary_accuracy: 0.8717 - space_violation: 0.0678 - overpricing: 0.0715
# Epoch 36/512
# 9000/9000 - 0s - loss: 0.2814 - binary_accuracy: 0.8713 - space_violation: 0.0683 - overpricing: 0.0705
# Epoch 37/512
# 9000/9000 - 0s - loss: 0.2809 - binary_accuracy: 0.8721 - space_violation: 0.0691 - overpricing: 0.0728
# Epoch 38/512
# 9000/9000 - 0s - loss: 0.2804 - binary_accuracy: 0.8720 - space_violation: 0.0683 - overpricing: 0.0706
# Epoch 39/512
# 9000/9000 - 0s - loss: 0.2798 - binary_accuracy: 0.8725 - space_violation: 0.0658 - overpricing: 0.0699
# Epoch 40/512
# 9000/9000 - 0s - loss: 0.2794 - binary_accuracy: 0.8730 - space_violation: 0.0662 - overpricing: 0.0713
# Epoch 41/512
# 9000/9000 - 0s - loss: 0.2793 - binary_accuracy: 0.8736 - space_violation: 0.0639 - overpricing: 0.0684
# Epoch 42/512
# 9000/9000 - 0s - loss: 0.2786 - binary_accuracy: 0.8735 - space_violation: 0.0649 - overpricing: 0.0688
# Epoch 43/512
# 9000/9000 - 0s - loss: 0.2783 - binary_accuracy: 0.8729 - space_violation: 0.0628 - overpricing: 0.0673
# Epoch 44/512
# 9000/9000 - 0s - loss: 0.2780 - binary_accuracy: 0.8738 - space_violation: 0.0638 - overpricing: 0.0689
# Epoch 45/512
# 9000/9000 - 0s - loss: 0.2776 - binary_accuracy: 0.8734 - space_violation: 0.0626 - overpricing: 0.0670
# Epoch 46/512
# 9000/9000 - 0s - loss: 0.2774 - binary_accuracy: 0.8740 - space_violation: 0.0619 - overpricing: 0.0675
# Epoch 47/512
# 9000/9000 - 0s - loss: 0.2770 - binary_accuracy: 0.8741 - space_violation: 0.0618 - overpricing: 0.0670
# Epoch 48/512
# 9000/9000 - 0s - loss: 0.2765 - binary_accuracy: 0.8744 - space_violation: 0.0614 - overpricing: 0.0687
# Epoch 49/512
# 9000/9000 - 0s - loss: 0.2762 - binary_accuracy: 0.8745 - space_violation: 0.0619 - overpricing: 0.0674
# Epoch 50/512
# 9000/9000 - 0s - loss: 0.2760 - binary_accuracy: 0.8745 - space_violation: 0.0608 - overpricing: 0.0668
# Epoch 51/512
# 9000/9000 - 0s - loss: 0.2756 - binary_accuracy: 0.8750 - space_violation: 0.0617 - overpricing: 0.0686
# Epoch 52/512
# 9000/9000 - 0s - loss: 0.2754 - binary_accuracy: 0.8750 - space_violation: 0.0595 - overpricing: 0.0637
# Epoch 53/512
# 9000/9000 - 0s - loss: 0.2750 - binary_accuracy: 0.8753 - space_violation: 0.0594 - overpricing: 0.0667
# Epoch 54/512
# 9000/9000 - 0s - loss: 0.2746 - binary_accuracy: 0.8754 - space_violation: 0.0600 - overpricing: 0.0657
# Epoch 55/512
# 9000/9000 - 0s - loss: 0.2745 - binary_accuracy: 0.8757 - space_violation: 0.0599 - overpricing: 0.0662
# Epoch 56/512
# 9000/9000 - 0s - loss: 0.2741 - binary_accuracy: 0.8761 - space_violation: 0.0589 - overpricing: 0.0668
# Epoch 57/512
# 9000/9000 - 0s - loss: 0.2739 - binary_accuracy: 0.8759 - space_violation: 0.0588 - overpricing: 0.0657
# Epoch 58/512
# 9000/9000 - 0s - loss: 0.2736 - binary_accuracy: 0.8756 - space_violation: 0.0573 - overpricing: 0.0621
# Epoch 59/512
# 9000/9000 - 0s - loss: 0.2733 - binary_accuracy: 0.8762 - space_violation: 0.0573 - overpricing: 0.0626
# Epoch 60/512
# 9000/9000 - 0s - loss: 0.2731 - binary_accuracy: 0.8763 - space_violation: 0.0581 - overpricing: 0.0643
# Epoch 61/512
# 9000/9000 - 0s - loss: 0.2729 - binary_accuracy: 0.8762 - space_violation: 0.0573 - overpricing: 0.0637
# Epoch 62/512
# 9000/9000 - 0s - loss: 0.2726 - binary_accuracy: 0.8768 - space_violation: 0.0574 - overpricing: 0.0635
# Epoch 63/512
# 9000/9000 - 0s - loss: 0.2723 - binary_accuracy: 0.8761 - space_violation: 0.0583 - overpricing: 0.0649
# Epoch 64/512
# 9000/9000 - 0s - loss: 0.2722 - binary_accuracy: 0.8762 - space_violation: 0.0565 - overpricing: 0.0631
# Epoch 65/512
# 9000/9000 - 0s - loss: 0.2719 - binary_accuracy: 0.8767 - space_violation: 0.0573 - overpricing: 0.0661
# Epoch 66/512
# 9000/9000 - 0s - loss: 0.2715 - binary_accuracy: 0.8772 - space_violation: 0.0572 - overpricing: 0.0663
# Epoch 67/512
# 9000/9000 - 0s - loss: 0.2714 - binary_accuracy: 0.8770 - space_violation: 0.0558 - overpricing: 0.0626
# Epoch 68/512
# 9000/9000 - 0s - loss: 0.2713 - binary_accuracy: 0.8773 - space_violation: 0.0566 - overpricing: 0.0633
# Epoch 69/512
# 9000/9000 - 0s - loss: 0.2708 - binary_accuracy: 0.8780 - space_violation: 0.0562 - overpricing: 0.0634
# Epoch 70/512
# 9000/9000 - 0s - loss: 0.2708 - binary_accuracy: 0.8782 - space_violation: 0.0559 - overpricing: 0.0630
# Epoch 71/512
# 9000/9000 - 0s - loss: 0.2705 - binary_accuracy: 0.8775 - space_violation: 0.0565 - overpricing: 0.0652
# Epoch 72/512
# 9000/9000 - 0s - loss: 0.2705 - binary_accuracy: 0.8776 - space_violation: 0.0558 - overpricing: 0.0640
# Epoch 73/512
# 9000/9000 - 0s - loss: 0.2701 - binary_accuracy: 0.8784 - space_violation: 0.0548 - overpricing: 0.0617
# Epoch 74/512
# 9000/9000 - 0s - loss: 0.2699 - binary_accuracy: 0.8776 - space_violation: 0.0552 - overpricing: 0.0617
# Epoch 75/512
# 9000/9000 - 0s - loss: 0.2698 - binary_accuracy: 0.8779 - space_violation: 0.0556 - overpricing: 0.0654
# Epoch 76/512
# 9000/9000 - 0s - loss: 0.2695 - binary_accuracy: 0.8789 - space_violation: 0.0542 - overpricing: 0.0621
# Epoch 77/512
# 9000/9000 - 0s - loss: 0.2692 - binary_accuracy: 0.8789 - space_violation: 0.0540 - overpricing: 0.0605
# Epoch 78/512
# 9000/9000 - 0s - loss: 0.2691 - binary_accuracy: 0.8785 - space_violation: 0.0543 - overpricing: 0.0620
# Epoch 79/512
# 9000/9000 - 0s - loss: 0.2690 - binary_accuracy: 0.8783 - space_violation: 0.0546 - overpricing: 0.0617
# Epoch 80/512
# 9000/9000 - 0s - loss: 0.2687 - binary_accuracy: 0.8784 - space_violation: 0.0538 - overpricing: 0.0620
# Epoch 81/512
# 9000/9000 - 0s - loss: 0.2685 - binary_accuracy: 0.8789 - space_violation: 0.0536 - overpricing: 0.0608
# Epoch 82/512
# 9000/9000 - 0s - loss: 0.2685 - binary_accuracy: 0.8781 - space_violation: 0.0541 - overpricing: 0.0618
# Epoch 83/512
# 9000/9000 - 0s - loss: 0.2682 - binary_accuracy: 0.8792 - space_violation: 0.0534 - overpricing: 0.0621
# Epoch 84/512
# 9000/9000 - 0s - loss: 0.2682 - binary_accuracy: 0.8793 - space_violation: 0.0536 - overpricing: 0.0621
# Epoch 85/512
# 9000/9000 - 0s - loss: 0.2680 - binary_accuracy: 0.8788 - space_violation: 0.0538 - overpricing: 0.0630
# Epoch 86/512
# 9000/9000 - 0s - loss: 0.2677 - binary_accuracy: 0.8796 - space_violation: 0.0527 - overpricing: 0.0601
# Epoch 87/512
# 9000/9000 - 0s - loss: 0.2674 - binary_accuracy: 0.8798 - space_violation: 0.0537 - overpricing: 0.0640
# Epoch 88/512
# 9000/9000 - 0s - loss: 0.2675 - binary_accuracy: 0.8792 - space_violation: 0.0523 - overpricing: 0.0597
# Epoch 89/512
# 9000/9000 - 0s - loss: 0.2672 - binary_accuracy: 0.8805 - space_violation: 0.0512 - overpricing: 0.0588
# Epoch 90/512
# 9000/9000 - 0s - loss: 0.2670 - binary_accuracy: 0.8796 - space_violation: 0.0530 - overpricing: 0.0606
# Epoch 91/512
# 9000/9000 - 0s - loss: 0.2670 - binary_accuracy: 0.8802 - space_violation: 0.0518 - overpricing: 0.0607
# Epoch 92/512
# 9000/9000 - 0s - loss: 0.2667 - binary_accuracy: 0.8798 - space_violation: 0.0527 - overpricing: 0.0621
# Epoch 93/512
# 9000/9000 - 0s - loss: 0.2666 - binary_accuracy: 0.8799 - space_violation: 0.0522 - overpricing: 0.0630
# Epoch 94/512
# 9000/9000 - 0s - loss: 0.2664 - binary_accuracy: 0.8803 - space_violation: 0.0522 - overpricing: 0.0618
# Epoch 95/512
# 9000/9000 - 0s - loss: 0.2662 - binary_accuracy: 0.8803 - space_violation: 0.0521 - overpricing: 0.0604
# Epoch 96/512
# 9000/9000 - 0s - loss: 0.2660 - binary_accuracy: 0.8804 - space_violation: 0.0519 - overpricing: 0.0616
# Epoch 97/512
# 9000/9000 - 0s - loss: 0.2659 - binary_accuracy: 0.8804 - space_violation: 0.0515 - overpricing: 0.0625
# Epoch 98/512
# 9000/9000 - 0s - loss: 0.2658 - binary_accuracy: 0.8807 - space_violation: 0.0513 - overpricing: 0.0614
# Epoch 99/512
# 9000/9000 - 0s - loss: 0.2656 - binary_accuracy: 0.8809 - space_violation: 0.0515 - overpricing: 0.0608
# Epoch 100/512
# 9000/9000 - 0s - loss: 0.2655 - binary_accuracy: 0.8805 - space_violation: 0.0514 - overpricing: 0.0611
# Epoch 101/512
# 9000/9000 - 0s - loss: 0.2654 - binary_accuracy: 0.8804 - space_violation: 0.0514 - overpricing: 0.0607
# Epoch 102/512
# 9000/9000 - 0s - loss: 0.2653 - binary_accuracy: 0.8811 - space_violation: 0.0513 - overpricing: 0.0616
# Epoch 103/512
# 9000/9000 - 0s - loss: 0.2652 - binary_accuracy: 0.8810 - space_violation: 0.0512 - overpricing: 0.0619
# Epoch 104/512
# 9000/9000 - 0s - loss: 0.2648 - binary_accuracy: 0.8805 - space_violation: 0.0497 - overpricing: 0.0581
# Epoch 105/512
# 9000/9000 - 0s - loss: 0.2648 - binary_accuracy: 0.8812 - space_violation: 0.0508 - overpricing: 0.0619
# Epoch 106/512
# 9000/9000 - 0s - loss: 0.2647 - binary_accuracy: 0.8812 - space_violation: 0.0512 - overpricing: 0.0614
# Epoch 107/512
# 9000/9000 - 0s - loss: 0.2645 - binary_accuracy: 0.8813 - space_violation: 0.0508 - overpricing: 0.0617
# Epoch 108/512
# 9000/9000 - 0s - loss: 0.2643 - binary_accuracy: 0.8816 - space_violation: 0.0506 - overpricing: 0.0620
# Epoch 109/512
# 9000/9000 - 0s - loss: 0.2642 - binary_accuracy: 0.8817 - space_violation: 0.0495 - overpricing: 0.0590
# Epoch 110/512
# 9000/9000 - 0s - loss: 0.2640 - binary_accuracy: 0.8813 - space_violation: 0.0500 - overpricing: 0.0591
# Epoch 111/512
# 9000/9000 - 0s - loss: 0.2639 - binary_accuracy: 0.8818 - space_violation: 0.0493 - overpricing: 0.0580
# Epoch 112/512
# 9000/9000 - 0s - loss: 0.2638 - binary_accuracy: 0.8816 - space_violation: 0.0488 - overpricing: 0.0582
# Epoch 113/512
# 9000/9000 - 0s - loss: 0.2637 - binary_accuracy: 0.8826 - space_violation: 0.0496 - overpricing: 0.0609
# Epoch 114/512
# 9000/9000 - 0s - loss: 0.2635 - binary_accuracy: 0.8817 - space_violation: 0.0499 - overpricing: 0.0617
# Epoch 115/512
# 9000/9000 - 0s - loss: 0.2634 - binary_accuracy: 0.8816 - space_violation: 0.0496 - overpricing: 0.0599
# Epoch 116/512
# 9000/9000 - 0s - loss: 0.2634 - binary_accuracy: 0.8819 - space_violation: 0.0492 - overpricing: 0.0592
# Epoch 117/512
# 9000/9000 - 0s - loss: 0.2631 - binary_accuracy: 0.8826 - space_violation: 0.0496 - overpricing: 0.0615
# Epoch 118/512
# 9000/9000 - 0s - loss: 0.2630 - binary_accuracy: 0.8823 - space_violation: 0.0490 - overpricing: 0.0612
# Epoch 119/512
# 9000/9000 - 0s - loss: 0.2631 - binary_accuracy: 0.8826 - space_violation: 0.0487 - overpricing: 0.0579
# Epoch 120/512
# 9000/9000 - 0s - loss: 0.2628 - binary_accuracy: 0.8824 - space_violation: 0.0494 - overpricing: 0.0604
# Epoch 121/512
# 9000/9000 - 0s - loss: 0.2627 - binary_accuracy: 0.8824 - space_violation: 0.0494 - overpricing: 0.0605
# Epoch 122/512
# 9000/9000 - 0s - loss: 0.2626 - binary_accuracy: 0.8825 - space_violation: 0.0495 - overpricing: 0.0607
# Epoch 123/512
# 9000/9000 - 0s - loss: 0.2624 - binary_accuracy: 0.8821 - space_violation: 0.0498 - overpricing: 0.0612
# Epoch 124/512
# 9000/9000 - 0s - loss: 0.2623 - binary_accuracy: 0.8828 - space_violation: 0.0483 - overpricing: 0.0589
# Epoch 125/512
# 9000/9000 - 0s - loss: 0.2623 - binary_accuracy: 0.8824 - space_violation: 0.0487 - overpricing: 0.0576
# Epoch 126/512
# 9000/9000 - 0s - loss: 0.2620 - binary_accuracy: 0.8836 - space_violation: 0.0482 - overpricing: 0.0585
# Epoch 127/512
# 9000/9000 - 0s - loss: 0.2620 - binary_accuracy: 0.8830 - space_violation: 0.0488 - overpricing: 0.0607
# Epoch 128/512
# 9000/9000 - 0s - loss: 0.2619 - binary_accuracy: 0.8828 - space_violation: 0.0480 - overpricing: 0.0580
# Epoch 129/512
# 9000/9000 - 0s - loss: 0.2618 - binary_accuracy: 0.8827 - space_violation: 0.0486 - overpricing: 0.0598
# Epoch 130/512
# 9000/9000 - 0s - loss: 0.2616 - binary_accuracy: 0.8830 - space_violation: 0.0482 - overpricing: 0.0581
# Epoch 131/512
# 9000/9000 - 0s - loss: 0.2617 - binary_accuracy: 0.8832 - space_violation: 0.0486 - overpricing: 0.0601
# Epoch 132/512
# 9000/9000 - 0s - loss: 0.2615 - binary_accuracy: 0.8832 - space_violation: 0.0492 - overpricing: 0.0611
# Epoch 133/512
# 9000/9000 - 0s - loss: 0.2613 - binary_accuracy: 0.8831 - space_violation: 0.0474 - overpricing: 0.0575
# Epoch 134/512
# 9000/9000 - 0s - loss: 0.2613 - binary_accuracy: 0.8837 - space_violation: 0.0486 - overpricing: 0.0608
# Epoch 135/512
# 9000/9000 - 0s - loss: 0.2612 - binary_accuracy: 0.8835 - space_violation: 0.0484 - overpricing: 0.0598
# Epoch 136/512
# 9000/9000 - 0s - loss: 0.2611 - binary_accuracy: 0.8830 - space_violation: 0.0485 - overpricing: 0.0602
# Epoch 137/512
# 9000/9000 - 0s - loss: 0.2609 - binary_accuracy: 0.8828 - space_violation: 0.0479 - overpricing: 0.0585
# Epoch 138/512
# 9000/9000 - 0s - loss: 0.2609 - binary_accuracy: 0.8839 - space_violation: 0.0479 - overpricing: 0.0593
# Epoch 139/512
# 9000/9000 - 0s - loss: 0.2606 - binary_accuracy: 0.8837 - space_violation: 0.0480 - overpricing: 0.0596
# Epoch 140/512
# 9000/9000 - 0s - loss: 0.2607 - binary_accuracy: 0.8833 - space_violation: 0.0481 - overpricing: 0.0586
# Epoch 141/512
# 9000/9000 - 0s - loss: 0.2605 - binary_accuracy: 0.8840 - space_violation: 0.0472 - overpricing: 0.0578
# Epoch 142/512
# 9000/9000 - 0s - loss: 0.2605 - binary_accuracy: 0.8840 - space_violation: 0.0471 - overpricing: 0.0574
# Epoch 143/512
# 9000/9000 - 0s - loss: 0.2606 - binary_accuracy: 0.8837 - space_violation: 0.0481 - overpricing: 0.0604
# Epoch 144/512
# 9000/9000 - 0s - loss: 0.2601 - binary_accuracy: 0.8834 - space_violation: 0.0480 - overpricing: 0.0600
# Epoch 145/512
# 9000/9000 - 0s - loss: 0.2601 - binary_accuracy: 0.8832 - space_violation: 0.0479 - overpricing: 0.0587
# Epoch 146/512
# 9000/9000 - 0s - loss: 0.2602 - binary_accuracy: 0.8839 - space_violation: 0.0465 - overpricing: 0.0560
# Epoch 147/512
# 9000/9000 - 0s - loss: 0.2601 - binary_accuracy: 0.8839 - space_violation: 0.0481 - overpricing: 0.0595
# Epoch 148/512
# 9000/9000 - 0s - loss: 0.2599 - binary_accuracy: 0.8840 - space_violation: 0.0467 - overpricing: 0.0587
# Epoch 149/512
# 9000/9000 - 0s - loss: 0.2599 - binary_accuracy: 0.8839 - space_violation: 0.0474 - overpricing: 0.0582
# Epoch 150/512
# 9000/9000 - 0s - loss: 0.2597 - binary_accuracy: 0.8844 - space_violation: 0.0473 - overpricing: 0.0592
# Epoch 151/512
# 9000/9000 - 0s - loss: 0.2595 - binary_accuracy: 0.8839 - space_violation: 0.0489 - overpricing: 0.0630
# Epoch 152/512
# 9000/9000 - 0s - loss: 0.2597 - binary_accuracy: 0.8841 - space_violation: 0.0469 - overpricing: 0.0576
# Epoch 153/512
# 9000/9000 - 0s - loss: 0.2595 - binary_accuracy: 0.8840 - space_violation: 0.0473 - overpricing: 0.0595
# Epoch 154/512
# 9000/9000 - 0s - loss: 0.2595 - binary_accuracy: 0.8838 - space_violation: 0.0476 - overpricing: 0.0596
# Epoch 155/512
# 9000/9000 - 0s - loss: 0.2592 - binary_accuracy: 0.8845 - space_violation: 0.0468 - overpricing: 0.0575
# Epoch 156/512
# 9000/9000 - 0s - loss: 0.2593 - binary_accuracy: 0.8841 - space_violation: 0.0471 - overpricing: 0.0581
# Epoch 157/512
# 9000/9000 - 0s - loss: 0.2591 - binary_accuracy: 0.8842 - space_violation: 0.0465 - overpricing: 0.0580
# Epoch 158/512
# 9000/9000 - 0s - loss: 0.2590 - binary_accuracy: 0.8844 - space_violation: 0.0456 - overpricing: 0.0564
# Epoch 159/512
# 9000/9000 - 0s - loss: 0.2589 - binary_accuracy: 0.8844 - space_violation: 0.0459 - overpricing: 0.0569
# Epoch 160/512
# 9000/9000 - 0s - loss: 0.2588 - binary_accuracy: 0.8842 - space_violation: 0.0458 - overpricing: 0.0568
# Epoch 161/512
# 9000/9000 - 0s - loss: 0.2588 - binary_accuracy: 0.8842 - space_violation: 0.0466 - overpricing: 0.0571
# Epoch 162/512
# 9000/9000 - 0s - loss: 0.2587 - binary_accuracy: 0.8847 - space_violation: 0.0462 - overpricing: 0.0581
# Epoch 163/512
# 9000/9000 - 0s - loss: 0.2587 - binary_accuracy: 0.8844 - space_violation: 0.0465 - overpricing: 0.0570
# Epoch 164/512
# 9000/9000 - 0s - loss: 0.2584 - binary_accuracy: 0.8844 - space_violation: 0.0465 - overpricing: 0.0581
# Epoch 165/512
# 9000/9000 - 0s - loss: 0.2584 - binary_accuracy: 0.8847 - space_violation: 0.0466 - overpricing: 0.0591
# Epoch 166/512
# 9000/9000 - 0s - loss: 0.2582 - binary_accuracy: 0.8847 - space_violation: 0.0459 - overpricing: 0.0570
# Epoch 167/512
# 9000/9000 - 0s - loss: 0.2583 - binary_accuracy: 0.8848 - space_violation: 0.0454 - overpricing: 0.0559
# Epoch 168/512
# 9000/9000 - 0s - loss: 0.2581 - binary_accuracy: 0.8850 - space_violation: 0.0468 - overpricing: 0.0591
# Epoch 169/512
# 9000/9000 - 0s - loss: 0.2581 - binary_accuracy: 0.8850 - space_violation: 0.0453 - overpricing: 0.0548
# Epoch 170/512
# 9000/9000 - 0s - loss: 0.2581 - binary_accuracy: 0.8847 - space_violation: 0.0452 - overpricing: 0.0556
# Epoch 171/512
# 9000/9000 - 0s - loss: 0.2578 - binary_accuracy: 0.8853 - space_violation: 0.0456 - overpricing: 0.0567
# Epoch 172/512
# 9000/9000 - 0s - loss: 0.2580 - binary_accuracy: 0.8858 - space_violation: 0.0458 - overpricing: 0.0565
# Epoch 173/512
# 9000/9000 - 0s - loss: 0.2577 - binary_accuracy: 0.8852 - space_violation: 0.0456 - overpricing: 0.0586
# Epoch 174/512
# 9000/9000 - 0s - loss: 0.2577 - binary_accuracy: 0.8854 - space_violation: 0.0459 - overpricing: 0.0555
# Epoch 175/512
# 9000/9000 - 0s - loss: 0.2576 - binary_accuracy: 0.8849 - space_violation: 0.0461 - overpricing: 0.0590
# Epoch 176/512
# 9000/9000 - 0s - loss: 0.2575 - binary_accuracy: 0.8849 - space_violation: 0.0454 - overpricing: 0.0531
# Epoch 177/512
# 9000/9000 - 0s - loss: 0.2574 - binary_accuracy: 0.8856 - space_violation: 0.0459 - overpricing: 0.0610
# Epoch 178/512
# 9000/9000 - 0s - loss: 0.2574 - binary_accuracy: 0.8852 - space_violation: 0.0447 - overpricing: 0.0561
# Epoch 179/512
# 9000/9000 - 0s - loss: 0.2573 - binary_accuracy: 0.8855 - space_violation: 0.0456 - overpricing: 0.0567
# Epoch 180/512
# 9000/9000 - 0s - loss: 0.2572 - binary_accuracy: 0.8852 - space_violation: 0.0449 - overpricing: 0.0557
# Epoch 181/512
# 9000/9000 - 0s - loss: 0.2573 - binary_accuracy: 0.8850 - space_violation: 0.0449 - overpricing: 0.0556
# Epoch 182/512
# 9000/9000 - 0s - loss: 0.2571 - binary_accuracy: 0.8854 - space_violation: 0.0454 - overpricing: 0.0575
# Epoch 183/512
# 9000/9000 - 0s - loss: 0.2571 - binary_accuracy: 0.8849 - space_violation: 0.0459 - overpricing: 0.0584
# Epoch 184/512
# 9000/9000 - 0s - loss: 0.2569 - binary_accuracy: 0.8856 - space_violation: 0.0451 - overpricing: 0.0569
# Epoch 185/512
# 9000/9000 - 0s - loss: 0.2569 - binary_accuracy: 0.8861 - space_violation: 0.0452 - overpricing: 0.0572
# Epoch 186/512
# 9000/9000 - 0s - loss: 0.2568 - binary_accuracy: 0.8852 - space_violation: 0.0454 - overpricing: 0.0567
# Epoch 187/512
# 9000/9000 - 0s - loss: 0.2567 - binary_accuracy: 0.8857 - space_violation: 0.0447 - overpricing: 0.0557
# Epoch 188/512
# 9000/9000 - 0s - loss: 0.2567 - binary_accuracy: 0.8854 - space_violation: 0.0448 - overpricing: 0.0555
# Epoch 189/512
# 9000/9000 - 0s - loss: 0.2566 - binary_accuracy: 0.8860 - space_violation: 0.0458 - overpricing: 0.0593
# Epoch 190/512
# 9000/9000 - 0s - loss: 0.2566 - binary_accuracy: 0.8856 - space_violation: 0.0450 - overpricing: 0.0556
# Epoch 191/512
# 9000/9000 - 0s - loss: 0.2565 - binary_accuracy: 0.8855 - space_violation: 0.0455 - overpricing: 0.0585
# Epoch 192/512
# 9000/9000 - 0s - loss: 0.2564 - binary_accuracy: 0.8856 - space_violation: 0.0452 - overpricing: 0.0560
# Epoch 193/512
# 9000/9000 - 0s - loss: 0.2562 - binary_accuracy: 0.8862 - space_violation: 0.0445 - overpricing: 0.0565
# Epoch 194/512
# 9000/9000 - 0s - loss: 0.2562 - binary_accuracy: 0.8862 - space_violation: 0.0451 - overpricing: 0.0578
# Epoch 195/512
# 9000/9000 - 0s - loss: 0.2560 - binary_accuracy: 0.8862 - space_violation: 0.0442 - overpricing: 0.0565
# Epoch 196/512
# 9000/9000 - 0s - loss: 0.2560 - binary_accuracy: 0.8861 - space_violation: 0.0452 - overpricing: 0.0560
# Epoch 197/512
# 9000/9000 - 0s - loss: 0.2560 - binary_accuracy: 0.8853 - space_violation: 0.0443 - overpricing: 0.0555
# Epoch 198/512
# 9000/9000 - 0s - loss: 0.2561 - binary_accuracy: 0.8863 - space_violation: 0.0451 - overpricing: 0.0589
# Epoch 199/512
# 9000/9000 - 0s - loss: 0.2558 - binary_accuracy: 0.8860 - space_violation: 0.0443 - overpricing: 0.0562
# Epoch 200/512
# 9000/9000 - 0s - loss: 0.2558 - binary_accuracy: 0.8863 - space_violation: 0.0445 - overpricing: 0.0570
# Epoch 201/512
# 9000/9000 - 0s - loss: 0.2558 - binary_accuracy: 0.8858 - space_violation: 0.0450 - overpricing: 0.0565
# Epoch 202/512
# 9000/9000 - 0s - loss: 0.2557 - binary_accuracy: 0.8860 - space_violation: 0.0443 - overpricing: 0.0537
# Epoch 203/512
# 9000/9000 - 0s - loss: 0.2554 - binary_accuracy: 0.8861 - space_violation: 0.0450 - overpricing: 0.0579
# Epoch 204/512
# 9000/9000 - 0s - loss: 0.2554 - binary_accuracy: 0.8862 - space_violation: 0.0440 - overpricing: 0.0556
# Epoch 205/512
# 9000/9000 - 0s - loss: 0.2555 - binary_accuracy: 0.8865 - space_violation: 0.0440 - overpricing: 0.0556
# Epoch 206/512
# 9000/9000 - 0s - loss: 0.2553 - binary_accuracy: 0.8862 - space_violation: 0.0428 - overpricing: 0.0520
# Epoch 207/512
# 9000/9000 - 0s - loss: 0.2552 - binary_accuracy: 0.8864 - space_violation: 0.0440 - overpricing: 0.0565
# Epoch 208/512
# 9000/9000 - 0s - loss: 0.2552 - binary_accuracy: 0.8862 - space_violation: 0.0437 - overpricing: 0.0546
# Epoch 209/512
# 9000/9000 - 0s - loss: 0.2551 - binary_accuracy: 0.8866 - space_violation: 0.0439 - overpricing: 0.0567
# Epoch 210/512
# 9000/9000 - 0s - loss: 0.2550 - binary_accuracy: 0.8863 - space_violation: 0.0437 - overpricing: 0.0547
# Epoch 211/512
# 9000/9000 - 0s - loss: 0.2550 - binary_accuracy: 0.8868 - space_violation: 0.0439 - overpricing: 0.0554
# Epoch 212/512
# 9000/9000 - 0s - loss: 0.2550 - binary_accuracy: 0.8862 - space_violation: 0.0433 - overpricing: 0.0533
# Epoch 213/512
# 9000/9000 - 0s - loss: 0.2549 - binary_accuracy: 0.8866 - space_violation: 0.0442 - overpricing: 0.0555
# Epoch 214/512
# 9000/9000 - 0s - loss: 0.2547 - binary_accuracy: 0.8864 - space_violation: 0.0442 - overpricing: 0.0554
# Epoch 215/512
# 9000/9000 - 0s - loss: 0.2547 - binary_accuracy: 0.8864 - space_violation: 0.0439 - overpricing: 0.0549
# Epoch 216/512
# 9000/9000 - 0s - loss: 0.2546 - binary_accuracy: 0.8858 - space_violation: 0.0442 - overpricing: 0.0554
# Epoch 217/512
# 9000/9000 - 0s - loss: 0.2545 - binary_accuracy: 0.8872 - space_violation: 0.0437 - overpricing: 0.0568
# Epoch 218/512
# 9000/9000 - 0s - loss: 0.2545 - binary_accuracy: 0.8866 - space_violation: 0.0438 - overpricing: 0.0549
# Epoch 219/512
# 9000/9000 - 0s - loss: 0.2545 - binary_accuracy: 0.8865 - space_violation: 0.0440 - overpricing: 0.0539
# Epoch 220/512
# 9000/9000 - 0s - loss: 0.2543 - binary_accuracy: 0.8864 - space_violation: 0.0441 - overpricing: 0.0549
# Epoch 221/512
# 9000/9000 - 0s - loss: 0.2542 - binary_accuracy: 0.8867 - space_violation: 0.0438 - overpricing: 0.0549
# Epoch 222/512
# 9000/9000 - 0s - loss: 0.2543 - binary_accuracy: 0.8871 - space_violation: 0.0431 - overpricing: 0.0558
# Epoch 223/512
# 9000/9000 - 0s - loss: 0.2541 - binary_accuracy: 0.8871 - space_violation: 0.0437 - overpricing: 0.0546
# Epoch 224/512
# 9000/9000 - 0s - loss: 0.2540 - binary_accuracy: 0.8870 - space_violation: 0.0434 - overpricing: 0.0575
# Epoch 225/512
# 9000/9000 - 0s - loss: 0.2540 - binary_accuracy: 0.8864 - space_violation: 0.0435 - overpricing: 0.0542
# Epoch 226/512
# 9000/9000 - 0s - loss: 0.2539 - binary_accuracy: 0.8871 - space_violation: 0.0437 - overpricing: 0.0560
# Epoch 227/512
# 9000/9000 - 0s - loss: 0.2539 - binary_accuracy: 0.8872 - space_violation: 0.0432 - overpricing: 0.0534
# Epoch 228/512
# 9000/9000 - 0s - loss: 0.2537 - binary_accuracy: 0.8866 - space_violation: 0.0434 - overpricing: 0.0562
# Epoch 229/512
# 9000/9000 - 0s - loss: 0.2538 - binary_accuracy: 0.8867 - space_violation: 0.0433 - overpricing: 0.0556
# Epoch 230/512
# 9000/9000 - 0s - loss: 0.2536 - binary_accuracy: 0.8867 - space_violation: 0.0431 - overpricing: 0.0511
# Epoch 231/512
# 9000/9000 - 0s - loss: 0.2538 - binary_accuracy: 0.8877 - space_violation: 0.0424 - overpricing: 0.0541
# Epoch 232/512
# 9000/9000 - 0s - loss: 0.2534 - binary_accuracy: 0.8874 - space_violation: 0.0436 - overpricing: 0.0549
# Epoch 233/512
# 9000/9000 - 0s - loss: 0.2533 - binary_accuracy: 0.8870 - space_violation: 0.0434 - overpricing: 0.0550
# Epoch 234/512
# 9000/9000 - 0s - loss: 0.2534 - binary_accuracy: 0.8875 - space_violation: 0.0432 - overpricing: 0.0556
# Epoch 235/512
# 9000/9000 - 0s - loss: 0.2533 - binary_accuracy: 0.8874 - space_violation: 0.0438 - overpricing: 0.0541
# Epoch 236/512
# 9000/9000 - 0s - loss: 0.2533 - binary_accuracy: 0.8868 - space_violation: 0.0437 - overpricing: 0.0551
# Epoch 237/512
# 9000/9000 - 0s - loss: 0.2532 - binary_accuracy: 0.8869 - space_violation: 0.0436 - overpricing: 0.0547
# Epoch 238/512
# 9000/9000 - 0s - loss: 0.2532 - binary_accuracy: 0.8868 - space_violation: 0.0427 - overpricing: 0.0528
# Epoch 239/512
# 9000/9000 - 0s - loss: 0.2531 - binary_accuracy: 0.8875 - space_violation: 0.0430 - overpricing: 0.0559
# Epoch 240/512
# 9000/9000 - 0s - loss: 0.2529 - binary_accuracy: 0.8871 - space_violation: 0.0440 - overpricing: 0.0564
# Epoch 241/512
# 9000/9000 - 0s - loss: 0.2529 - binary_accuracy: 0.8873 - space_violation: 0.0431 - overpricing: 0.0545
# Epoch 242/512
# 9000/9000 - 0s - loss: 0.2528 - binary_accuracy: 0.8875 - space_violation: 0.0434 - overpricing: 0.0547
# Epoch 243/512
# 9000/9000 - 0s - loss: 0.2527 - binary_accuracy: 0.8867 - space_violation: 0.0429 - overpricing: 0.0533
# Epoch 244/512
# 9000/9000 - 0s - loss: 0.2528 - binary_accuracy: 0.8877 - space_violation: 0.0426 - overpricing: 0.0540
# Epoch 245/512
# 9000/9000 - 0s - loss: 0.2527 - binary_accuracy: 0.8877 - space_violation: 0.0428 - overpricing: 0.0539
# Epoch 246/512
# 9000/9000 - 0s - loss: 0.2528 - binary_accuracy: 0.8872 - space_violation: 0.0425 - overpricing: 0.0524
# Epoch 247/512
# 9000/9000 - 0s - loss: 0.2525 - binary_accuracy: 0.8881 - space_violation: 0.0429 - overpricing: 0.0556
# Epoch 248/512
# 9000/9000 - 0s - loss: 0.2525 - binary_accuracy: 0.8876 - space_violation: 0.0427 - overpricing: 0.0547
# Epoch 249/512
# 9000/9000 - 0s - loss: 0.2523 - binary_accuracy: 0.8879 - space_violation: 0.0421 - overpricing: 0.0509
# Epoch 250/512
# 9000/9000 - 0s - loss: 0.2525 - binary_accuracy: 0.8874 - space_violation: 0.0426 - overpricing: 0.0550
# Epoch 251/512
# 9000/9000 - 0s - loss: 0.2522 - binary_accuracy: 0.8876 - space_violation: 0.0426 - overpricing: 0.0546
# Epoch 252/512
# 9000/9000 - 0s - loss: 0.2523 - binary_accuracy: 0.8882 - space_violation: 0.0427 - overpricing: 0.0546
# Epoch 253/512
# 9000/9000 - 0s - loss: 0.2523 - binary_accuracy: 0.8881 - space_violation: 0.0427 - overpricing: 0.0552
# Epoch 254/512
# 9000/9000 - 0s - loss: 0.2522 - binary_accuracy: 0.8885 - space_violation: 0.0426 - overpricing: 0.0547
# Epoch 255/512
# 9000/9000 - 0s - loss: 0.2522 - binary_accuracy: 0.8877 - space_violation: 0.0416 - overpricing: 0.0523
# Epoch 256/512
# 9000/9000 - 0s - loss: 0.2519 - binary_accuracy: 0.8878 - space_violation: 0.0423 - overpricing: 0.0540
# Epoch 257/512
# 9000/9000 - 0s - loss: 0.2519 - binary_accuracy: 0.8873 - space_violation: 0.0426 - overpricing: 0.0541
# Epoch 258/512
# 9000/9000 - 0s - loss: 0.2518 - binary_accuracy: 0.8878 - space_violation: 0.0426 - overpricing: 0.0547
# Epoch 259/512
# 9000/9000 - 0s - loss: 0.2518 - binary_accuracy: 0.8882 - space_violation: 0.0417 - overpricing: 0.0542
# Epoch 260/512
# 9000/9000 - 0s - loss: 0.2518 - binary_accuracy: 0.8882 - space_violation: 0.0428 - overpricing: 0.0548
# Epoch 261/512
# 9000/9000 - 0s - loss: 0.2516 - binary_accuracy: 0.8878 - space_violation: 0.0418 - overpricing: 0.0534
# Epoch 262/512
# 9000/9000 - 0s - loss: 0.2517 - binary_accuracy: 0.8878 - space_violation: 0.0422 - overpricing: 0.0536
# Epoch 263/512
# 9000/9000 - 0s - loss: 0.2515 - binary_accuracy: 0.8877 - space_violation: 0.0416 - overpricing: 0.0521
# Epoch 264/512
# 9000/9000 - 0s - loss: 0.2514 - binary_accuracy: 0.8883 - space_violation: 0.0422 - overpricing: 0.0518
# Epoch 265/512
# 9000/9000 - 0s - loss: 0.2514 - binary_accuracy: 0.8886 - space_violation: 0.0414 - overpricing: 0.0514
# Epoch 266/512
# 9000/9000 - 0s - loss: 0.2514 - binary_accuracy: 0.8881 - space_violation: 0.0422 - overpricing: 0.0541
# Epoch 267/512
# 9000/9000 - 0s - loss: 0.2513 - binary_accuracy: 0.8885 - space_violation: 0.0420 - overpricing: 0.0560
# Epoch 268/512
# 9000/9000 - 0s - loss: 0.2513 - binary_accuracy: 0.8887 - space_violation: 0.0414 - overpricing: 0.0507
# Epoch 269/512
# 9000/9000 - 0s - loss: 0.2512 - binary_accuracy: 0.8878 - space_violation: 0.0411 - overpricing: 0.0509
# Epoch 270/512
# 9000/9000 - 0s - loss: 0.2512 - binary_accuracy: 0.8886 - space_violation: 0.0421 - overpricing: 0.0546
# Epoch 271/512
# 9000/9000 - 0s - loss: 0.2511 - binary_accuracy: 0.8884 - space_violation: 0.0413 - overpricing: 0.0522
# Epoch 272/512
# 9000/9000 - 0s - loss: 0.2511 - binary_accuracy: 0.8881 - space_violation: 0.0419 - overpricing: 0.0526
# Epoch 273/512
# 9000/9000 - 0s - loss: 0.2509 - binary_accuracy: 0.8880 - space_violation: 0.0418 - overpricing: 0.0528
# Epoch 274/512
# 9000/9000 - 0s - loss: 0.2510 - binary_accuracy: 0.8879 - space_violation: 0.0422 - overpricing: 0.0538
# Epoch 275/512
# 9000/9000 - 0s - loss: 0.2508 - binary_accuracy: 0.8883 - space_violation: 0.0409 - overpricing: 0.0515
# Epoch 276/512
# 9000/9000 - 0s - loss: 0.2507 - binary_accuracy: 0.8886 - space_violation: 0.0407 - overpricing: 0.0510
# Epoch 277/512
# 9000/9000 - 0s - loss: 0.2509 - binary_accuracy: 0.8886 - space_violation: 0.0414 - overpricing: 0.0530
# Epoch 278/512
# 9000/9000 - 0s - loss: 0.2507 - binary_accuracy: 0.8887 - space_violation: 0.0414 - overpricing: 0.0522
# Epoch 279/512
# 9000/9000 - 0s - loss: 0.2508 - binary_accuracy: 0.8883 - space_violation: 0.0419 - overpricing: 0.0545
# Epoch 280/512
# 9000/9000 - 0s - loss: 0.2506 - binary_accuracy: 0.8890 - space_violation: 0.0412 - overpricing: 0.0513
# Epoch 281/512
# 9000/9000 - 0s - loss: 0.2505 - binary_accuracy: 0.8882 - space_violation: 0.0408 - overpricing: 0.0525
# Epoch 282/512
# 9000/9000 - 0s - loss: 0.2504 - binary_accuracy: 0.8891 - space_violation: 0.0413 - overpricing: 0.0522
# Epoch 283/512
# 9000/9000 - 0s - loss: 0.2504 - binary_accuracy: 0.8881 - space_violation: 0.0411 - overpricing: 0.0519
# Epoch 284/512
# 9000/9000 - 0s - loss: 0.2503 - binary_accuracy: 0.8887 - space_violation: 0.0407 - overpricing: 0.0526
# Epoch 285/512
# 9000/9000 - 0s - loss: 0.2503 - binary_accuracy: 0.8888 - space_violation: 0.0408 - overpricing: 0.0516
# Epoch 286/512
# 9000/9000 - 0s - loss: 0.2504 - binary_accuracy: 0.8889 - space_violation: 0.0408 - overpricing: 0.0513
# Epoch 287/512
# 9000/9000 - 0s - loss: 0.2502 - binary_accuracy: 0.8887 - space_violation: 0.0407 - overpricing: 0.0496
# Epoch 288/512
# 9000/9000 - 0s - loss: 0.2502 - binary_accuracy: 0.8887 - space_violation: 0.0407 - overpricing: 0.0525
# Epoch 289/512
# 9000/9000 - 0s - loss: 0.2500 - binary_accuracy: 0.8894 - space_violation: 0.0408 - overpricing: 0.0523
# Epoch 290/512
# 9000/9000 - 0s - loss: 0.2502 - binary_accuracy: 0.8883 - space_violation: 0.0409 - overpricing: 0.0518
# Epoch 291/512
# 9000/9000 - 0s - loss: 0.2500 - binary_accuracy: 0.8886 - space_violation: 0.0401 - overpricing: 0.0497
# Epoch 292/512
# 9000/9000 - 0s - loss: 0.2498 - binary_accuracy: 0.8892 - space_violation: 0.0403 - overpricing: 0.0510
# Epoch 293/512
# 9000/9000 - 0s - loss: 0.2500 - binary_accuracy: 0.8887 - space_violation: 0.0410 - overpricing: 0.0527
# Epoch 294/512
# 9000/9000 - 0s - loss: 0.2498 - binary_accuracy: 0.8888 - space_violation: 0.0408 - overpricing: 0.0523
# Epoch 295/512
# 9000/9000 - 0s - loss: 0.2498 - binary_accuracy: 0.8894 - space_violation: 0.0411 - overpricing: 0.0541
# Epoch 296/512
# 9000/9000 - 0s - loss: 0.2498 - binary_accuracy: 0.8890 - space_violation: 0.0406 - overpricing: 0.0519
# Epoch 297/512
# 9000/9000 - 0s - loss: 0.2496 - binary_accuracy: 0.8887 - space_violation: 0.0401 - overpricing: 0.0501
# Epoch 298/512
# 9000/9000 - 0s - loss: 0.2497 - binary_accuracy: 0.8891 - space_violation: 0.0402 - overpricing: 0.0507
# Epoch 299/512
# 9000/9000 - 0s - loss: 0.2496 - binary_accuracy: 0.8894 - space_violation: 0.0411 - overpricing: 0.0531
# Epoch 300/512
# 9000/9000 - 0s - loss: 0.2495 - binary_accuracy: 0.8895 - space_violation: 0.0405 - overpricing: 0.0521
# Epoch 301/512
# 9000/9000 - 0s - loss: 0.2496 - binary_accuracy: 0.8892 - space_violation: 0.0408 - overpricing: 0.0526
# Epoch 302/512
# 9000/9000 - 0s - loss: 0.2493 - binary_accuracy: 0.8902 - space_violation: 0.0393 - overpricing: 0.0479
# Epoch 303/512
# 9000/9000 - 0s - loss: 0.2493 - binary_accuracy: 0.8888 - space_violation: 0.0404 - overpricing: 0.0526
# Epoch 304/512
# 9000/9000 - 0s - loss: 0.2493 - binary_accuracy: 0.8892 - space_violation: 0.0398 - overpricing: 0.0517
# Epoch 305/512
# 9000/9000 - 0s - loss: 0.2492 - binary_accuracy: 0.8890 - space_violation: 0.0399 - overpricing: 0.0494
# Epoch 306/512
# 9000/9000 - 0s - loss: 0.2492 - binary_accuracy: 0.8894 - space_violation: 0.0404 - overpricing: 0.0525
# Epoch 307/512
# 9000/9000 - 0s - loss: 0.2491 - binary_accuracy: 0.8899 - space_violation: 0.0401 - overpricing: 0.0523
# Epoch 308/512
# 9000/9000 - 0s - loss: 0.2491 - binary_accuracy: 0.8896 - space_violation: 0.0402 - overpricing: 0.0515
# Epoch 309/512
# 9000/9000 - 0s - loss: 0.2490 - binary_accuracy: 0.8892 - space_violation: 0.0399 - overpricing: 0.0506
# Epoch 310/512
# 9000/9000 - 0s - loss: 0.2489 - binary_accuracy: 0.8894 - space_violation: 0.0400 - overpricing: 0.0506
# Epoch 311/512
# 9000/9000 - 0s - loss: 0.2489 - binary_accuracy: 0.8897 - space_violation: 0.0394 - overpricing: 0.0498
# Epoch 312/512
# 9000/9000 - 0s - loss: 0.2488 - binary_accuracy: 0.8895 - space_violation: 0.0397 - overpricing: 0.0505
# Epoch 313/512
# 9000/9000 - 0s - loss: 0.2488 - binary_accuracy: 0.8895 - space_violation: 0.0391 - overpricing: 0.0486
# Epoch 314/512
# 9000/9000 - 0s - loss: 0.2487 - binary_accuracy: 0.8892 - space_violation: 0.0401 - overpricing: 0.0509
# Epoch 315/512
# 9000/9000 - 0s - loss: 0.2487 - binary_accuracy: 0.8897 - space_violation: 0.0401 - overpricing: 0.0522
# Epoch 316/512
# 9000/9000 - 0s - loss: 0.2486 - binary_accuracy: 0.8898 - space_violation: 0.0392 - overpricing: 0.0488
# Epoch 317/512
# 9000/9000 - 0s - loss: 0.2486 - binary_accuracy: 0.8894 - space_violation: 0.0401 - overpricing: 0.0513
# Epoch 318/512
# 9000/9000 - 0s - loss: 0.2485 - binary_accuracy: 0.8895 - space_violation: 0.0392 - overpricing: 0.0485
# Epoch 319/512
# 9000/9000 - 0s - loss: 0.2485 - binary_accuracy: 0.8900 - space_violation: 0.0397 - overpricing: 0.0504
# Epoch 320/512
# 9000/9000 - 0s - loss: 0.2484 - binary_accuracy: 0.8894 - space_violation: 0.0391 - overpricing: 0.0488
# Epoch 321/512
# 9000/9000 - 0s - loss: 0.2485 - binary_accuracy: 0.8891 - space_violation: 0.0400 - overpricing: 0.0495
# Epoch 322/512
# 9000/9000 - 0s - loss: 0.2484 - binary_accuracy: 0.8897 - space_violation: 0.0394 - overpricing: 0.0505
# Epoch 323/512
# 9000/9000 - 0s - loss: 0.2482 - binary_accuracy: 0.8902 - space_violation: 0.0396 - overpricing: 0.0509
# Epoch 324/512
# 9000/9000 - 0s - loss: 0.2484 - binary_accuracy: 0.8896 - space_violation: 0.0392 - overpricing: 0.0501
# Epoch 325/512
# 9000/9000 - 0s - loss: 0.2482 - binary_accuracy: 0.8901 - space_violation: 0.0392 - overpricing: 0.0508
# Epoch 326/512
# 9000/9000 - 0s - loss: 0.2481 - binary_accuracy: 0.8900 - space_violation: 0.0395 - overpricing: 0.0495
# Epoch 327/512
# 9000/9000 - 0s - loss: 0.2481 - binary_accuracy: 0.8897 - space_violation: 0.0391 - overpricing: 0.0497
# Epoch 328/512
# 9000/9000 - 0s - loss: 0.2481 - binary_accuracy: 0.8897 - space_violation: 0.0391 - overpricing: 0.0497
# Epoch 329/512
# 9000/9000 - 0s - loss: 0.2480 - binary_accuracy: 0.8897 - space_violation: 0.0394 - overpricing: 0.0499
# Epoch 330/512
# 9000/9000 - 0s - loss: 0.2480 - binary_accuracy: 0.8895 - space_violation: 0.0395 - overpricing: 0.0497
# Epoch 331/512
# 9000/9000 - 0s - loss: 0.2479 - binary_accuracy: 0.8904 - space_violation: 0.0387 - overpricing: 0.0484
# Epoch 332/512
# 9000/9000 - 0s - loss: 0.2478 - binary_accuracy: 0.8905 - space_violation: 0.0396 - overpricing: 0.0512
# Epoch 333/512
# 9000/9000 - 0s - loss: 0.2480 - binary_accuracy: 0.8903 - space_violation: 0.0396 - overpricing: 0.0494
# Epoch 334/512
# 9000/9000 - 0s - loss: 0.2477 - binary_accuracy: 0.8899 - space_violation: 0.0386 - overpricing: 0.0483
# Epoch 335/512
# 9000/9000 - 0s - loss: 0.2477 - binary_accuracy: 0.8891 - space_violation: 0.0393 - overpricing: 0.0489
# Epoch 336/512
# 9000/9000 - 0s - loss: 0.2477 - binary_accuracy: 0.8896 - space_violation: 0.0387 - overpricing: 0.0471
# Epoch 337/512
# 9000/9000 - 0s - loss: 0.2476 - binary_accuracy: 0.8901 - space_violation: 0.0392 - overpricing: 0.0495
# Epoch 338/512
# 9000/9000 - 0s - loss: 0.2476 - binary_accuracy: 0.8904 - space_violation: 0.0398 - overpricing: 0.0531
# Epoch 339/512
# 9000/9000 - 0s - loss: 0.2475 - binary_accuracy: 0.8901 - space_violation: 0.0394 - overpricing: 0.0502
# Epoch 340/512
# 9000/9000 - 0s - loss: 0.2475 - binary_accuracy: 0.8905 - space_violation: 0.0392 - overpricing: 0.0497
# Epoch 341/512
# 9000/9000 - 0s - loss: 0.2474 - binary_accuracy: 0.8900 - space_violation: 0.0386 - overpricing: 0.0486
# Epoch 342/512
# 9000/9000 - 0s - loss: 0.2476 - binary_accuracy: 0.8903 - space_violation: 0.0386 - overpricing: 0.0488
# Epoch 343/512
# 9000/9000 - 0s - loss: 0.2473 - binary_accuracy: 0.8904 - space_violation: 0.0388 - overpricing: 0.0500
# Epoch 344/512
# 9000/9000 - 0s - loss: 0.2475 - binary_accuracy: 0.8901 - space_violation: 0.0387 - overpricing: 0.0474
# Epoch 345/512
# 9000/9000 - 0s - loss: 0.2473 - binary_accuracy: 0.8906 - space_violation: 0.0388 - overpricing: 0.0506
# Epoch 346/512
# 9000/9000 - 0s - loss: 0.2472 - binary_accuracy: 0.8904 - space_violation: 0.0388 - overpricing: 0.0498
# Epoch 347/512
# 9000/9000 - 0s - loss: 0.2472 - binary_accuracy: 0.8902 - space_violation: 0.0388 - overpricing: 0.0483
# Epoch 348/512
# 9000/9000 - 0s - loss: 0.2472 - binary_accuracy: 0.8906 - space_violation: 0.0382 - overpricing: 0.0475
# Epoch 349/512
# 9000/9000 - 0s - loss: 0.2471 - binary_accuracy: 0.8902 - space_violation: 0.0387 - overpricing: 0.0488
# Epoch 350/512
# 9000/9000 - 0s - loss: 0.2471 - binary_accuracy: 0.8904 - space_violation: 0.0386 - overpricing: 0.0484
# Epoch 351/512
# 9000/9000 - 0s - loss: 0.2470 - binary_accuracy: 0.8906 - space_violation: 0.0382 - overpricing: 0.0480
# Epoch 352/512
# 9000/9000 - 0s - loss: 0.2470 - binary_accuracy: 0.8904 - space_violation: 0.0378 - overpricing: 0.0464
# Epoch 353/512
# 9000/9000 - 0s - loss: 0.2471 - binary_accuracy: 0.8898 - space_violation: 0.0386 - overpricing: 0.0498
# Epoch 354/512
# 9000/9000 - 0s - loss: 0.2469 - binary_accuracy: 0.8906 - space_violation: 0.0381 - overpricing: 0.0480
# Epoch 355/512
# 9000/9000 - 0s - loss: 0.2468 - binary_accuracy: 0.8907 - space_violation: 0.0387 - overpricing: 0.0505
# Epoch 356/512
# 9000/9000 - 0s - loss: 0.2469 - binary_accuracy: 0.8903 - space_violation: 0.0377 - overpricing: 0.0468
# Epoch 357/512
# 9000/9000 - 0s - loss: 0.2468 - binary_accuracy: 0.8904 - space_violation: 0.0380 - overpricing: 0.0470
# Epoch 358/512
# 9000/9000 - 0s - loss: 0.2469 - binary_accuracy: 0.8905 - space_violation: 0.0386 - overpricing: 0.0484
# Epoch 359/512
# 9000/9000 - 0s - loss: 0.2467 - binary_accuracy: 0.8908 - space_violation: 0.0374 - overpricing: 0.0468
# Epoch 360/512
# 9000/9000 - 0s - loss: 0.2467 - binary_accuracy: 0.8904 - space_violation: 0.0392 - overpricing: 0.0507
# Epoch 361/512
# 9000/9000 - 0s - loss: 0.2466 - binary_accuracy: 0.8910 - space_violation: 0.0385 - overpricing: 0.0495
# Epoch 362/512
# 9000/9000 - 0s - loss: 0.2465 - binary_accuracy: 0.8912 - space_violation: 0.0381 - overpricing: 0.0479
# Epoch 363/512
# 9000/9000 - 0s - loss: 0.2466 - binary_accuracy: 0.8908 - space_violation: 0.0378 - overpricing: 0.0478
# Epoch 364/512
# 9000/9000 - 0s - loss: 0.2464 - binary_accuracy: 0.8905 - space_violation: 0.0386 - overpricing: 0.0486
# Epoch 365/512
# 9000/9000 - 0s - loss: 0.2463 - binary_accuracy: 0.8917 - space_violation: 0.0382 - overpricing: 0.0494
# Epoch 366/512
# 9000/9000 - 0s - loss: 0.2463 - binary_accuracy: 0.8905 - space_violation: 0.0384 - overpricing: 0.0499
# Epoch 367/512
# 9000/9000 - 0s - loss: 0.2463 - binary_accuracy: 0.8906 - space_violation: 0.0377 - overpricing: 0.0468
# Epoch 368/512
# 9000/9000 - 0s - loss: 0.2463 - binary_accuracy: 0.8910 - space_violation: 0.0384 - overpricing: 0.0494
# Epoch 369/512
# 9000/9000 - 0s - loss: 0.2463 - binary_accuracy: 0.8909 - space_violation: 0.0376 - overpricing: 0.0463
# Epoch 370/512
# 9000/9000 - 0s - loss: 0.2462 - binary_accuracy: 0.8908 - space_violation: 0.0386 - overpricing: 0.0484
# Epoch 371/512
# 9000/9000 - 0s - loss: 0.2461 - binary_accuracy: 0.8906 - space_violation: 0.0378 - overpricing: 0.0480
# Epoch 372/512
# 9000/9000 - 0s - loss: 0.2462 - binary_accuracy: 0.8906 - space_violation: 0.0379 - overpricing: 0.0486
# Epoch 373/512
# 9000/9000 - 0s - loss: 0.2461 - binary_accuracy: 0.8912 - space_violation: 0.0380 - overpricing: 0.0485
# Epoch 374/512
# 9000/9000 - 0s - loss: 0.2461 - binary_accuracy: 0.8914 - space_violation: 0.0377 - overpricing: 0.0497
# Epoch 375/512
# 9000/9000 - 0s - loss: 0.2460 - binary_accuracy: 0.8907 - space_violation: 0.0384 - overpricing: 0.0481
# Epoch 376/512
# 9000/9000 - 0s - loss: 0.2460 - binary_accuracy: 0.8908 - space_violation: 0.0385 - overpricing: 0.0501
# Epoch 377/512
# 9000/9000 - 0s - loss: 0.2459 - binary_accuracy: 0.8908 - space_violation: 0.0379 - overpricing: 0.0484
# Epoch 378/512
# 9000/9000 - 0s - loss: 0.2459 - binary_accuracy: 0.8907 - space_violation: 0.0381 - overpricing: 0.0488
# Epoch 379/512
# 9000/9000 - 0s - loss: 0.2458 - binary_accuracy: 0.8910 - space_violation: 0.0372 - overpricing: 0.0449
# Epoch 380/512
# 9000/9000 - 0s - loss: 0.2458 - binary_accuracy: 0.8910 - space_violation: 0.0372 - overpricing: 0.0466
# Epoch 381/512
# 9000/9000 - 0s - loss: 0.2456 - binary_accuracy: 0.8910 - space_violation: 0.0377 - overpricing: 0.0486
# Epoch 382/512
# 9000/9000 - 0s - loss: 0.2456 - binary_accuracy: 0.8912 - space_violation: 0.0379 - overpricing: 0.0489
# Epoch 383/512
# 9000/9000 - 0s - loss: 0.2457 - binary_accuracy: 0.8914 - space_violation: 0.0373 - overpricing: 0.0473
# Epoch 384/512
# 9000/9000 - 0s - loss: 0.2456 - binary_accuracy: 0.8921 - space_violation: 0.0376 - overpricing: 0.0491
# Epoch 385/512
# 9000/9000 - 0s - loss: 0.2456 - binary_accuracy: 0.8911 - space_violation: 0.0367 - overpricing: 0.0446
# Epoch 386/512
# 9000/9000 - 0s - loss: 0.2455 - binary_accuracy: 0.8910 - space_violation: 0.0374 - overpricing: 0.0470
# Epoch 387/512
# 9000/9000 - 0s - loss: 0.2455 - binary_accuracy: 0.8915 - space_violation: 0.0375 - overpricing: 0.0467
# Epoch 388/512
# 9000/9000 - 0s - loss: 0.2454 - binary_accuracy: 0.8910 - space_violation: 0.0372 - overpricing: 0.0470
# Epoch 389/512
# 9000/9000 - 0s - loss: 0.2454 - binary_accuracy: 0.8914 - space_violation: 0.0378 - overpricing: 0.0474
# Epoch 390/512
# 9000/9000 - 0s - loss: 0.2454 - binary_accuracy: 0.8917 - space_violation: 0.0383 - overpricing: 0.0507
# Epoch 391/512
# 9000/9000 - 0s - loss: 0.2453 - binary_accuracy: 0.8914 - space_violation: 0.0376 - overpricing: 0.0491
# Epoch 392/512
# 9000/9000 - 0s - loss: 0.2453 - binary_accuracy: 0.8915 - space_violation: 0.0385 - overpricing: 0.0504
# Epoch 393/512
# 9000/9000 - 0s - loss: 0.2452 - binary_accuracy: 0.8913 - space_violation: 0.0371 - overpricing: 0.0467
# Epoch 394/512
# 9000/9000 - 0s - loss: 0.2451 - binary_accuracy: 0.8910 - space_violation: 0.0369 - overpricing: 0.0448
# Epoch 395/512
# 9000/9000 - 0s - loss: 0.2453 - binary_accuracy: 0.8912 - space_violation: 0.0376 - overpricing: 0.0484
# Epoch 396/512
# 9000/9000 - 0s - loss: 0.2452 - binary_accuracy: 0.8914 - space_violation: 0.0370 - overpricing: 0.0451
# Epoch 397/512
# 9000/9000 - 0s - loss: 0.2451 - binary_accuracy: 0.8914 - space_violation: 0.0371 - overpricing: 0.0464
# Epoch 398/512
# 9000/9000 - 0s - loss: 0.2451 - binary_accuracy: 0.8915 - space_violation: 0.0375 - overpricing: 0.0489
# Epoch 399/512
# 9000/9000 - 0s - loss: 0.2450 - binary_accuracy: 0.8921 - space_violation: 0.0368 - overpricing: 0.0459
# Epoch 400/512
# 9000/9000 - 0s - loss: 0.2450 - binary_accuracy: 0.8920 - space_violation: 0.0377 - overpricing: 0.0490
# Epoch 401/512
# 9000/9000 - 0s - loss: 0.2449 - binary_accuracy: 0.8914 - space_violation: 0.0369 - overpricing: 0.0456
# Epoch 402/512
# 9000/9000 - 0s - loss: 0.2450 - binary_accuracy: 0.8914 - space_violation: 0.0373 - overpricing: 0.0466
# Epoch 403/512
# 9000/9000 - 0s - loss: 0.2449 - binary_accuracy: 0.8908 - space_violation: 0.0368 - overpricing: 0.0440
# Epoch 404/512
# 9000/9000 - 0s - loss: 0.2447 - binary_accuracy: 0.8920 - space_violation: 0.0368 - overpricing: 0.0460
# Epoch 405/512
# 9000/9000 - 0s - loss: 0.2449 - binary_accuracy: 0.8916 - space_violation: 0.0376 - overpricing: 0.0477
# Epoch 406/512
# 9000/9000 - 0s - loss: 0.2447 - binary_accuracy: 0.8919 - space_violation: 0.0374 - overpricing: 0.0487
# Epoch 407/512
# 9000/9000 - 0s - loss: 0.2446 - binary_accuracy: 0.8920 - space_violation: 0.0369 - overpricing: 0.0469
# Epoch 408/512
# 9000/9000 - 0s - loss: 0.2447 - binary_accuracy: 0.8913 - space_violation: 0.0367 - overpricing: 0.0457
# Epoch 409/512
# 9000/9000 - 0s - loss: 0.2446 - binary_accuracy: 0.8913 - space_violation: 0.0372 - overpricing: 0.0473
# Epoch 410/512
# 9000/9000 - 0s - loss: 0.2446 - binary_accuracy: 0.8914 - space_violation: 0.0376 - overpricing: 0.0486
# Epoch 411/512
# 9000/9000 - 0s - loss: 0.2445 - binary_accuracy: 0.8916 - space_violation: 0.0370 - overpricing: 0.0475
# Epoch 412/512
# 9000/9000 - 0s - loss: 0.2446 - binary_accuracy: 0.8910 - space_violation: 0.0373 - overpricing: 0.0473
# Epoch 413/512
# 9000/9000 - 0s - loss: 0.2444 - binary_accuracy: 0.8921 - space_violation: 0.0365 - overpricing: 0.0470
# Epoch 414/512
# 9000/9000 - 0s - loss: 0.2445 - binary_accuracy: 0.8920 - space_violation: 0.0368 - overpricing: 0.0462
# Epoch 415/512
# 9000/9000 - 0s - loss: 0.2445 - binary_accuracy: 0.8914 - space_violation: 0.0370 - overpricing: 0.0469
# Epoch 416/512
# 9000/9000 - 0s - loss: 0.2444 - binary_accuracy: 0.8922 - space_violation: 0.0370 - overpricing: 0.0477
# Epoch 417/512
# 9000/9000 - 0s - loss: 0.2443 - binary_accuracy: 0.8921 - space_violation: 0.0360 - overpricing: 0.0438
# Epoch 418/512
# 9000/9000 - 0s - loss: 0.2444 - binary_accuracy: 0.8916 - space_violation: 0.0371 - overpricing: 0.0466
# Epoch 419/512
# 9000/9000 - 0s - loss: 0.2442 - binary_accuracy: 0.8920 - space_violation: 0.0369 - overpricing: 0.0471
# Epoch 420/512
# 9000/9000 - 0s - loss: 0.2443 - binary_accuracy: 0.8914 - space_violation: 0.0368 - overpricing: 0.0460
# Epoch 421/512
# 9000/9000 - 0s - loss: 0.2441 - binary_accuracy: 0.8918 - space_violation: 0.0367 - overpricing: 0.0461
# Epoch 422/512
# 9000/9000 - 0s - loss: 0.2441 - binary_accuracy: 0.8918 - space_violation: 0.0367 - overpricing: 0.0479
# Epoch 423/512
# 9000/9000 - 0s - loss: 0.2441 - binary_accuracy: 0.8919 - space_violation: 0.0368 - overpricing: 0.0465
# Epoch 424/512
# 9000/9000 - 0s - loss: 0.2441 - binary_accuracy: 0.8912 - space_violation: 0.0364 - overpricing: 0.0447
# Epoch 425/512
# 9000/9000 - 0s - loss: 0.2440 - binary_accuracy: 0.8921 - space_violation: 0.0365 - overpricing: 0.0451
# Epoch 426/512
# 9000/9000 - 0s - loss: 0.2441 - binary_accuracy: 0.8916 - space_violation: 0.0369 - overpricing: 0.0467
# Epoch 427/512
# 9000/9000 - 0s - loss: 0.2440 - binary_accuracy: 0.8918 - space_violation: 0.0365 - overpricing: 0.0460
# Epoch 428/512
# 9000/9000 - 0s - loss: 0.2439 - binary_accuracy: 0.8920 - space_violation: 0.0364 - overpricing: 0.0461
# Epoch 429/512
# 9000/9000 - 0s - loss: 0.2439 - binary_accuracy: 0.8916 - space_violation: 0.0367 - overpricing: 0.0455
# Epoch 430/512
# 9000/9000 - 0s - loss: 0.2439 - binary_accuracy: 0.8914 - space_violation: 0.0371 - overpricing: 0.0471
# Epoch 431/512
# 9000/9000 - 0s - loss: 0.2437 - binary_accuracy: 0.8924 - space_violation: 0.0365 - overpricing: 0.0475
# Epoch 432/512
# 9000/9000 - 0s - loss: 0.2438 - binary_accuracy: 0.8923 - space_violation: 0.0370 - overpricing: 0.0468
# Epoch 433/512
# 9000/9000 - 0s - loss: 0.2436 - binary_accuracy: 0.8919 - space_violation: 0.0365 - overpricing: 0.0462
# Epoch 434/512
# 9000/9000 - 0s - loss: 0.2437 - binary_accuracy: 0.8924 - space_violation: 0.0365 - overpricing: 0.0457
# Epoch 435/512
# 9000/9000 - 0s - loss: 0.2436 - binary_accuracy: 0.8925 - space_violation: 0.0369 - overpricing: 0.0489
# Epoch 436/512
# 9000/9000 - 0s - loss: 0.2436 - binary_accuracy: 0.8919 - space_violation: 0.0359 - overpricing: 0.0437
# Epoch 437/512
# 9000/9000 - 0s - loss: 0.2435 - binary_accuracy: 0.8921 - space_violation: 0.0366 - overpricing: 0.0469
# Epoch 438/512
# 9000/9000 - 0s - loss: 0.2434 - binary_accuracy: 0.8919 - space_violation: 0.0366 - overpricing: 0.0480
# Epoch 439/512
# 9000/9000 - 0s - loss: 0.2434 - binary_accuracy: 0.8916 - space_violation: 0.0368 - overpricing: 0.0471
# Epoch 440/512
# 9000/9000 - 0s - loss: 0.2436 - binary_accuracy: 0.8916 - space_violation: 0.0369 - overpricing: 0.0469
# Epoch 441/512
# 9000/9000 - 0s - loss: 0.2433 - binary_accuracy: 0.8924 - space_violation: 0.0360 - overpricing: 0.0438
# Epoch 442/512
# 9000/9000 - 0s - loss: 0.2435 - binary_accuracy: 0.8919 - space_violation: 0.0361 - overpricing: 0.0450
# Epoch 443/512
# 9000/9000 - 0s - loss: 0.2433 - binary_accuracy: 0.8920 - space_violation: 0.0365 - overpricing: 0.0472
# Epoch 444/512
# 9000/9000 - 0s - loss: 0.2434 - binary_accuracy: 0.8921 - space_violation: 0.0363 - overpricing: 0.0468
# Epoch 445/512
# 9000/9000 - 0s - loss: 0.2433 - binary_accuracy: 0.8924 - space_violation: 0.0359 - overpricing: 0.0452
# Epoch 446/512
# 9000/9000 - 0s - loss: 0.2432 - binary_accuracy: 0.8918 - space_violation: 0.0362 - overpricing: 0.0462
# Epoch 447/512
# 9000/9000 - 0s - loss: 0.2430 - binary_accuracy: 0.8921 - space_violation: 0.0367 - overpricing: 0.0450
# Epoch 448/512
# 9000/9000 - 0s - loss: 0.2431 - binary_accuracy: 0.8927 - space_violation: 0.0362 - overpricing: 0.0468
# Epoch 449/512
# 9000/9000 - 0s - loss: 0.2430 - binary_accuracy: 0.8920 - space_violation: 0.0360 - overpricing: 0.0453
# Epoch 450/512
# 9000/9000 - 0s - loss: 0.2429 - binary_accuracy: 0.8928 - space_violation: 0.0367 - overpricing: 0.0483
# Epoch 451/512
# 9000/9000 - 0s - loss: 0.2429 - binary_accuracy: 0.8921 - space_violation: 0.0362 - overpricing: 0.0440
# Epoch 452/512
# 9000/9000 - 0s - loss: 0.2430 - binary_accuracy: 0.8921 - space_violation: 0.0361 - overpricing: 0.0450
# Epoch 453/512
# 9000/9000 - 0s - loss: 0.2430 - binary_accuracy: 0.8927 - space_violation: 0.0360 - overpricing: 0.0460
# Epoch 454/512
# 9000/9000 - 0s - loss: 0.2430 - binary_accuracy: 0.8920 - space_violation: 0.0362 - overpricing: 0.0452
# Epoch 455/512
# 9000/9000 - 0s - loss: 0.2429 - binary_accuracy: 0.8920 - space_violation: 0.0362 - overpricing: 0.0455
# Epoch 456/512
# 9000/9000 - 0s - loss: 0.2427 - binary_accuracy: 0.8925 - space_violation: 0.0360 - overpricing: 0.0431
# Epoch 457/512
# 9000/9000 - 0s - loss: 0.2429 - binary_accuracy: 0.8922 - space_violation: 0.0362 - overpricing: 0.0474
# Epoch 458/512
# 9000/9000 - 0s - loss: 0.2427 - binary_accuracy: 0.8920 - space_violation: 0.0357 - overpricing: 0.0434
# Epoch 459/512
# 9000/9000 - 0s - loss: 0.2429 - binary_accuracy: 0.8913 - space_violation: 0.0360 - overpricing: 0.0448
# Epoch 460/512
# 9000/9000 - 0s - loss: 0.2427 - binary_accuracy: 0.8927 - space_violation: 0.0360 - overpricing: 0.0449
# Epoch 461/512
# 9000/9000 - 0s - loss: 0.2426 - binary_accuracy: 0.8926 - space_violation: 0.0358 - overpricing: 0.0443
# Epoch 462/512
# 9000/9000 - 0s - loss: 0.2425 - binary_accuracy: 0.8924 - space_violation: 0.0360 - overpricing: 0.0462
# Epoch 463/512
# 9000/9000 - 0s - loss: 0.2426 - binary_accuracy: 0.8917 - space_violation: 0.0365 - overpricing: 0.0455
# Epoch 464/512
# 9000/9000 - 0s - loss: 0.2426 - binary_accuracy: 0.8927 - space_violation: 0.0354 - overpricing: 0.0441
# Epoch 465/512
# 9000/9000 - 0s - loss: 0.2424 - binary_accuracy: 0.8928 - space_violation: 0.0364 - overpricing: 0.0462
# Epoch 466/512
# 9000/9000 - 0s - loss: 0.2424 - binary_accuracy: 0.8922 - space_violation: 0.0362 - overpricing: 0.0450
# Epoch 467/512
# 9000/9000 - 0s - loss: 0.2425 - binary_accuracy: 0.8923 - space_violation: 0.0358 - overpricing: 0.0450
# Epoch 468/512
# 9000/9000 - 0s - loss: 0.2425 - binary_accuracy: 0.8920 - space_violation: 0.0349 - overpricing: 0.0434
# Epoch 469/512
# 9000/9000 - 0s - loss: 0.2423 - binary_accuracy: 0.8929 - space_violation: 0.0360 - overpricing: 0.0448
# Epoch 470/512
# 9000/9000 - 0s - loss: 0.2424 - binary_accuracy: 0.8927 - space_violation: 0.0358 - overpricing: 0.0450
# Epoch 471/512
# 9000/9000 - 0s - loss: 0.2423 - binary_accuracy: 0.8925 - space_violation: 0.0357 - overpricing: 0.0446
# Epoch 472/512
# 9000/9000 - 0s - loss: 0.2423 - binary_accuracy: 0.8929 - space_violation: 0.0358 - overpricing: 0.0450
# Epoch 473/512
# 9000/9000 - 0s - loss: 0.2422 - binary_accuracy: 0.8924 - space_violation: 0.0352 - overpricing: 0.0432
# Epoch 474/512
# 9000/9000 - 0s - loss: 0.2422 - binary_accuracy: 0.8930 - space_violation: 0.0359 - overpricing: 0.0465
# Epoch 475/512
# 9000/9000 - 0s - loss: 0.2423 - binary_accuracy: 0.8922 - space_violation: 0.0358 - overpricing: 0.0442
# Epoch 476/512
# 9000/9000 - 0s - loss: 0.2419 - binary_accuracy: 0.8929 - space_violation: 0.0360 - overpricing: 0.0449
# Epoch 477/512
# 9000/9000 - 0s - loss: 0.2421 - binary_accuracy: 0.8924 - space_violation: 0.0364 - overpricing: 0.0453
# Epoch 478/512
# 9000/9000 - 0s - loss: 0.2421 - binary_accuracy: 0.8930 - space_violation: 0.0357 - overpricing: 0.0448
# Epoch 479/512
# 9000/9000 - 0s - loss: 0.2421 - binary_accuracy: 0.8930 - space_violation: 0.0359 - overpricing: 0.0453
# Epoch 480/512
# 9000/9000 - 0s - loss: 0.2420 - binary_accuracy: 0.8925 - space_violation: 0.0360 - overpricing: 0.0437
# Epoch 481/512
# 9000/9000 - 0s - loss: 0.2420 - binary_accuracy: 0.8928 - space_violation: 0.0361 - overpricing: 0.0462
# Epoch 482/512
# 9000/9000 - 0s - loss: 0.2419 - binary_accuracy: 0.8925 - space_violation: 0.0363 - overpricing: 0.0456
# Epoch 483/512
# 9000/9000 - 0s - loss: 0.2420 - binary_accuracy: 0.8926 - space_violation: 0.0363 - overpricing: 0.0447
# Epoch 484/512
# 9000/9000 - 0s - loss: 0.2419 - binary_accuracy: 0.8928 - space_violation: 0.0361 - overpricing: 0.0468
# Epoch 485/512
# 9000/9000 - 0s - loss: 0.2418 - binary_accuracy: 0.8926 - space_violation: 0.0356 - overpricing: 0.0444
# Epoch 486/512
# 9000/9000 - 0s - loss: 0.2418 - binary_accuracy: 0.8926 - space_violation: 0.0357 - overpricing: 0.0444
# Epoch 487/512
# 9000/9000 - 0s - loss: 0.2417 - binary_accuracy: 0.8930 - space_violation: 0.0360 - overpricing: 0.0452
# Epoch 488/512
# 9000/9000 - 0s - loss: 0.2417 - binary_accuracy: 0.8932 - space_violation: 0.0355 - overpricing: 0.0439
# Epoch 489/512
# 9000/9000 - 0s - loss: 0.2417 - binary_accuracy: 0.8930 - space_violation: 0.0354 - overpricing: 0.0447
# Epoch 490/512
# 9000/9000 - 0s - loss: 0.2417 - binary_accuracy: 0.8929 - space_violation: 0.0358 - overpricing: 0.0455
# Epoch 491/512
# 9000/9000 - 0s - loss: 0.2417 - binary_accuracy: 0.8927 - space_violation: 0.0354 - overpricing: 0.0426
# Epoch 492/512
# 9000/9000 - 0s - loss: 0.2415 - binary_accuracy: 0.8926 - space_violation: 0.0355 - overpricing: 0.0448
# Epoch 493/512
# 9000/9000 - 0s - loss: 0.2415 - binary_accuracy: 0.8932 - space_violation: 0.0353 - overpricing: 0.0445
# Epoch 494/512
# 9000/9000 - 0s - loss: 0.2415 - binary_accuracy: 0.8932 - space_violation: 0.0350 - overpricing: 0.0443
# Epoch 495/512
# 9000/9000 - 0s - loss: 0.2415 - binary_accuracy: 0.8938 - space_violation: 0.0353 - overpricing: 0.0454
# Epoch 496/512
# 9000/9000 - 0s - loss: 0.2414 - binary_accuracy: 0.8933 - space_violation: 0.0358 - overpricing: 0.0454
# Epoch 497/512
# 9000/9000 - 0s - loss: 0.2414 - binary_accuracy: 0.8929 - space_violation: 0.0347 - overpricing: 0.0426
# Epoch 498/512
# 9000/9000 - 0s - loss: 0.2414 - binary_accuracy: 0.8930 - space_violation: 0.0361 - overpricing: 0.0476
# Epoch 499/512
# 9000/9000 - 0s - loss: 0.2413 - binary_accuracy: 0.8930 - space_violation: 0.0348 - overpricing: 0.0429
# Epoch 500/512
# 9000/9000 - 0s - loss: 0.2413 - binary_accuracy: 0.8930 - space_violation: 0.0355 - overpricing: 0.0456
# Epoch 501/512
# 9000/9000 - 0s - loss: 0.2414 - binary_accuracy: 0.8928 - space_violation: 0.0361 - overpricing: 0.0457
# Epoch 502/512
# 9000/9000 - 0s - loss: 0.2412 - binary_accuracy: 0.8927 - space_violation: 0.0360 - overpricing: 0.0446
# Epoch 503/512
# 9000/9000 - 0s - loss: 0.2413 - binary_accuracy: 0.8932 - space_violation: 0.0355 - overpricing: 0.0452
# Epoch 504/512
# 9000/9000 - 0s - loss: 0.2412 - binary_accuracy: 0.8934 - space_violation: 0.0350 - overpricing: 0.0429
# Epoch 505/512
# 9000/9000 - 0s - loss: 0.2410 - binary_accuracy: 0.8932 - space_violation: 0.0353 - overpricing: 0.0439
# Epoch 506/512
# 9000/9000 - 0s - loss: 0.2411 - binary_accuracy: 0.8932 - space_violation: 0.0357 - overpricing: 0.0456
# Epoch 507/512
# 9000/9000 - 0s - loss: 0.2410 - binary_accuracy: 0.8935 - space_violation: 0.0347 - overpricing: 0.0419
# Epoch 508/512
# 9000/9000 - 0s - loss: 0.2410 - binary_accuracy: 0.8929 - space_violation: 0.0357 - overpricing: 0.0459
# Epoch 509/512
# 9000/9000 - 0s - loss: 0.2410 - binary_accuracy: 0.8931 - space_violation: 0.0352 - overpricing: 0.0447
# Epoch 510/512
# 9000/9000 - 0s - loss: 0.2411 - binary_accuracy: 0.8926 - space_violation: 0.0356 - overpricing: 0.0454
# Epoch 511/512
# 9000/9000 - 0s - loss: 0.2409 - binary_accuracy: 0.8932 - space_violation: 0.0354 - overpricing: 0.0454
# Epoch 512/512
# 9000/9000 - 0s - loss: 0.2409 - binary_accuracy: 0.8935 - space_violation: 0.0352 - overpricing: 0.0443

# %%
model.evaluate(x_test,  y_test, verbose=2)
# It's the following:
# [loss, accuracy, space_violation, overpricing]
# Out:
# C:\Users\Guilherme\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# [0.24429048132896422, 0.8928, 0.035031185, 0.045922533]

# %%
# Understanding the data shape:

# x_train[0] are weights
# x_train[1] are prices

# model.predict([x_train[0], x_train[1]]) == model.predict(x_train)
print(model.predict([[x_train[0][0]], [x_train[1][0]]]))
print(np.array([x_train[0], x_train[1]]).shape)
print(np.array([[x_train[0][0]], [x_train[1][0]]]).shape)
# [
#  [
#   ... weights
#   ... 9000 entries
#  ]
#  [
#   ... prices
#   ... 9000 entries
#  ]
# ]
# Out:
# [[0.09659481 0.98779726 0.89629364 0.00433263 0.26424748]]
# (2, 9000, 5)
# (2, 1, 5)

# %%
print("5 first previsions: ")
for i in range(5):
  print(f"Features data - {i}")
  print("Weights:")
  print(x_train[0][i])
  print("Prices:")
  print(x_train[1][i])
  print("Actual output")
  print(y_train[i])
  print("Predicted output")
  predictions, = model.predict([[x_train[0][i]], [x_train[1][i]]])
  print(predictions)
  print("Predicted output rounded")
  print(np.round(predictions))
  print("\n")
# Out:
# 5 first previsions:
# Features data - 0
# Weights:
# [1.13333333 0.26666667 0.03333333 1.43333333 0.5       ]
# Prices:
# [0.9787234  1.         0.15957447 0.75531915 0.12765957]
# Actual output
# [0. 1. 1. 0. 1.]
# Predicted output
# [0.09659481 0.98779726 0.89629364 0.00433263 0.26424748]
# Predicted output rounded
# [0. 1. 1. 0. 0.]
#
#
# Features data - 1
# Weights:
# [1.46153846 1.92307692 1.61538462 2.84615385 2.69230769]
# Prices:
# [0.48387097 1.         0.53763441 0.84946237 0.15053763]
# Actual output
# [0. 0. 0. 0. 0.]
# Predicted output
# [1.1871278e-02 1.0654032e-02 4.5799911e-03 8.0499053e-04 9.8496348e-06]
# Predicted output rounded
# [0. 0. 0. 0. 0.]
#
#
# Features data - 2
# Weights:
# [4.66666667 6.16666667 6.16666667 5.5        3.        ]
# Prices:
# [0.125    1.       0.28125  0.515625 0.09375 ]
# Actual output
# [0. 0. 0. 0. 0.]
# Predicted output
# [1.0511759e-04 4.1440129e-04 6.0831480e-05 1.7166436e-03 1.3001263e-03]
# Predicted output rounded
# [0. 0. 0. 0. 0.]
#
#
# Features data - 3
# Weights:
# [1.59259259 1.37037037 0.74074074 0.96296296 1.11111111]
# Prices:
# [0.48       0.53333333 0.18666667 1.         0.84      ]
# Actual output
# [0. 0. 0. 1. 0.]
# Predicted output
# [2.0807981e-04 3.4523308e-03 6.0438335e-02 6.2443817e-01 9.0706915e-02]
# Predicted output rounded
# [0. 0. 0. 1. 0.]
#
#
# Features data - 4
# Weights:
# [16.  3. 17. 30.  6.]
# Prices:
# [0.51923077 0.98076923 1.         0.55769231 0.63461538]
# Actual output
# [0. 0. 0. 0. 0.]
# Predicted output
# [3.3065032e-06 7.5445384e-02 1.9282103e-04 5.4866459e-06 1.1865466e-04]
# Predicted output rounded
# [0. 0. 0. 0. 0.]
